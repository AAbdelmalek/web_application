# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
response = requests.get("https://www.youtube.com/watch?v=8Eq6yWDHOEY")
soup = bs(response.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
for title in soup.find_all("h4"):
    print(title.text)
# Out:
#       Partner rating
#
#
#       Category
#
#
#         Up next

# %%
test = ["x","y","z"]

test.pop(0)
# Out:
# 'x'

# %%
test
# Out:
# ['y', 'z']
