# %%
# To do:
# Fix Dates, must be another published on vs premiered on discrepancy -- OK
# Fix Titles -- OK
# Looks like missing one (1) video for Gibi 344/345 -- OK
# DUPLICATES -- OK
# User entered date range --
# Better commenting --
# Duration --

# Import Dependencies
from bs4 import BeautifulSoup as bs
import requests
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
pd.set_option('display.max_rows', 500)

# %%
converted_date = ""
raw_months = {"Jan": 1, "Feb": 2, "Mar" : 3, "Apr" : 4, 
              "May" : 5, "Jun" : 6, "Jul" : 7, "Aug" : 8,
              "Sep" : 9, "Oct" : 10, "Nov" : 11, "Dec" : 12}

# Convert Date from Jan 1, 1999 format to datetime object
def convertDate(raw_date):
    
    converted_date = ""
    
    number_month = raw_months.get(raw_date[0])
    
    date_str = (str(number_month) + "/" + raw_date[1] + "/" + raw_date[2]).replace(",", "")
    
    converted_date = datetime.strptime(date_str, '%m/%d/%Y')
    
    return converted_date

# %%
# Get Youtuber's Name
input_name = input("Enter Youtuber's Name: ")

list_name = input_name.split()

converted_name = input_name

if len(list_name) > 1:
    
    converted_name = ""
    
    for i in range(len(list_name)):

        converted_name = converted_name + list_name[i]
        
        if i != len(list_name)-1:
            converted_name = converted_name + "+"

search_name = converted_name

start_url = "https://www.youtube.com/results?search_query=" + search_name
# Out:
# Enter Youtuber's Name: asmr glow

# %%
print(start_url)
get_youtube_url_response = requests.get(start_url)
# Out:
# https://www.youtube.com/results?search_query=asmr+glow

# %%
youtube_name_soup = bs(get_youtube_url_response.text, "lxml")

# %%
raw_youtube_name_link = youtube_name_soup.find_all("div", class_="yt-lockup-byline")[0].a.get("href")

videos_link = "https://www.youtube.com" + raw_youtube_name_link + "/videos"

about_link = "https://www.youtube.com" + raw_youtube_name_link + "/about"

print(videos_link)
print(about_link)
# Out:
# https://www.youtube.com/channel/UCFmL725KKPx2URVPvH3Gp8w/videos
# https://www.youtube.com/channel/UCFmL725KKPx2URVPvH3Gp8w/about

# %%
# Get About Information
about_html = requests.get(about_link)

# Parse HTML
about_soup = bs(about_html.text, "lxml")

# %%
# Artist Information
artist_name = about_soup.find("meta", property="og:title").get("content")

subscribers = about_soup.find_all("span", class_="about-stat")[0].text
subscribers_int = int(subscribers.split(" ")[0].replace(",",""))

total_views = about_soup.find_all("span", class_="about-stat")[1].text
total_views_int = int(total_views[3:len(total_views)].split(" ")[0].replace(",",""))

joined = about_soup.find_all("span", class_="about-stat")[2].text
joined_temp = joined.split(" ")[1:4]
joined_convert = convertDate(joined_temp)

print(f"Artist: {artist_name}")
print(f"Subscribers: {subscribers_int}")
print(f"Views: {total_views_int}")
print(f"Joined: {joined_convert}")
# Out:
# Artist: ASMR Glow
# Subscribers: 630919
# Views: 102071202
# Joined: 2016-10-24 00:00:00

# %%
# Convert User Name to UU Format
youtube_code = raw_youtube_name_link.split("/")[2]

if youtube_code[0:2] == "UC":
    
    youtube_code = raw_youtube_name_link.split("/")[2]

    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:] 

elif youtube_code[0:2] != "UC":
    
    youtube_code_raw = about_soup.find("link", rel="canonical").get("href")
    
    youtube_code = youtube_code_raw.split("/")[4]
    
    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:]  
    

print(playlist_link)
# Out:
# https://www.youtube.com/playlist?list=UUFmL725KKPx2URVPvH3Gp8w

# %%
# Get Playlist Response
playlist_response = requests.get(playlist_link)

# %%
# Create Playlist Soup Object
playlist_soup = bs(playlist_response.text, 'lxml')

# %%
# Get First Video URL as Starting Point
first_video = "https://www.youtube.com" + playlist_soup.find_all("a", class_="pl-video-title-link")[0].get("href").split("&")[0]
first_video_within_playlist = first_video + "&" + playlist_link.split("?")[1]

print(first_video_within_playlist)
# Out:
# https://www.youtube.com/watch?v=iWQ9COY5K4A&list=UUFmL725KKPx2URVPvH3Gp8w

# %%
# Create Soup Object for First Video Inside Playlist
playlist_inside_request = requests.get(first_video_within_playlist) 

playlist_inside_soup = bs(playlist_inside_request.text, "lxml")

# %%
urls_all = []
total_videos_in_playlist = int(playlist_inside_soup.find("span", id="playlist-length").text.replace(" videos","").replace(",",""))
number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) 
last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
link_fix = "https://www.youtube.com" + last_shown_link
    
for i in range(total_videos_in_playlist):   

    if i == 0:
        
        print(f"loop1, i={i}")
        
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
        
        url = "https://www.youtube.com" + first_link.find_next("a").get("href")
        
        original_url = url.split("&")[0]

        urls_all.append(original_url)
        
        next_link = first_link
        
    elif i == last_video_index:

        print(f"loop2, i={i}------------------------------------------------")
        
        playlist_inside_request = requests.get(link_fix)
        
        playlist_inside_soup = bs(playlist_inside_request.text, "lxml")
        
        last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
        
        link_fix = "https://www.youtube.com" + last_shown_link
        
        last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
        
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i+1}\n    ")
        
        second_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ")
        
        temp_link = second_link.find_next("span", class_="index")
        
        if temp_link.text.replace("\n","").replace(" ","") == "▶":
            
            next_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
            
        else:
            
            next_link = first_link
        
        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
        
        original_url = next_url.split("&")[0]
        
        urls_all.append(original_url)
        
        number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) - 1
              
    else:
        
        print(f"loop3, i={i}")
 
        if i == 1:

            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
            
        else:
        
            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ")

        next_link = first_link

        next_link = next_link.find_next("span", class_="index")

        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")

        original_url = next_url.split("&")[0]

        urls_all.append(original_url)
# Out:
# loop1, i=0
# loop3, i=1
# loop3, i=2
# loop3, i=3
# loop3, i=4
# loop3, i=5
# loop3, i=6
# loop3, i=7
# loop3, i=8
# loop3, i=9
# loop3, i=10
# loop3, i=11
# loop3, i=12
# loop3, i=13
# loop3, i=14
# loop3, i=15
# loop3, i=16
# loop3, i=17
# loop3, i=18
# loop3, i=19
# loop3, i=20
# loop3, i=21
# loop3, i=22
# loop3, i=23
# loop3, i=24
# loop3, i=25
# loop3, i=26
# loop3, i=27
# loop3, i=28
# loop3, i=29
# loop3, i=30
# loop3, i=31
# loop3, i=32
# loop3, i=33
# loop3, i=34
# loop3, i=35
# loop3, i=36
# loop3, i=37
# loop3, i=38
# loop3, i=39
# loop3, i=40
# loop3, i=41
# loop3, i=42
# loop3, i=43
# loop3, i=44
# loop3, i=45
# loop3, i=46
# loop3, i=47
# loop3, i=48
# loop3, i=49
# loop3, i=50
# loop3, i=51
# loop3, i=52
# loop3, i=53
# loop3, i=54
# loop3, i=55
# loop3, i=56
# loop3, i=57
# loop3, i=58
# loop3, i=59
# loop3, i=60
# loop3, i=61
# loop3, i=62
# loop3, i=63
# loop3, i=64
# loop3, i=65
# loop3, i=66
# loop3, i=67
# loop3, i=68
# loop3, i=69
# loop3, i=70
# loop3, i=71
# loop3, i=72
# loop3, i=73
# loop3, i=74
# loop3, i=75
# loop3, i=76
# loop3, i=77
# loop3, i=78
# loop2, i=79------------------------------------------------
# loop3, i=80
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-251-0898f667e3f8> in <module>()
#      72         next_link = first_link
#      73
# ---> 74         next_link = next_link.find_next("span", class_="index")
#      75
#      76         next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
#
# AttributeError: 'NoneType' object has no attribute 'find_next'

# %%
first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ")
next_link = first_link
first_link
# next_link = next_link.find_next("span", class_="index")
# next_link.text.replace("\n","").replace(" ","")
# Out:
# <span class="index">
#         79
#     </span>

# %%
first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ")
first_link.find_next("span", class_="index")
# Out:
# <span class="index">
#         ▶
#     </span>

# %%
# Going to Each Video and Extracting Data
published_on = []
raw_published_on = []
views = []
date = []
duration_videos = []
likes = []
dislikes = []
title_videos = []
categories = []

for i in range(len(urls_all)):
    
    video_url = urls_all[i]
    video_response = requests.get(video_url)
    video_soup = bs(video_response.text, 'lxml')
    
    # Title
    title = video_soup.find("title").text.replace(" - YouTube", "")
    title_videos.append(title)
    
    # Views
    string_views = video_soup.find("div", id="watch7-views-info").text.replace(" views", "").replace(",","").replace("\n","")
    int_views = int(string_views)
    views.append(int_views)
    
#     # Duration
#     duration = video_soup.find("span", class_="video-time").text
#     duration_videos.append(duration)
    
    # Likes
    string_likes = video_soup.find("button", title="I like this").text
    if string_likes != "":
        int_likes = int(string_likes.replace(",",""))
        likes.append(int_likes)
    else:
        likes.append(0)
    
    # Dislikes
    string_dislikes = video_soup.find("button", title="I dislike this").text
    if string_dislikes != "":
        int_dislikes = int(string_dislikes.replace(",",""))
        dislikes.append(int_dislikes)
    else:
        dislikes.append(0)
    
    # Publish Date
    raw_publish_date = video_soup.find("div", id="watch-uploader-info").text
    raw_published_on.append(raw_publish_date)
    
    # Handle All Raw Dates "Premiered", ""Published", "Streamed"
    publish_date_format = raw_publish_date.split(" ")[len(raw_publish_date.split(" "))-3:len(raw_publish_date.split(" "))]
    publish_date_convert = convertDate(publish_date_format)
    published_on.append(publish_date_convert)
    
    # Category
    category = video_soup.find("h4", class_="title", text="\n      Category\n    ").find_next("a").text
    categories.append(category)
    
    print(f"({i+1}/{len(urls_all)})")
# Out:
# (1/17)
# (2/17)
# (3/17)
# (4/17)
# (5/17)
# (6/17)
# (7/17)
# (8/17)
# (9/17)
# (10/17)
# (11/17)
# (12/17)
# (13/17)
# (14/17)
# (15/17)
# (16/17)
# (17/17)

# %%
# Create DataFrame
df = pd.DataFrame({"Artist" : artist_name,
                   "Joined" : joined_convert,
                   "Subscribers" : subscribers_int,
                   "Total Views" : total_views_int,
                   "Date": published_on,
                   "Title" : title_videos,
                   "Category" : categories,
                   #"Duration" : duration_videos,
                   "Views" : views,
                   "Likes" : likes,
                   "Dislikes" : dislikes,
                   "URL" : urls_all,
                  })

# df = df.sort_values("Date",ascending=False).reindex()
df.to_csv(f"{artist_name}_scrape.csv")
df
# Out:
#          Artist     Joined  Subscribers  Total Views       Date  \
# 0   Diddly ASMR 2018-07-04        31585      1703756 2018-12-10
# 1   Diddly ASMR 2018-07-04        31585      1703756 2018-12-01
# 2   Diddly ASMR 2018-07-04        31585      1703756 2018-11-23
# 3   Diddly ASMR 2018-07-04        31585      1703756 2018-11-17
# 4   Diddly ASMR 2018-07-04        31585      1703756 2018-11-09
# 5   Diddly ASMR 2018-07-04        31585      1703756 2018-11-03
# 6   Diddly ASMR 2018-07-04        31585      1703756 2018-10-28
# 7   Diddly ASMR 2018-07-04        31585      1703756 2018-10-21
# 8   Diddly ASMR 2018-07-04        31585      1703756 2018-10-06
# 9   Diddly ASMR 2018-07-04        31585      1703756 2018-09-28
# 10  Diddly ASMR 2018-07-04        31585      1703756 2018-09-21
# 11  Diddly ASMR 2018-07-04        31585      1703756 2018-09-11
# 12  Diddly ASMR 2018-07-04        31585      1703756 2018-09-01
# 13  Diddly ASMR 2018-07-04        31585      1703756 2018-08-22
# 14  Diddly ASMR 2018-07-04        31585      1703756 2018-08-16
# 15  Diddly ASMR 2018-07-04        31585      1703756 2018-08-10
# 16  Diddly ASMR 2018-07-04        31585      1703756 2018-07-22
#
#                                                 Title        Category   Views  \
# 0          ASMR Tingly Trigger Words & Hand Movements   Entertainment   28703
# 1     ASMR Face Brushing & Breathy Whispers for Sleep   Entertainment   93442
# 2   ASMR Tweezing Your Eyebrows (Up-Close Personal...   Entertainment   35605
# 3             ASMR Rainbow Mechanical Keyboard Typing   Entertainment   99208
# 4   ASMR Wooden Sound Assortment | Tapping on Wood...   Entertainment   50584
# 5                ASMR Controller Sounds (Soft Spoken)   Entertainment   36975
# 6   Australian Tries American Candy For The First ...   Entertainment   47805
# 7                        ASMR Giving You a Haircut ✂️   Entertainment  132965
# 8   ASMR Teaching You Australian Slang | Trigger W...   Entertainment  146350
# 9                ASMR Mic Brushing & Breathy Whispers   Entertainment   89800
# 10               ASMR Kissing Sounds & Hand Movements   Entertainment  108116
# 11                         ASMR Tingly Tapping Sounds   Entertainment  102244
# 12             ASMR Relaxing Hand Movements for Sleep   Entertainment  272467
# 13                 ASMR Show & Tell | Pokémon Edition   Entertainment   52002
# 14  ASMR Checking Your Eyes With a Flashlight | Up...   Entertainment  207535
# 15                             ASMR Doing Your Makeup   Entertainment  106600
# 16  My First ASMR Video! Whispers, Mouth sounds, V...  People & Blogs   94629
#
#     Likes  Dislikes                                          URL
# 0    1127        31  https://www.youtube.com/watch?v=BcfxBR9rp4A
# 1    2059       104  https://www.youtube.com/watch?v=9JBxmqkKi8Y
# 2    1012        47  https://www.youtube.com/watch?v=7HVvtCBQvBo
# 3    1746       127  https://www.youtube.com/watch?v=0CwxjrAMtXg
# 4    1293        39  https://www.youtube.com/watch?v=iw4Xkep2IiE
# 5    1084        72  https://www.youtube.com/watch?v=S726_NzCtX0
# 6    1122        80  https://www.youtube.com/watch?v=iEiu0Tumlws
# 7    2259       117  https://www.youtube.com/watch?v=4CnpuCknGK0
# 8    3011       150  https://www.youtube.com/watch?v=kTgOVqBkmhs
# 9    1936        79  https://www.youtube.com/watch?v=wQ-4jmVpBk8
# 10   1951       124  https://www.youtube.com/watch?v=U1QmytdQ7eQ
# 11   2038       123  https://www.youtube.com/watch?v=s25i2lMwLhQ
# 12   4684       211  https://www.youtube.com/watch?v=fxslk8vnlqs
# 13   1335        41  https://www.youtube.com/watch?v=hqYs8jkc-5A
# 14   3275       141  https://www.youtube.com/watch?v=ky433l_b6h0
# 15   2015        86  https://www.youtube.com/watch?v=0rvROFMj1og
# 16   2660        77  https://www.youtube.com/watch?v=HVxVjZ93tTc

# %%
# Graph Data
#plt.bar(np.arange(0,len(df),1),df["Views"], tick_label = df["Date"])
plt.scatter(np.arange(0,len(df),1),df["Views"])
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"] = [15,6]

# %%
df[df["Dislikes"] == 0]
# Out:
#                      Artist     Joined  Subscribers  Total Views       Date  \
# 264  Gentle Whispering ASMR 2011-02-24      1552679    553807676 2012-11-15
# 344  Gentle Whispering ASMR 2011-02-24      1552679    553807676 2011-09-07
#
#                                             Title        Category   Views  \
# 264   :D THANK YOU 50K! :D not relaxing, sorry :)  People & Blogs  139203
# 344  Customer Service Relaxation (soft spoken) #2   Entertainment  776569
#
#      Likes  Dislikes                                          URL
# 264      0         0  https://www.youtube.com/watch?v=j8MOCbL-Jko
# 344      0         0  https://www.youtube.com/watch?v=XI10SFOLgKw
