# %%
# To do:
# Fix Dates, must be another published on vs premiered on discrepancy -- OK
# Fix Titles -- OK
# Looks like missing one (1) video for Gibi 344/345 -- OK
# DUPLICATES -- OK
# EDGE CASES ▶ -- OK
# User entered date range -- OK
# Better commenting -- 
# Duration --
# Flask -- 
# HTML/CSS/JS --

# Import Dependencies
from bs4 import BeautifulSoup as bs
import requests
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
import time
pd.set_option('display.max_rows', 500)

# Convert Date from Jan 1, 1999 format to datetime object
converted_date = ""
raw_months = {"Jan": 1, "Feb": 2, "Mar" : 3, "Apr" : 4, 
              "May" : 5, "Jun" : 6, "Jul" : 7, "Aug" : 8,
              "Sep" : 9, "Oct" : 10, "Nov" : 11, "Dec" : 12}

def convertDate(raw_date):
    
    try:
        converted_date = ""
        number_month = raw_months.get(raw_date[0])
        date_str = (str(number_month) + "/" + raw_date[1] + "/" + raw_date[2]).replace(",", "")
        converted_date = datetime.strptime(date_str, '%m/%d/%Y')
        return converted_date
    
    except:
        print("Input date is not valid.")

# Get Youtuber's Name
input_name = input("Enter Youtuber's Name: ")
print(input_name)

input_date_range = input("How far back in time do you want to go? (YYYY-MM-DD) or (all-time): ")
print(input_date_range)

if input_date_range == "all-time":
    converted_input_date = datetime.strptime("1950-01-01", '%Y-%m-%d')
    
else:
    try:
        converted_input_date = datetime.strptime(input_date_range, '%Y-%m-%d')
        
    except:
        print("Input date is not valid.")

list_name = input_name.split()

converted_name = input_name

if len(list_name) > 1:
    
    converted_name = ""
    
    for i in range(len(list_name)):

        converted_name = converted_name + list_name[i]
        
        if i != len(list_name)-1:
            converted_name = converted_name + "+"

search_name = converted_name
start_url = "https://www.youtube.com/results?search_query=" + search_name

print(start_url)

get_youtube_url_response = requests.get(start_url)
youtube_name_soup = bs(get_youtube_url_response.text, "lxml")
raw_youtube_name_link = youtube_name_soup.find_all("div", class_="yt-lockup-byline")[0].a.get("href")
videos_link = "https://www.youtube.com" + raw_youtube_name_link + "/videos"
about_link = "https://www.youtube.com" + raw_youtube_name_link + "/about"

print(videos_link)
print(about_link)

# Get About Information
about_html = requests.get(about_link)

# Parse HTML
about_soup = bs(about_html.text, "lxml")

# Artist Information
artist_name = about_soup.find("meta", property="og:title").get("content")

subscribers = about_soup.find_all("span", class_="about-stat")[0].text
subscribers_int = int(subscribers.split(" ")[0].replace(",",""))

total_views = about_soup.find_all("span", class_="about-stat")[1].text
total_views_int = int(total_views[3:len(total_views)].split(" ")[0].replace(",",""))

joined = about_soup.find_all("span", class_="about-stat")[2].text
joined_temp = joined.split(" ")[1:4]
joined_convert = convertDate(joined_temp)

print(f"Artist: {artist_name}")
print(f"Subscribers: {subscribers_int}")
print(f"Views: {total_views_int}")
print(f"Joined: {joined_convert}")

# Convert User Name to UU Format
youtube_code = raw_youtube_name_link.split("/")[2]

if youtube_code[0:2] == "UC":
    
    youtube_code = raw_youtube_name_link.split("/")[2]
    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:] 

elif youtube_code[0:2] != "UC":
    
    youtube_code_raw = about_soup.find("link", rel="canonical").get("href")
    youtube_code = youtube_code_raw.split("/")[4]
    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:]  
    
print(playlist_link)

# Get Playlist Response
playlist_response = requests.get(playlist_link)

# Create Playlist Soup Object
playlist_soup = bs(playlist_response.text, 'lxml')

# Get First Video URL as Starting Point
first_video = "https://www.youtube.com" + playlist_soup.find_all("a", class_="pl-video-title-link")[0].get("href").split("&")[0]
first_video_within_playlist = first_video + "&" + playlist_link.split("?")[1]

print(first_video_within_playlist)

# Create Soup Object for First Video Inside Playlist
playlist_inside_request = requests.get(first_video_within_playlist) 

playlist_inside_soup = bs(playlist_inside_request.text, "lxml")

urls_all = []
total_videos_in_playlist = int(playlist_inside_soup.find("span", id="playlist-length").text.replace(" videos","").replace(",",""))
print(f"Total videos: {total_videos_in_playlist}")
number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) 
last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
link_fix = "https://www.youtube.com" + last_shown_link
    
for i in range(total_videos_in_playlist):   

    if i == 0:
        
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
        url = "https://www.youtube.com" + first_link.find_next("a").get("href")
        original_url = url.split("&")[0]
        urls_all.append(original_url)
        next_link = first_link
        
    elif i == last_video_index:
        
        playlist_inside_request = requests.get(link_fix)
        playlist_inside_soup = bs(playlist_inside_request.text, "lxml")
        last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
        link_fix = "https://www.youtube.com" + last_shown_link
        last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i+1}\n    ")
        
        if first_link is None:
            
            next_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
            
        else:
            
            next_link = first_link
        
        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
        original_url = next_url.split("&")[0]
        urls_all.append(original_url)
        number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) - 1
              
    else:
 
        if i == 1:

            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
            
        elif playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ") is None:
            
            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
        
        else:
        
            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ")

        next_link = first_link
        next_link = next_link.find_next("span", class_="index")
        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
        original_url = next_url.split("&")[0]
        urls_all.append(original_url)

# Going to Each Video and Extracting Data
published_on = []
raw_published_on = []
views = []
date = []
duration_videos = []
likes = []
dislikes = []
title_videos = []
categories = []

for i in range(len(urls_all)):
    
    video_url = urls_all[i]
    video_response = requests.get(video_url)
    video_soup = bs(video_response.text, 'lxml')
    
    # Publish Date
    raw_publish_date = video_soup.find("div", id="watch-uploader-info").text
    raw_published_on.append(raw_publish_date)
    
    # Handle All Raw Dates "Premiered", ""Published", "Streamed"
    publish_date_format = raw_publish_date.split(" ")[len(raw_publish_date.split(" "))-3:len(raw_publish_date.split(" "))]
    publish_date_convert = convertDate(publish_date_format)
    
    # Break if Date Less than Input Date Range
    if publish_date_convert < converted_input_date:
        break
    
    else:
        published_on.append(publish_date_convert)
    
    # Title
    title = video_soup.find("title").text.replace(" - YouTube", "")
    title_videos.append(title)
    
    # Views
    string_views = video_soup.find("div", id="watch7-views-info").text.replace(" views", "").replace(",","").replace("\n","")
    int_views = int(string_views)
    views.append(int_views)
    
#     # Duration
#     duration = video_soup.find("span", class_="video-time").text
#     duration_videos.append(duration)
    
    # Likes
    string_likes = video_soup.find("button", title="I like this").text
    if string_likes != "":
        int_likes = int(string_likes.replace(",",""))
        likes.append(int_likes)
    else:
        likes.append(0)
    
    # Dislikes
    string_dislikes = video_soup.find("button", title="I dislike this").text
    if string_dislikes != "":
        int_dislikes = int(string_dislikes.replace(",",""))
        dislikes.append(int_dislikes)
    else:
        dislikes.append(0)
    
    # Category
    category = video_soup.find("h4", class_="title", text="\n      Category\n    ").find_next("a").text
    categories.append(category)
    
    print(f"({i+1}/{len(urls_all)})")
    
urls_to_date = urls_all[0:len(published_on)]

# Create DataFrame
df = pd.DataFrame({"Artist" : artist_name,
                   "Joined" : joined_convert,
                   "Subscribers" : subscribers_int,
                   "Total Views" : total_views_int,
                   "Date": published_on,
                   "Title" : title_videos,
                   "Category" : categories,
                   #"Duration" : duration_videos,
                   "Views" : views,
                   "Likes" : likes,
                   "Dislikes" : dislikes,
                   "URL" : urls_to_date,
                  })

df = df.sort_values("Date",ascending=False)

# Saving to CSV
df.to_csv(f"{artist_name}_scrape.csv")

# Saving to JSON
df.to_json(f"../js/{artist_name}_data.js", orient="records")

# View Data
df
# Out:
# Enter Youtuber's Name: asmr darling
# asmr darling
# How far back in time do you want to go? (YYYY-MM-DD) or (all-time): all-time
# all-time
# https://www.youtube.com/results?search_query=asmr+darling
# https://www.youtube.com/channel/UCikebqFWoT3QC9axUbXCPYw/videos
# https://www.youtube.com/channel/UCikebqFWoT3QC9axUbXCPYw/about
# Artist: ASMR Darling
# Subscribers: 2136346
# Views: 391606080
# Joined: 2014-12-10 00:00:00
# https://www.youtube.com/playlist?list=UUikebqFWoT3QC9axUbXCPYw
# https://www.youtube.com/watch?v=9Cz9_49Pcv4&list=UUikebqFWoT3QC9axUbXCPYw
# Total videos: 147
# (1/147)
# (2/147)
# (3/147)
# (4/147)
# (5/147)
# (6/147)
# (7/147)
# (8/147)
# (9/147)
# (10/147)
# (11/147)
# (12/147)
# (13/147)
# (14/147)
# (15/147)
# (16/147)
# (17/147)
# (18/147)
# (19/147)
# (20/147)
# (21/147)
# (22/147)
# (23/147)
# (24/147)
# (25/147)
# (26/147)
# (27/147)
# (28/147)
# (29/147)
# (30/147)
# (31/147)
# (32/147)
# (33/147)
# (34/147)
# (35/147)
# (36/147)
# (37/147)
# (38/147)
# (39/147)
# (40/147)
# (41/147)
# (42/147)
# (43/147)
# (44/147)
# (45/147)
# (46/147)
# (47/147)
# (48/147)
# (49/147)
# (50/147)
# (51/147)
# (52/147)
# (53/147)
# (54/147)
# (55/147)
# (56/147)
# (57/147)
# (58/147)
# (59/147)
# (60/147)
# (61/147)
# (62/147)
# (63/147)
# (64/147)
# (65/147)
# (66/147)
# (67/147)
# (68/147)
# (69/147)
# (70/147)
# (71/147)
# (72/147)
# (73/147)
# (74/147)
# (75/147)
# (76/147)
# (77/147)
# (78/147)
# (79/147)
# (80/147)
# (81/147)
# (82/147)
# (83/147)
# (84/147)
# (85/147)
# (86/147)
# (87/147)
# (88/147)
# (89/147)
# (90/147)
# (91/147)
# (92/147)
# (93/147)
# (94/147)
# (95/147)
# (96/147)
# (97/147)
# (98/147)
# (99/147)
# (100/147)
# (101/147)
# (102/147)
# (103/147)
# (104/147)
# (105/147)
# (106/147)
# (107/147)
# (108/147)
# (109/147)
# (110/147)
# (111/147)
# (112/147)
# (113/147)
# (114/147)
# (115/147)
# (116/147)
# (117/147)
# (118/147)
# (119/147)
# (120/147)
# (121/147)
# (122/147)
# (123/147)
# (124/147)
# (125/147)
# (126/147)
# (127/147)
# (128/147)
# (129/147)
# (130/147)
# (131/147)
# (132/147)
# (133/147)
# (134/147)
# (135/147)
# (136/147)
# (137/147)
# (138/147)
# (139/147)
# (140/147)
# (141/147)
# (142/147)
# (143/147)
# (144/147)
# (145/147)
# (146/147)
# (147/147)
#            Artist     Joined  Subscribers  Total Views       Date  \
# 0    ASMR Darling 2014-12-10      2136346    391606080 2018-11-27
# 1    ASMR Darling 2014-12-10      2136346    391606080 2018-11-15
# 2    ASMR Darling 2014-12-10      2136346    391606080 2018-11-09
# 3    ASMR Darling 2014-12-10      2136346    391606080 2018-11-04
# 4    ASMR Darling 2014-12-10      2136346    391606080 2018-09-06
# 5    ASMR Darling 2014-12-10      2136346    391606080 2018-08-22
# 6    ASMR Darling 2014-12-10      2136346    391606080 2018-08-05
# 7    ASMR Darling 2014-12-10      2136346    391606080 2018-07-31
# 8    ASMR Darling 2014-12-10      2136346    391606080 2018-07-25
# 9    ASMR Darling 2014-12-10      2136346    391606080 2018-07-22
# 10   ASMR Darling 2014-12-10      2136346    391606080 2018-07-13
# 11   ASMR Darling 2014-12-10      2136346    391606080 2018-07-09
# 12   ASMR Darling 2014-12-10      2136346    391606080 2018-07-03
# 13   ASMR Darling 2014-12-10      2136346    391606080 2018-06-30
# 14   ASMR Darling 2014-12-10      2136346    391606080 2018-06-23
# 15   ASMR Darling 2014-12-10      2136346    391606080 2018-06-03
# 16   ASMR Darling 2014-12-10      2136346    391606080 2018-05-24
# 17   ASMR Darling 2014-12-10      2136346    391606080 2018-05-21
# 18   ASMR Darling 2014-12-10      2136346    391606080 2018-05-17
# 19   ASMR Darling 2014-12-10      2136346    391606080 2018-05-08
# 20   ASMR Darling 2014-12-10      2136346    391606080 2018-05-02
# 21   ASMR Darling 2014-12-10      2136346    391606080 2018-04-25
# 22   ASMR Darling 2014-12-10      2136346    391606080 2018-04-20
# 23   ASMR Darling 2014-12-10      2136346    391606080 2018-04-16
# 24   ASMR Darling 2014-12-10      2136346    391606080 2018-04-06
# 25   ASMR Darling 2014-12-10      2136346    391606080 2018-03-24
# 26   ASMR Darling 2014-12-10      2136346    391606080 2018-03-16
# 27   ASMR Darling 2014-12-10      2136346    391606080 2018-02-18
# 28   ASMR Darling 2014-12-10      2136346    391606080 2018-02-11
# 29   ASMR Darling 2014-12-10      2136346    391606080 2018-01-30
# 30   ASMR Darling 2014-12-10      2136346    391606080 2018-01-21
# 31   ASMR Darling 2014-12-10      2136346    391606080 2018-01-16
# 32   ASMR Darling 2014-12-10      2136346    391606080 2018-01-01
# 33   ASMR Darling 2014-12-10      2136346    391606080 2017-12-06
# 34   ASMR Darling 2014-12-10      2136346    391606080 2017-11-22
# 35   ASMR Darling 2014-12-10      2136346    391606080 2017-11-19
# 36   ASMR Darling 2014-12-10      2136346    391606080 2017-10-30
# 37   ASMR Darling 2014-12-10      2136346    391606080 2017-10-28
# 38   ASMR Darling 2014-12-10      2136346    391606080 2017-10-24
# 39   ASMR Darling 2014-12-10      2136346    391606080 2017-10-18
# 40   ASMR Darling 2014-12-10      2136346    391606080 2017-10-14
# 41   ASMR Darling 2014-12-10      2136346    391606080 2017-10-10
# 42   ASMR Darling 2014-12-10      2136346    391606080 2017-10-06
# 43   ASMR Darling 2014-12-10      2136346    391606080 2017-10-03
# 44   ASMR Darling 2014-12-10      2136346    391606080 2017-09-27
# 45   ASMR Darling 2014-12-10      2136346    391606080 2017-09-22
# 46   ASMR Darling 2014-12-10      2136346    391606080 2017-09-19
# 47   ASMR Darling 2014-12-10      2136346    391606080 2017-09-11
# 48   ASMR Darling 2014-12-10      2136346    391606080 2017-09-10
# 49   ASMR Darling 2014-12-10      2136346    391606080 2017-09-02
# 50   ASMR Darling 2014-12-10      2136346    391606080 2017-08-28
# 51   ASMR Darling 2014-12-10      2136346    391606080 2017-08-24
# 52   ASMR Darling 2014-12-10      2136346    391606080 2017-08-21
# 53   ASMR Darling 2014-12-10      2136346    391606080 2017-08-18
# 54   ASMR Darling 2014-12-10      2136346    391606080 2017-08-15
# 55   ASMR Darling 2014-12-10      2136346    391606080 2017-08-08
# 56   ASMR Darling 2014-12-10      2136346    391606080 2017-08-03
# 57   ASMR Darling 2014-12-10      2136346    391606080 2017-07-25
# 58   ASMR Darling 2014-12-10      2136346    391606080 2017-07-21
# 59   ASMR Darling 2014-12-10      2136346    391606080 2017-07-18
# 60   ASMR Darling 2014-12-10      2136346    391606080 2017-07-15
# 61   ASMR Darling 2014-12-10      2136346    391606080 2017-07-11
# 62   ASMR Darling 2014-12-10      2136346    391606080 2017-07-06
# 63   ASMR Darling 2014-12-10      2136346    391606080 2017-07-04
# 64   ASMR Darling 2014-12-10      2136346    391606080 2017-06-29
# 65   ASMR Darling 2014-12-10      2136346    391606080 2017-06-27
# 66   ASMR Darling 2014-12-10      2136346    391606080 2017-06-19
# 67   ASMR Darling 2014-12-10      2136346    391606080 2017-06-14
# 68   ASMR Darling 2014-12-10      2136346    391606080 2017-06-12
# 69   ASMR Darling 2014-12-10      2136346    391606080 2017-06-06
# 70   ASMR Darling 2014-12-10      2136346    391606080 2017-06-01
# 71   ASMR Darling 2014-12-10      2136346    391606080 2017-05-29
# 72   ASMR Darling 2014-12-10      2136346    391606080 2017-05-09
# 73   ASMR Darling 2014-12-10      2136346    391606080 2017-05-04
# 74   ASMR Darling 2014-12-10      2136346    391606080 2017-04-27
# 75   ASMR Darling 2014-12-10      2136346    391606080 2017-04-24
# 76   ASMR Darling 2014-12-10      2136346    391606080 2017-04-19
# 77   ASMR Darling 2014-12-10      2136346    391606080 2017-04-06
# 78   ASMR Darling 2014-12-10      2136346    391606080 2017-04-03
# 79   ASMR Darling 2014-12-10      2136346    391606080 2017-03-30
# 80   ASMR Darling 2014-12-10      2136346    391606080 2017-03-24
# 81   ASMR Darling 2014-12-10      2136346    391606080 2017-03-21
# 82   ASMR Darling 2014-12-10      2136346    391606080 2017-03-15
# 83   ASMR Darling 2014-12-10      2136346    391606080 2017-03-12
# 84   ASMR Darling 2014-12-10      2136346    391606080 2017-03-09
# 85   ASMR Darling 2014-12-10      2136346    391606080 2017-03-07
# 86   ASMR Darling 2014-12-10      2136346    391606080 2017-03-04
# 87   ASMR Darling 2014-12-10      2136346    391606080 2017-03-02
# 88   ASMR Darling 2014-12-10      2136346    391606080 2017-02-27
# 89   ASMR Darling 2014-12-10      2136346    391606080 2017-02-26
# 90   ASMR Darling 2014-12-10      2136346    391606080 2017-02-25
# 91   ASMR Darling 2014-12-10      2136346    391606080 2017-02-19
# 92   ASMR Darling 2014-12-10      2136346    391606080 2017-02-14
# 93   ASMR Darling 2014-12-10      2136346    391606080 2017-02-09
# 94   ASMR Darling 2014-12-10      2136346    391606080 2017-02-07
# 95   ASMR Darling 2014-12-10      2136346    391606080 2017-01-24
# 96   ASMR Darling 2014-12-10      2136346    391606080 2017-01-21
# 97   ASMR Darling 2014-12-10      2136346    391606080 2017-01-12
# 98   ASMR Darling 2014-12-10      2136346    391606080 2017-01-07
# 99   ASMR Darling 2014-12-10      2136346    391606080 2016-12-28
# 100  ASMR Darling 2014-12-10      2136346    391606080 2016-12-22
# 101  ASMR Darling 2014-12-10      2136346    391606080 2016-12-19
# 102  ASMR Darling 2014-12-10      2136346    391606080 2016-12-16
# 103  ASMR Darling 2014-12-10      2136346    391606080 2016-12-13
# 104  ASMR Darling 2014-12-10      2136346    391606080 2016-12-03
# 105  ASMR Darling 2014-12-10      2136346    391606080 2016-11-22
# 106  ASMR Darling 2014-12-10      2136346    391606080 2016-11-19
# 107  ASMR Darling 2014-12-10      2136346    391606080 2016-11-18
# 108  ASMR Darling 2014-12-10      2136346    391606080 2016-11-04
# 109  ASMR Darling 2014-12-10      2136346    391606080 2016-10-24
# 110  ASMR Darling 2014-12-10      2136346    391606080 2016-10-21
# 111  ASMR Darling 2014-12-10      2136346    391606080 2016-10-18
# 112  ASMR Darling 2014-12-10      2136346    391606080 2016-09-26
# 113  ASMR Darling 2014-12-10      2136346    391606080 2016-09-24
# 114  ASMR Darling 2014-12-10      2136346    391606080 2016-09-16
# 115  ASMR Darling 2014-12-10      2136346    391606080 2016-09-16
# 116  ASMR Darling 2014-12-10      2136346    391606080 2016-09-06
# 117  ASMR Darling 2014-12-10      2136346    391606080 2016-08-30
# 118  ASMR Darling 2014-12-10      2136346    391606080 2016-08-25
# 119  ASMR Darling 2014-12-10      2136346    391606080 2016-08-17
# 120  ASMR Darling 2014-12-10      2136346    391606080 2016-08-16
# 121  ASMR Darling 2014-12-10      2136346    391606080 2016-08-15
# 122  ASMR Darling 2014-12-10      2136346    391606080 2016-08-12
# 123  ASMR Darling 2014-12-10      2136346    391606080 2016-07-19
# 124  ASMR Darling 2014-12-10      2136346    391606080 2016-06-25
# 125  ASMR Darling 2014-12-10      2136346    391606080 2016-06-24
# 126  ASMR Darling 2014-12-10      2136346    391606080 2016-06-23
# 127  ASMR Darling 2014-12-10      2136346    391606080 2016-05-27
# 128  ASMR Darling 2014-12-10      2136346    391606080 2016-05-10
# 129  ASMR Darling 2014-12-10      2136346    391606080 2016-04-30
# 130  ASMR Darling 2014-12-10      2136346    391606080 2016-04-27
# 131  ASMR Darling 2014-12-10      2136346    391606080 2016-04-17
# 132  ASMR Darling 2014-12-10      2136346    391606080 2016-04-11
# 133  ASMR Darling 2014-12-10      2136346    391606080 2016-04-07
# 134  ASMR Darling 2014-12-10      2136346    391606080 2016-04-02
# 135  ASMR Darling 2014-12-10      2136346    391606080 2016-03-31
# 136  ASMR Darling 2014-12-10      2136346    391606080 2016-03-30
# 137  ASMR Darling 2014-12-10      2136346    391606080 2016-03-29
# 138  ASMR Darling 2014-12-10      2136346    391606080 2016-03-27
# 139  ASMR Darling 2014-12-10      2136346    391606080 2016-03-26
# 140  ASMR Darling 2014-12-10      2136346    391606080 2016-03-26
# 141  ASMR Darling 2014-12-10      2136346    391606080 2016-03-25
# 142  ASMR Darling 2014-12-10      2136346    391606080 2016-03-23
# 143  ASMR Darling 2014-12-10      2136346    391606080 2016-03-19
# 144  ASMR Darling 2014-12-10      2136346    391606080 2016-03-14
# 145  ASMR Darling 2014-12-10      2136346    391606080 2016-03-13
# 146  ASMR Darling 2014-12-10      2136346    391606080 2016-03-12
#
#                                                  Title        Category  \
# 0    ASMR Brushing You To Sleep - Brushing, Hand Mo...   Entertainment
# 1           ASMR Relaxing Triggers to Help You Sleep ♥   Entertainment
# 2                ASMR Crazy Flora the Florist Roleplay   Entertainment
# 3    ASMR Reacting and Recreating My First Video - ...   Entertainment
# 4        ASMR Purple Triggers 💜 Tapping and Scratching   Entertainment
# 5    ASMR Relaxing Haircut ♥ Shampoo & Condition, S...   Entertainment
# 6                                  ASMR Sephora Haul ♥   Entertainment
# 7    ASMR My Morning Skin Care Routine ✨ Applied On...   Entertainment
# 8                   ASMR Choose Your Dream - The Cloud   Entertainment
# 9                                 ASMR 90's Triggers ♥   Entertainment
# 10       ASMR Most Hated Triggers with B*tchy Brittney   Entertainment
# 11    ASMR Tiny Trigger Test (Lo-fi, Mini Microphones)   Entertainment
# 12                          ASMR Most Loved Triggers ♥   Entertainment
# 13              ASMR Relaxing Close-Up Face Touching ♥   Entertainment
# 14    ASMR 1950's Drive In Movie Theater Date Roleplay   Entertainment
# 15                  ASMR Whispered Fortnite Gameplay ♥   Entertainment
# 16            ASMR Guess The Trigger to Help You Sleep   Entertainment
# 17     ASMR Microphone Brushing with Different Brushes   Entertainment
# 18                           ASMR Painting Your Face ♥   Entertainment
# 19                            ASMR Magnetic Zen Garden   Entertainment
# 20           ASMR Personal Attention To Help You Sleep   Entertainment
# 21    ASMR White Triggers ☁️ Tapping and Scratching ☁️   Entertainment
# 22                  ASMR Arya ♥ Puppy Love and Petting   Entertainment
# 23                                   ASMR Trigger Test   Entertainment
# 24                      ASMR Prom Makeup and Dresses ♥   Entertainment
# 25                           ASMR Dreamy Scalp Massage   Entertainment
# 26                               ASMR Sketching You ✏️   Entertainment
# 27                       ASMR Triggers With Tiny Hands   Entertainment
# 28                  ASMR Girlfriends Valentine's Day 💋   Entertainment
# 29      ASMR Red Triggers ❤️ Tapping and Scratching ❤️   Entertainment
# 30                 ASMR My Makeup Routine (No Talking)   Entertainment
# 31     ASMR Lushful Spa Treatment ✨ Facial and Massage   Entertainment
# 32   ASMR Secret Santa Unboxing (Tapping, Relaxing ...   Entertainment
# 33                        ASMR Putting You To Sleep 💤✨   Entertainment
# 34                    ASMR Measuring You For No Reason   Entertainment
# 35      ASMR Brushing Your Face With Different Objects   Entertainment
# 36   ASMR Halloween Makeup Roleplay ft. B*tchy Brit...   Entertainment
# 37        ASMR Relaxing Super Mario Odyssey Gameplay ♥   Entertainment
# 38              ASMR Stranger Things - Eleven Roleplay   Entertainment
# 39   ASMR Gaming - Super Mario 3 - Nostalgic Tingles ♥   Entertainment
# 40       ASMR Blue Triggers 💤 Tapping and Scratching 💤   Entertainment
# 41                    ASMR Picnic and Cloud Watching ♥   Entertainment
# 42                      The Struggles of Watching ASMR   Entertainment
# 43   ASMR Sleepover Roleplay ♥ Spa, Makeup, Popcorn...   Entertainment
# 44                        I'M IN CALIFORNIA! [nonASMR]   Entertainment
# 45   ASMR Scary Storytime - Sleep Paralysis - How t...   Entertainment
# 46   ASMR B*tchy Brittney Barista - Starbucks Roleplay   Entertainment
# 47   ASMR During A Hurricane (Comforting You Roleplay)   Entertainment
# 48     ASMR 100 Triggers To Help You Sleep ♥ (4 HOURS)   Entertainment
# 49                          ASMR Hurricane Harvey Help   Entertainment
# 50                             ASMR The Eyes Never Lie   Entertainment
# 51               ASMR Hair Stylist - Styling Your Hair   Entertainment
# 52                            ASMR Tuning My Ukulele ♥   Entertainment
# 53             ASMR School Nurse - First Day of School   Entertainment
# 54   ASMR Drawing Features On Your Face - The Face ...   Entertainment
# 55                    ASMR THE BEST SLIME IN THE WORLD   Entertainment
# 56               ASMR Tapping on Things From Jamaica ♥   Entertainment
# 57                ASMR 20 Triggers To Help You Sleep ♥   Entertainment
# 58          ASMR Doing My Makeup ♥  Get Ready With Me!   Entertainment
# 59   ASMR Gaming - Legend of Zelda: Breath of the W...   Entertainment
# 60   ASMR Game of Thrones Roleplay: Daenerys Targar...   Entertainment
# 61       ASMR Pink Triggers 🌸 Tapping and Scratching 🌸   Entertainment
# 62                            ASMR Light-Up Triggers ✨   Entertainment
# 63               ASMR Modern Video Game Store Roleplay   Entertainment
# 64                        ASMR Blackhead Removal Spa ♥   Entertainment
# 65                            ASMR Doing Your Makeup ♥   Entertainment
# 66   ASMR Relaxing Mouth Sounds and Hand Movements ...   Entertainment
# 67   ASMR 1 HOUR of Watercolor Painting During A Ra...   Entertainment
# 68    ASMR Whispering To My Flute - Songs From Movies!   Entertainment
# 69   ASMR Relaxing Head Massage ♥ Face and Scalp Ma...   Entertainment
# 70            ASMR Cooking Breakfast For You! Roleplay   Entertainment
# 71                 ASMR Painting Your Nails Roleplay ♥   Entertainment
# 72                       ASMR Tangles For Your Tingles   Entertainment
# 73                 ASMR Whispered Summer Clothing Haul   Entertainment
# 74                 ASMR 90's Video Game Store Roleplay   Entertainment
# 75                               ASMR Cleaning My Room   Entertainment
# 76   ASMR What's In My Makeup Bag? Tapping and Brus...   Entertainment
# 77                              ASMR Stargazing Date ♥   Entertainment
# 78                  ASMR Doctor Roleplay - Yearly Exam   Entertainment
# 79           Polaroid ASMR - Let Me Take Your Picture!   Entertainment
# 80           Ask Me Anything! ASMR Reddit ANNOUNCEMENT   Entertainment
# 81   ASMR Intense Microphone Scratching - Weird Hou...   Entertainment
# 82            ASMR Beauty and the Beast BELLE Roleplay   Entertainment
# 83     ASMR A-Z Triggers to Help You Sleep ♥ (2 HOURS)   Entertainment
# 84    ASMR B*tchy Brittney Does Your Makeup (Roleplay)   Entertainment
# 85          ASMR Ear Cleaning and Ear Massage Roleplay   Entertainment
# 86                        ASMR Unboxing Pop Microphone   Entertainment
# 87              ASMR Happy Birthday To You! ASMR Party   Entertainment
# 88   7 Struggles ASMRtists Deal With (with a little...   Entertainment
# 89             ASMR Intense Face Massage with Brushing   Entertainment
# 90                                       What is ASMR?   Entertainment
# 91           ASMR Unboxing Collab with MinxLaura123 ❤️   Entertainment
# 92                     ASMR Valentine's Day Triggers ♥   Entertainment
# 93           ASMR Tapping and Scratching Spectacular ♥   Entertainment
# 94   ASMR Wendy Darling Helps You Fall Asleep Roleplay   Entertainment
# 95   LIFE UPDATE.. I GOT A JOB ON A TV SHOW! (nonASMR)   Entertainment
# 96   ASMR Relaxing Hair Play, Brushing, and Scalp M...   Entertainment
# 97                           ASMR Gaming - Battlefront   Entertainment
# 98             ASMR Tweezing and Styling Your Eyebrows   Entertainment
# 99   ASMR Brushing the Microphone With Different Br...   Entertainment
# 100        ASMR Building a Beautiful Gingerbread House   Entertainment
# 101               ASMR Decorating OUR Christmas Tree 🎄   Entertainment
# 102                            ASMR Haircut Roleplay ♥   Entertainment
# 103      Candid ASMR - Makeup Application (No Talking)   Entertainment
# 104                 ASMR Tapping Christmas Decorations   Entertainment
# 105  ASMR Close Up Personal Attention For You To Sl...   Entertainment
# 106             ASMR Reacting to Other ASMRtists' ASMR   Entertainment
# 107             ASMR Whispering and Tapping LIVESTREAM  People & Blogs
# 108              ASMR Whispered Tapping and Scratching   Entertainment
# 109                     ASMR Halloween Makeup Roleplay   Entertainment
# 110                      ASMR Whispered Fashion Haul ♥   Entertainment
# 111  ASMR Ear to Ear Kisses, Sk's, Ts's, and Tk's (...   Entertainment
# 112                  ASMR Whispered New Channel Update   Entertainment
# 113          ASMR Best Friend Bubbly Makeup Roleplay ♥   Entertainment
# 114               ASMR How I Calm Down From a Bad Mood   Entertainment
# 115  ASMR Eating Chick-fil-a BREAKFAST 200K CELEBRA...   Entertainment
# 116                            ASMR Loving Dog Petting   Entertainment
# 117  ASMR - What Do My Friends and Family Think of ...   Entertainment
# 118                      ASMR Relaxing Scalp Massage ♥   Entertainment
# 119                            Question & Answer Time!   Entertainment
# 120                    Ask Me Thy Questions (non ASMR)   Entertainment
# 121               ASMR 10 Triggers to Help You Sleep ♥   Entertainment
# 122                ASMR The Ultimate Spa Day! (Unisex)   Entertainment
# 123                                     Livestream Q&A   Entertainment
# 124  ASMR Whispered Tour of My Room (visual ASMR/vo...  People & Blogs
# 125          ASMR Soft Spoken DARK Story Time (Part 1)  People & Blogs
# 126  ASMR Helping You Fall Asleep In Bed Friend Rol...  People & Blogs
# 127        TAY AND ROSCOE IN LOVE... Update (NOT ASMR)  People & Blogs
# 128            ASMR Unboxing New Microphone! Blue Yeti  People & Blogs
# 129  ASMR Eating Chick-fil-a Celebration (50K SUBSC...  People & Blogs
# 130              ASMR LONG HAIR Brushing and Hair Play  People & Blogs
# 131                     ASMR Cranial Nerve Examination  People & Blogs
# 132  Color With Me! ASMR 1 HOUR of Relaxing Story T...  People & Blogs
# 133  Star Wars: The Force Awakens ASMR Rey Wounded ...  People & Blogs
# 134  Star Wars: The Force Awakens ASMR REY Hair & M...  People & Blogs
# 135  ASMR LOTS of Inaudible Whisper, Sking&Tking, K...  People & Blogs
# 136  ASMR Tapping Random Objects & Discussing ASMR ...  People & Blogs
# 137  ASMR Get Ready With Me!.. Whispered Bubbly Mak...  People & Blogs
# 138               Answering Your Questions! (NOT ASMR)  People & Blogs
# 139                   ASMR Whispered Ask Me Questions!  People & Blogs
# 140                          ASMR Men's Shave Roleplay  People & Blogs
# 141      ASMR At Home Whispered Doctor Visit Roleplay!  People & Blogs
# 142  Study With Me! ASMR with Inaudible Whispers, P...  People & Blogs
# 143             ASMR Whispered Unisex Haircut Roleplay  People & Blogs
# 144                    ASMR Whispered Match Lighting 🔥  People & Blogs
# 145                   ASMR Curling Our Hair Roleplay!!  People & Blogs
# 146             ASMR Whispered Bubbly Makeup Roleplay.  People & Blogs
#
#         Views   Likes  Dislikes                                          URL
# 0      918169   22381       671  https://www.youtube.com/watch?v=9Cz9_49Pcv4
# 1     2806381   47677      2276  https://www.youtube.com/watch?v=wGL-e6eC6AY
# 2      368798   11612      1739  https://www.youtube.com/watch?v=5gXmiZQYu8g
# 3      627596   21844       569  https://www.youtube.com/watch?v=tWQ83SwP9Do
# 4     1484205   29643      1892  https://www.youtube.com/watch?v=6M0MbrjXmxI
# 5     2468560   37235      2544  https://www.youtube.com/watch?v=prghVaRUIcA
# 6     1343770   28202       918  https://www.youtube.com/watch?v=774-t1TgRac
# 7      978358   21536       570  https://www.youtube.com/watch?v=cnXtQDnFhfE
# 8     1787727   44482      1509  https://www.youtube.com/watch?v=75vm5REJnXQ
# 9      659537   17989       412  https://www.youtube.com/watch?v=_E6ONFQ-Dp0
# 10    1854425   43248      2812  https://www.youtube.com/watch?v=JoIgppFZ-Iw
# 11     927706   23774       724  https://www.youtube.com/watch?v=5QpZia62Vno
# 12    1950304   37787      1298  https://www.youtube.com/watch?v=At4JDrtw8_8
# 13     926888   19866       904  https://www.youtube.com/watch?v=7oBM4lZKejk
# 14     941488   25249      1052  https://www.youtube.com/watch?v=uIJ905p9O7Y
# 15    1661967   37653      4149  https://www.youtube.com/watch?v=zhGLmvSBWns
# 16    1234085   25151       654  https://www.youtube.com/watch?v=qHAMzTHG3_g
# 17    1412655   29632       731  https://www.youtube.com/watch?v=JAZTcpADZRc
# 18    1304468   24830       694  https://www.youtube.com/watch?v=MhmD-7pTlvI
# 19    1339720   30388      1003  https://www.youtube.com/watch?v=z_M_2yBf824
# 20    3473682   47227      1612  https://www.youtube.com/watch?v=Hffn3vYJq80
# 21    1353630   26711       802  https://www.youtube.com/watch?v=rh8kDNahyr0
# 22     574544   22502       436  https://www.youtube.com/watch?v=wN9fuxw-Dq0
# 23    2450051   40227      1834  https://www.youtube.com/watch?v=lm1zvnsSl8E
# 24    1699068   30219      1063  https://www.youtube.com/watch?v=PcOWzl2zZ-Q
# 25    3293698   43435      2932  https://www.youtube.com/watch?v=KlGKuVLf5hM
# 26    1579373   30774      1063  https://www.youtube.com/watch?v=lWIKOErglTE
# 27    1011190   24451      1599  https://www.youtube.com/watch?v=uQBf9wd6e8I
# 28    1213486   27469       977  https://www.youtube.com/watch?v=x1YgxwIRlj0
# 29    1482704   30556       818  https://www.youtube.com/watch?v=YWnhIjG3hEg
# 30    3229729   53234      3574  https://www.youtube.com/watch?v=3Cp6WYC8QaE
# 31    4981425   64104      3562  https://www.youtube.com/watch?v=0eUk_VN3e2A
# 32    1223359   28228      1057  https://www.youtube.com/watch?v=qXwdbJYqDao
# 33    7269236   78801      4886  https://www.youtube.com/watch?v=JdWb-cIwfJ4
# 34    1954006   29755       996  https://www.youtube.com/watch?v=wvjCfM7jeZM
# 35    1318142   29507       808  https://www.youtube.com/watch?v=K9xOH1_hJ_g
# 36    1319113   27560      1021  https://www.youtube.com/watch?v=dpLHqPkuR9Y
# 37    1341775   23515       950  https://www.youtube.com/watch?v=zp-Kubjffhs
# 38     863649   19513      1821  https://www.youtube.com/watch?v=nDpB9sa8bmk
# 39    1926067   35248      1417  https://www.youtube.com/watch?v=dEB36036VmE
# 40    2405180   36599      1135  https://www.youtube.com/watch?v=nIRv1hvDecY
# 41     916816   22047       621  https://www.youtube.com/watch?v=HXLOufY4HPA
# 42    2969647  107605      4120  https://www.youtube.com/watch?v=oZlJZ0BhXsA
# 43    3475316   48607      1745  https://www.youtube.com/watch?v=1Wwoca2DVU4
# 44     541991   17955       284  https://www.youtube.com/watch?v=JlndAKOYDUQ
# 45     887095   21171       539  https://www.youtube.com/watch?v=KnthjyYsk-8
# 46    2201897   45372      2932  https://www.youtube.com/watch?v=r6crhFjPphM
# 47    1415015   36838       953  https://www.youtube.com/watch?v=cRZD846-1F8
# 48   18727029  255882     17720  https://www.youtube.com/watch?v=eLjSyI8bNfk
# 49     650361   19893       831  https://www.youtube.com/watch?v=qEtHdZbjo0Q
# 50    1142746   22973       927  https://www.youtube.com/watch?v=CHj3939Bm2A
# 51    3835142   49239      1945  https://www.youtube.com/watch?v=IDL-ZKqdAXE
# 52     629845   15828      1729  https://www.youtube.com/watch?v=iOPjs-4-ZGg
# 53    4303761   49656      2997  https://www.youtube.com/watch?v=aUHyjgxXjzg
# 54    6644866   70271      3278  https://www.youtube.com/watch?v=G2O1UFiKHZI
# 55    2698340   48154      2164  https://www.youtube.com/watch?v=edWU-TfHekg
# 56    1015965   19872       688  https://www.youtube.com/watch?v=EOwbfGMLBCs
# 57   28765108  293777     29737  https://www.youtube.com/watch?v=DaXwnTk0hUE
# 58    1889966   28842      1230  https://www.youtube.com/watch?v=Da1vjWgs3o4
# 59    1411395   20557      1059  https://www.youtube.com/watch?v=0G9noApJ1V8
# 60     856520   15796      1519  https://www.youtube.com/watch?v=7Pk8oYEvJFA
# 61    2071311   36785      1147  https://www.youtube.com/watch?v=ImcwkIYrh4s
# 62    1050846   21380       852  https://www.youtube.com/watch?v=a4SqByQ3LTI
# 63    3677707   45466      2885  https://www.youtube.com/watch?v=GvNnK03Vcw0
# 64    2285585   32174      1369  https://www.youtube.com/watch?v=Hqfl2ftiy9A
# 65    6172845   70240      4085  https://www.youtube.com/watch?v=CkimIaCVVGU
# 66    1377205   20786      1143  https://www.youtube.com/watch?v=WfXr1CYg6_4
# 67    1124353   17152       976  https://www.youtube.com/watch?v=W9oj9E3Fq7U
# 68    1104387   23284      1503  https://www.youtube.com/watch?v=Me7LheXveoM
# 69    6889158   64543      3199  https://www.youtube.com/watch?v=zltEvQK03Hs
# 70    2248385   36320      1541  https://www.youtube.com/watch?v=JEdMVhklJHk
# 71    1806036   30550      1294  https://www.youtube.com/watch?v=davWeF4JFsU
# 72    1475633   26325      1102  https://www.youtube.com/watch?v=jTmrbZFHNpk
# 73    1156372   19587       653  https://www.youtube.com/watch?v=3BYlKZvuOA8
# 74    4181795   49680      2573  https://www.youtube.com/watch?v=JKIZjXkmmco
# 75    2070127   32208      2258  https://www.youtube.com/watch?v=0iNQJ57YGBM
# 76    2101707   30344      1117  https://www.youtube.com/watch?v=zj6X2U5OBhY
# 77    1020859   17100       656  https://www.youtube.com/watch?v=Bj8zSqSIjFU
# 78    6151710   56720      2862  https://www.youtube.com/watch?v=8hkGXGZZJpg
# 79    1367711   23529       956  https://www.youtube.com/watch?v=KqGhjUPfGx0
# 80     272213    6470       220  https://www.youtube.com/watch?v=qBuCoRX0_KQ
# 81    2371640   35219      1600  https://www.youtube.com/watch?v=qo_Chxia4J0
# 82     680844   13027       514  https://www.youtube.com/watch?v=mDyoF1lqieE
# 83   22661630  116106     17453  https://www.youtube.com/watch?v=JeuriGzAnSI
# 84    2873301   48301      2674  https://www.youtube.com/watch?v=1AVF4uSL5bE
# 85    2649753   30196      1122  https://www.youtube.com/watch?v=DGaNjktn-vs
# 86    1260926   24462       676  https://www.youtube.com/watch?v=fTxWDsnEVxI
# 87    1026497   21587       712  https://www.youtube.com/watch?v=1tAplfMTREQ
# 88    3749712  106356      1778  https://www.youtube.com/watch?v=wqIDSINFgM8
# 89    1430878   22276      1264  https://www.youtube.com/watch?v=_eAywtNg4EY
# 90    2936140   29546      3592  https://www.youtube.com/watch?v=qAEM95ixp-s
# 91     361786    8091       257  https://www.youtube.com/watch?v=Sxanem07pO0
# 92     860306   18479       753  https://www.youtube.com/watch?v=YDRkXBSANyg
# 93    2623422   39006      1361  https://www.youtube.com/watch?v=Ov2O7Yw5CLI
# 94    1089763   19482       570  https://www.youtube.com/watch?v=4TAhGTU5l4s
# 95    1116068   34794       646  https://www.youtube.com/watch?v=82j-wrDT8-g
# 96    4954304   55842      1855  https://www.youtube.com/watch?v=By3HgtiAUUw
# 97    1894198   38821      1955  https://www.youtube.com/watch?v=930mJDCZKfw
# 98    1558022   22642       766  https://www.youtube.com/watch?v=ufVJFRRva54
# 99    7250580   87571      3745  https://www.youtube.com/watch?v=WX6SPJxurLo
# 100   1050470   19535       976  https://www.youtube.com/watch?v=vE7pTSuw8vg
# 101    526712   11053       281  https://www.youtube.com/watch?v=OBnnVb3MWWE
# 102   4198872   40311      2221  https://www.youtube.com/watch?v=-k2vi4A4OuQ
# 103    522933    9205       355  https://www.youtube.com/watch?v=4ivUbv7ZBGE
# 104   1048258   20830       599  https://www.youtube.com/watch?v=p5giMvXmfp0
# 105  10645925   87096      4292  https://www.youtube.com/watch?v=PHu5p8dpxk8
# 106   1302413   23250       778  https://www.youtube.com/watch?v=fCp2G-wHUic
# 107    572228   11503       441  https://www.youtube.com/watch?v=Z6y8Cb45Bpw
# 108  10866947  101092      6179  https://www.youtube.com/watch?v=vwnLdjhQ0b0
# 109   1577456   21407       876  https://www.youtube.com/watch?v=E8rzym0YJw4
# 110   2666210   31461      1233  https://www.youtube.com/watch?v=zkW-64uzEGw
# 111   1625547   20122      1591  https://www.youtube.com/watch?v=8M-EmeE_HDg
# 112    315363    4761       130  https://www.youtube.com/watch?v=dmV4YUOHRAA
# 113   1275075   17834       740  https://www.youtube.com/watch?v=-EAJmQAMVG0
# 114    570731   11704       332  https://www.youtube.com/watch?v=XN38W3PaY9U
# 115   2673610   32456      2772  https://www.youtube.com/watch?v=a8udFXUGvOs
# 116    334256    6211       324  https://www.youtube.com/watch?v=r9iIS-ipC3E
# 117   1422200   34752       737  https://www.youtube.com/watch?v=QBSUJzVkZhM
# 118  12208239   94002      6437  https://www.youtube.com/watch?v=HZ4PLgct3Og
# 119    411374    7864       140  https://www.youtube.com/watch?v=yD1vngFG9y0
# 120    183439    3821        68  https://www.youtube.com/watch?v=FaMNJYthXjQ
# 121  29097774  300430     33135  https://www.youtube.com/watch?v=_RjhsY06mOI
# 122   1294265   14844       665  https://www.youtube.com/watch?v=8ke6aRN98JA
# 123    201837    3227       168  https://www.youtube.com/watch?v=7UwnXzflFlE
# 124   1573044   16825       668  https://www.youtube.com/watch?v=10omMBSTvCg
# 125    237789    3932       111  https://www.youtube.com/watch?v=2dZwFCYQWqM
# 126   6795431   51688      2918  https://www.youtube.com/watch?v=1wh8f-b6Tys
# 127    302428    5797       180  https://www.youtube.com/watch?v=AIcRcqRqQFU
# 128    419188    5487       313  https://www.youtube.com/watch?v=RvjpUbDe3f8
# 129   1567526   19395      1712  https://www.youtube.com/watch?v=wsgyIptFtn0
# 130   1294866   14181       817  https://www.youtube.com/watch?v=AjjRob97Iko
# 131   5891421   43832      2993  https://www.youtube.com/watch?v=JjvWAdGF0S0
# 132   3900771   27972      3013  https://www.youtube.com/watch?v=g7rDjiyUUEM
# 133    434795    6231       233  https://www.youtube.com/watch?v=k39O-l-7f6A
# 134    668395    7046       517  https://www.youtube.com/watch?v=t5iPKy5DdBA
# 135   1593743   14543       955  https://www.youtube.com/watch?v=V1Li4WVNp-U
# 136    600758    8370       248  https://www.youtube.com/watch?v=ZOzLeSarR-c
# 137   1382249   13378       803  https://www.youtube.com/watch?v=lAsC8rCMpXg
# 138    959654   20091       464  https://www.youtube.com/watch?v=dJA2BVijU5s
# 139    148524    2212        84  https://www.youtube.com/watch?v=MeWePeWQKgk
# 140   2209445   20120      2370  https://www.youtube.com/watch?v=430Gm_vBZvw
# 141   1074549   10152       590  https://www.youtube.com/watch?v=eqElJprZcPQ
# 142   1012344   11702       661  https://www.youtube.com/watch?v=FmM9DV1DKVE
# 143   1098443   10427       510  https://www.youtube.com/watch?v=uQw46snlTRk
# 144    224425    3474       123  https://www.youtube.com/watch?v=C8WLiTD8tXQ
# 145    331205    4539       148  https://www.youtube.com/watch?v=waVp-2_W4ac
# 146    423339    7077       294  https://www.youtube.com/watch?v=9WckzJYfCFU
