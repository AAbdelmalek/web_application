# %%
# To do:
# Fix Dates, must be another published on vs premiered on discrepancy -- OK
# Fix Titles -- OK
# Looks like missing one (1) video for Gibi 344/345 -- OK
# DUPLICATES -- OK
# User entered date range --
# Better commenting --
# Duration --

# Import Dependencies
from bs4 import BeautifulSoup as bs
import requests
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
pd.set_option('display.max_rows', 500)

# %%
converted_date = ""
raw_months = {"Jan": 1, "Feb": 2, "Mar" : 3, "Apr" : 4, 
              "May" : 5, "Jun" : 6, "Jul" : 7, "Aug" : 8,
              "Sep" : 9, "Oct" : 10, "Nov" : 11, "Dec" : 12}

# Convert Date from Jan 1, 1999 format to datetime object
def convertDate(raw_date):
    
    converted_date = ""
    
    number_month = raw_months.get(raw_date[0])
    
    date_str = (str(number_month) + "/" + raw_date[1] + "/" + raw_date[2]).replace(",", "")
    
    converted_date = datetime.strptime(date_str, '%m/%d/%Y')
    
    return converted_date

# %%
# Get Youtuber's Name
input_name = input("Enter Youtuber's Name: ")

list_name = input_name.split()

converted_name = input_name

if len(list_name) > 1:
    
    converted_name = ""
    
    for i in range(len(list_name)):

        converted_name = converted_name + list_name[i]
        
        if i != len(list_name)-1:
            converted_name = converted_name + "+"

search_name = converted_name

start_url = "https://www.youtube.com/results?search_query=" + search_name
# Out:
# Enter Youtuber's Name: scenery

# %%
print(start_url)
get_youtube_url_response = requests.get(start_url)
# Out:
# https://www.youtube.com/results?search_query=scenery

# %%
youtube_name_soup = bs(get_youtube_url_response.text, "lxml")

# %%
raw_youtube_name_link = youtube_name_soup.find_all("div", class_="yt-lockup-byline")[0].a.get("href")

videos_link = "https://www.youtube.com" + raw_youtube_name_link + "/videos"

about_link = "https://www.youtube.com" + raw_youtube_name_link + "/about"

print(videos_link)
print(about_link)
# Out:
# https://www.youtube.com/user/LoungeVstudio/videos
# https://www.youtube.com/user/LoungeVstudio/about

# %%
# Get About Information
about_html = requests.get(about_link)

# Parse HTML
about_soup = bs(about_html.text, "lxml")

# %%
# Artist Information
artist_name = about_soup.find("meta", property="og:title").get("content")

subscribers = about_soup.find_all("span", class_="about-stat")[0].text
subscribers_int = int(subscribers.split(" ")[0].replace(",",""))

total_views = about_soup.find_all("span", class_="about-stat")[1].text
total_views_int = int(total_views[3:len(total_views)].split(" ")[0].replace(",",""))

joined = about_soup.find_all("span", class_="about-stat")[2].text
joined_temp = joined.split(" ")[1:4]
joined_convert = convertDate(joined_temp)

print(f"Artist: {artist_name}")
print(f"Subscribers: {subscribers_int}")
print(f"Views: {total_views_int}")
print(f"Joined: {joined_convert}")
# Out:
# Artist: LoungeV Films - Relaxing Music and Nature Sounds
# Subscribers: 277242
# Views: 111616587
# Joined: 2011-05-30 00:00:00

# %%
# Convert User Name to UU Format
youtube_code = raw_youtube_name_link.split("/")[2]

if youtube_code[0:2] == "UC":
    
    youtube_code = raw_youtube_name_link.split("/")[2]

    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:] 

elif youtube_code[0:2] != "UC":
    
    youtube_code_raw = about_soup.find("link", rel="canonical").get("href")
    
    youtube_code = youtube_code_raw.split("/")[4]
    
    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:]  
    

print(playlist_link)
# Out:
# https://www.youtube.com/playlist?list=UUyupwg56cb-DKlz8fg09Vbw

# %%
# Get Playlist Response
playlist_response = requests.get(playlist_link)

# %%
# Create Playlist Soup Object
playlist_soup = bs(playlist_response.text, 'lxml')

# %%
# Get First Video URL as Starting Point
first_video = "https://www.youtube.com" + playlist_soup.find_all("a", class_="pl-video-title-link")[0].get("href").split("&")[0]
first_video_within_playlist = first_video + "&" + playlist_link.split("?")[1]

print(first_video_within_playlist)
# Out:
# https://www.youtube.com/watch?v=EstNSjwpqE8&list=UUyupwg56cb-DKlz8fg09Vbw

# %%
# Create Soup Object for First Video Inside Playlist
playlist_inside_request = requests.get(first_video_within_playlist) 

playlist_inside_soup = bs(playlist_inside_request.text, "lxml")

# %%
urls_all = []
# urls_all.append(first_video)
i=0
total_videos_in_playlist = int(playlist_inside_soup.find("span", id="playlist-length").text.replace(" videos","").replace(",",""))
number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) 
last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
link_fix = "https://www.youtube.com" + last_shown_link
    
for i in range(total_videos_in_playlist):   

    if i == 0:
        
        print(f"loop1, i={i}")
        
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
        
        url = "https://www.youtube.com" + first_link.find_next("a").get("href")
        
        original_url = url.split("&")[0]

        urls_all.append(original_url)
        
        next_link = first_link
        
    elif i == last_video_index:

        print(f"loop2, i={i}------------------------------------------------")
        
        playlist_inside_request = requests.get(link_fix)
        
        playlist_inside_soup = bs(playlist_inside_request.text, "lxml")
        
        last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
        
        link_fix = "https://www.youtube.com" + last_shown_link
        
        last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
        
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i+1}\n    ")
        
        next_link = first_link
        
        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
        
        original_url = next_url.split("&")[0]
        
        urls_all.append(original_url)
        
        number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) - 1
              
    else:
        
        print(f"loop3, i={i}")
 
        if i == 1:
    
            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
        
        else:
        
            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ")

        next_link = first_link

        next_link = next_link.find_next("span", class_="index")

        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")

        original_url = next_url.split("&")[0]

        urls_all.append(original_url)
# Out:
# loop1, i=0
# loop3, i=1
# loop3, i=2
# loop3, i=3
# loop3, i=4
# loop3, i=5
# loop3, i=6
# loop3, i=7
# loop3, i=8
# loop3, i=9
# loop3, i=10
# loop3, i=11
# loop3, i=12
# loop3, i=13
# loop3, i=14
# loop3, i=15
# loop3, i=16
# loop3, i=17
# loop3, i=18
# loop3, i=19
# loop3, i=20
# loop3, i=21
# loop3, i=22
# loop3, i=23
# loop3, i=24
# loop3, i=25
# loop3, i=26
# loop3, i=27
# loop3, i=28
# loop3, i=29
# loop3, i=30
# loop3, i=31
# loop3, i=32
# loop3, i=33
# loop3, i=34
# loop3, i=35
# loop3, i=36
# loop3, i=37
# loop3, i=38
# loop3, i=39
# loop3, i=40
# loop3, i=41
# loop3, i=42
# loop3, i=43
# loop3, i=44
# loop3, i=45
# loop3, i=46
# loop3, i=47
# loop3, i=48
# loop3, i=49
# loop3, i=50
# loop3, i=51
# loop3, i=52
# loop3, i=53
# loop3, i=54
# loop3, i=55
# loop3, i=56
# loop3, i=57
# loop3, i=58
# loop3, i=59
# loop3, i=60
# loop3, i=61
# loop3, i=62
# loop3, i=63
# loop3, i=64
# loop3, i=65
# loop3, i=66
# loop3, i=67
# loop3, i=68
# loop3, i=69
# loop3, i=70
# loop3, i=71
# loop3, i=72
# loop3, i=73
# loop3, i=74
# loop3, i=75
# loop3, i=76
# loop3, i=77
# loop3, i=78
# loop2, i=79------------------------------------------------
# loop3, i=80
# loop3, i=81
# loop3, i=82
# loop3, i=83
# loop3, i=84
# loop3, i=85
# loop3, i=86
# loop3, i=87
# loop3, i=88
# loop3, i=89
# loop3, i=90
# loop3, i=91
# loop3, i=92
# loop3, i=93
# loop3, i=94
# loop3, i=95
# loop3, i=96
# loop3, i=97
# loop3, i=98
# loop3, i=99
# loop3, i=100
# loop3, i=101
# loop3, i=102
# loop3, i=103
# loop3, i=104
# loop3, i=105
# loop3, i=106
# loop3, i=107
# loop3, i=108
# loop3, i=109
# loop3, i=110
# loop3, i=111
# loop3, i=112
# loop3, i=113
# loop3, i=114
# loop3, i=115
# loop3, i=116
# loop3, i=117

# %%
# Going to Each Video and Extracting Data
published_on = []
raw_published_on = []
views = []
date = []
duration_videos = []
likes = []
dislikes = []
title_videos = []
categories = []

for i in range(len(urls_all)):
    
    video_url = urls_all[i]
    video_response = requests.get(video_url)
    video_soup = bs(video_response.text, 'lxml')
    
    # Title
    title = video_soup.find("title").text.replace(" - YouTube", "")
    title_videos.append(title)
    
    # Views
    string_views = video_soup.find("div", id="watch7-views-info").text.replace(" views\n\n\n\n\n", "").replace(",","") 
    int_views = int(string_views)
    views.append(int_views)
    
#     # Duration
#     duration = video_soup.find("span", class_="video-time").text
#     duration_videos.append(duration)
    
    # Likes
    string_likes = video_soup.find("button", title="I like this").text
    int_likes = int(string_likes.replace(",",""))
    likes.append(int_likes)
    
    # Dislikes
    string_dislikes = video_soup.find("button", title="I dislike this").text
    int_dislikes = int(string_dislikes.replace(",",""))
    dislikes.append(int_dislikes)
    
    # Publish Date
    raw_publish_date = video_soup.find("div", id="watch-uploader-info").text
    raw_published_on.append(raw_publish_date)
    
    # Handle All Raw Dates "Premiered", ""Published", "Streamed"
    publish_date_format = raw_publish_date.split(" ")[len(raw_publish_date.split(" "))-3:len(raw_publish_date.split(" "))]
    publish_date_convert = convertDate(publish_date_format)
    published_on.append(publish_date_convert)
    
    # Category
    category = video_soup.find("h4", class_="title", text="\n      Category\n    ").find_next("a").text
    categories.append(category)
    
    print(f"({i+1}/{len(urls_all)})")
# Out:
# (1/118)
# (2/118)
# (3/118)
# (4/118)
# (5/118)
# (6/118)
# (7/118)
# (8/118)
# (9/118)
# (10/118)
# (11/118)
# (12/118)
# (13/118)
# (14/118)
# (15/118)
# (16/118)
# (17/118)
# (18/118)
# (19/118)
# (20/118)
# (21/118)
# (22/118)
# (23/118)
# (24/118)
# (25/118)
# (26/118)
# (27/118)
# (28/118)
# (29/118)
# (30/118)
# (31/118)
# (32/118)
# (33/118)
# (34/118)
# (35/118)
# (36/118)
# (37/118)
# (38/118)
# (39/118)
# (40/118)
# (41/118)
# (42/118)
# (43/118)
# (44/118)
# (45/118)
# (46/118)
# (47/118)
# (48/118)
# (49/118)
# (50/118)
# (51/118)
# (52/118)
# (53/118)
# (54/118)
# (55/118)
# (56/118)
# (57/118)
# (58/118)
# (59/118)
# (60/118)
# (61/118)
# (62/118)
# (63/118)
# (64/118)
# (65/118)
# (66/118)
# (67/118)
# (68/118)
# (69/118)
# (70/118)
# (71/118)
# (72/118)
# (73/118)
# (74/118)
# (75/118)
# (76/118)
# (77/118)
# (78/118)
# (79/118)
# (80/118)
# (81/118)
# (82/118)
# (83/118)
# (84/118)
# (85/118)
# (86/118)
# (87/118)
# (88/118)
# (89/118)
# (90/118)
# (91/118)
# (92/118)
# (93/118)
# (94/118)
# (95/118)
# (96/118)
# (97/118)
# (98/118)
# (99/118)
# (100/118)
# (101/118)
# (102/118)
# (103/118)
# (104/118)
# (105/118)
# (106/118)
# (107/118)
# (108/118)
# (109/118)
# (110/118)
# (111/118)
# (112/118)
# (113/118)
# (114/118)
# (115/118)
# (116/118)
# (117/118)
# (118/118)

# %%
# Create DataFrame
df = pd.DataFrame({"Artist" : artist_name,
                   "Joined" : joined_convert,
                   "Subscribers" : subscribers_int,
                   "Total Views" : total_views_int,
                   "Date": published_on,
                   "Title" : title_videos,
                   "Category" : categories,
                   #"Duration" : duration_videos,
                   "Views" : views,
                   "Likes" : likes,
                   "Dislikes" : dislikes,
                   "URL" : urls_all,
                  })

df = df.sort_values("Date",ascending=False).reindex()
df.to_csv(f"{artist_name}_scrape.csv")
df
# Out:
#                                                Artist     Joined  Subscribers  \
# 0    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 1    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 2    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 3    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 4    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 5    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 6    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 7    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 8    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 9    LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 10   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 11   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 12   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 13   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 14   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 15   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 16   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 17   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 18   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 19   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 20   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 21   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 22   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 23   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 24   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 25   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 26   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 27   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 28   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 29   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 30   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 31   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 32   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 33   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 34   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 35   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 36   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 37   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 38   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 39   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 40   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 41   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 42   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 43   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 44   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 45   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 46   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 47   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 48   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 49   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 50   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 51   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 52   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 53   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 54   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 55   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 56   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 57   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 58   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 59   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 60   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 61   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 62   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 63   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 64   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 65   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 66   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 67   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 68   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 69   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 70   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 71   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 72   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 73   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 74   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 75   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 76   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 77   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 78   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 79   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 80   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 81   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 82   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 83   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 84   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 85   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 86   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 87   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 88   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 89   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 90   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 91   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 92   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 93   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 94   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 95   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 96   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 97   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 98   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 99   LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 100  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 101  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 102  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 103  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 104  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 105  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 106  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 107  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 108  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 109  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 110  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 111  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 112  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 113  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 114  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 115  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 116  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
# 117  LoungeV Films - Relaxing Music and Nature Sounds 2011-05-30       277242
#
#      Total Views       Date  \
# 0      111616587 2018-11-02
# 1      111616587 2018-10-26
# 2      111616587 2018-06-17
# 3      111616587 2018-06-12
# 4      111616587 2018-06-10
# 5      111616587 2018-06-03
# 6      111616587 2018-06-02
# 7      111616587 2018-06-01
# 8      111616587 2018-05-08
# 9      111616587 2018-04-04
# 10     111616587 2018-03-05
# 11     111616587 2018-02-08
# 12     111616587 2017-11-14
# 13     111616587 2017-11-06
# 14     111616587 2017-10-24
# 15     111616587 2017-10-02
# 16     111616587 2017-09-18
# 17     111616587 2017-09-04
# 18     111616587 2017-08-27
# 19     111616587 2017-08-20
# 20     111616587 2017-08-13
# 21     111616587 2017-08-06
# 22     111616587 2017-07-30
# 23     111616587 2017-07-20
# 24     111616587 2017-07-18
# 25     111616587 2017-06-07
# 26     111616587 2017-06-05
# 27     111616587 2017-06-02
# 28     111616587 2017-05-30
# 29     111616587 2017-05-22
# 30     111616587 2017-05-21
# 31     111616587 2017-05-19
# 32     111616587 2017-05-18
# 33     111616587 2017-05-17
# 34     111616587 2017-05-16
# 35     111616587 2017-05-15
# 36     111616587 2017-05-13
# 37     111616587 2017-05-11
# 38     111616587 2017-05-10
# 39     111616587 2017-05-08
# 40     111616587 2017-05-06
# 41     111616587 2017-05-05
# 42     111616587 2017-05-04
# 43     111616587 2017-05-03
# 44     111616587 2017-05-01
# 45     111616587 2017-04-30
# 46     111616587 2017-04-29
# 47     111616587 2017-04-28
# 48     111616587 2017-04-26
# 49     111616587 2017-04-25
# 50     111616587 2017-04-23
# 51     111616587 2017-04-22
# 52     111616587 2017-04-21
# 53     111616587 2017-04-20
# 54     111616587 2017-04-19
# 55     111616587 2017-04-18
# 56     111616587 2017-04-18
# 57     111616587 2017-04-10
# 58     111616587 2017-03-24
# 59     111616587 2017-03-12
# 60     111616587 2017-02-19
# 61     111616587 2017-02-19
# 62     111616587 2016-12-14
# 63     111616587 2016-11-30
# 64     111616587 2016-11-21
# 65     111616587 2016-08-30
# 66     111616587 2016-08-01
# 67     111616587 2016-07-29
# 68     111616587 2016-07-06
# 69     111616587 2016-07-02
# 70     111616587 2016-06-22
# 71     111616587 2016-05-16
# 72     111616587 2016-03-14
# 73     111616587 2016-01-15
# 74     111616587 2016-01-13
# 75     111616587 2016-01-11
# 76     111616587 2016-01-06
# 77     111616587 2016-01-02
# 78     111616587 2015-11-19
# 79     111616587 2015-11-16
# 80     111616587 2015-10-12
# 81     111616587 2015-07-16
# 82     111616587 2015-06-07
# 83     111616587 2015-06-02
# 84     111616587 2015-05-04
# 85     111616587 2015-04-28
# 86     111616587 2015-04-09
# 87     111616587 2015-01-30
# 88     111616587 2014-11-24
# 89     111616587 2014-11-17
# 90     111616587 2014-11-16
# 91     111616587 2014-06-03
# 92     111616587 2014-03-17
# 93     111616587 2014-03-12
# 94     111616587 2014-03-10
# 95     111616587 2014-02-02
# 96     111616587 2014-01-25
# 97     111616587 2014-01-12
# 98     111616587 2014-01-07
# 99     111616587 2013-10-28
# 100    111616587 2013-10-04
# 101    111616587 2013-09-24
# 102    111616587 2013-05-25
# 103    111616587 2013-03-22
# 104    111616587 2012-12-04
# 105    111616587 2012-09-30
# 106    111616587 2012-09-22
# 107    111616587 2012-09-13
# 108    111616587 2012-09-01
# 109    111616587 2012-08-24
# 110    111616587 2012-08-13
# 111    111616587 2012-07-21
# 112    111616587 2012-06-28
# 113    111616587 2012-04-25
# 114    111616587 2011-11-12
# 115    111616587 2011-09-15
# 116    111616587 2011-09-15
# 117    111616587 2011-06-28
#
#                                                  Title          Category  \
# 0    4K Ultra HD Video - Lakes and Volcanoes, 1 Hou...  Film & Animation
# 1    New 4K Video Coming Soon - Lakes and Volcanoes...  Film & Animation
# 2    🍏 Heavenly Music for Deep Sleeping or Simply D...             Music
# 3    Distant Ocean Sounds for Deep Sleeping - Empty...             Music
# 4    Sleep with Ocean Sounds at Night - NO MUSIC - ...             Music
# 5    Sleep Music with Ocean Sounds at Night - Relax...             Music
# 6         4K Video 🌴 Caribbean Nature - Ultra HD 2160p  Film & Animation
# 7                           4K Video ☯ Relaxing Night!             Music
# 8    Sleep Music with Snow Falling Peacefully at Ni...             Music
# 9    Nature Sounds 🌎 Earth's Most Beautiful Places ...             Music
# 10   Uplifting Study Music with Nature Scenery Vide...             Music
# 11   Relaxing & Easy Listening Lounge Music 💚 Sweet...             Music
# 12   Very Relaxing Music with Paradise Beaches and ...             Music
# 13   Sleep Music Video to Fall Asleep Naturally at ...             Music
# 14   Relaxing Sleep Music with Lake and Moon at Nig...             Music
# 15   Relaxing Music and Spectacular Atacama Desert ...             Music
# 16   Relaxing Sleep Music with River and Moon at Ni...             Music
# 17   Sleep Music Dreamy Lullabies at Night with Moo...             Music
# 18   Sleep Music with Dreamy Waterfall at Night - R...             Music
# 19   Sleep Music with Lake and Volcano at Night - R...             Music
# 20   Sleep Music with River at Night - Relaxing Mus...             Music
# 21   Sleep Music Video at Night with Wave Sounds - ...             Music
# 22   Sleep Music Video with Gentle Wave Sounds 🌙 Su...             Music
# 23   💚 Relaxing Music Background with Heavenly Beau...             Music
# 24   Japanese Meditation Music, Harp (Koto) Perform...             Music
# 25                       Argentina - 4K Video Ultra HD             Music
# 26   Sleep Music MEGA playlist 🌙 Relaxing Music for...             Music
# 27                       4K Video - Chile in Ultra HD!             Music
# 28   Relaxing Music 9 Hour MEGA Playlist ❤ Over 100...             Music
# 29   Relaxing Music for Yoga and Meditation - 8 Hours!             Music
# 30   🌙 Relaxing Deep Sleep Music with Ambient Blue ...             Music
# 31   Relaxing Hang Drum Music ❤ Relaxing New Age Am...             Music
# 32   8 Hours of Relaxing Music - Peaceful Backgroun...             Music
# 33   Relaxing Harp Music - Peaceful Background Musi...             Music
# 34               8 Hours of Relaxing Music - Blissful!             Music
# 35   Relaxing Music with Tibetan Singing Bowls and ...             Music
# 36                   4K Video Ultra HD - Epic Footage!             Music
# 37   ☯ Very Relaxing Piano Music for Study, Yoga, M...             Music
# 38   Relaxing Flute Music - Double Rainbow - Medita...             Music
# 39   The Sweetest Sleep Music ☯ Relaxing Vocal Elf ...             Music
# 40        Relaxing Japanese Music with Nature Sounds ☯             Music
# 41   Relaxing Spa Music - 3 Hours of Peaceful Backg...             Music
# 42   Relaxing Music and Lake Sounds for Yoga, Study...             Music
# 43   ❤ Relaxing Music with Singing Birds and Waterf...             Music
# 44   Relaxing Yoga Music, Ideal as Study Music, Per...             Music
# 45   Unbelievably Relaxing Music - Soothing Yoga Mu...             Music
# 46   Relaxing Tribal Music with Delta Waves - Deep ...             Music
# 47   Meditation Music - 3 Hours of Pure Relaxation ...             Music
# 48   Relaxing Music Video ❤ Crashing Waves ❤ Study ...             Music
# 49   Relaxing Yoga Music with Bird Song, Water Soun...             Music
# 50    Relaxing Water Sounds - 8 Minute Break, No Music  Film & Animation
# 51   Water Sounds - Relaxing Rivers and Waterfalls,...  Film & Animation
# 52                       4K Video - The Andes Ultra HD  Film & Animation
# 53   Rolling Waves of the Atlantic Ocean - No Music...  Film & Animation
# 54   Instant Stress Relief with Relaxing Music and ...  Film & Animation
# 55   10 Minute Break from Work or Study - Relaxing ...  Film & Animation
# 56   4k Video - Rivers and Waterfalls - Time Lapse ...  Film & Animation
# 57   Ocean Waves Lullaby for Sleeping with Blue Nig...             Music
# 58          4K Video Ultra HD 💚 Most Beautiful Sunsets     Entertainment
# 59   4K Video Ultra HD 💚 60fps Epic 2160p Drone Foo...     Entertainment
# 60                 Underwater Music FIlm Trailer 1080p     Entertainment
# 61                     Beach Lounge Film Trailer 1080p     Entertainment
# 62   Relaxing Nature Sounds for Study, Yoga and Med...             Music
# 63   Relaxing Music with Amazing Nature Scenery HD ...             Music
# 64     4K Video - DJI Inspire 1 RAW X5R Aerial Footage   Travel & Events
# 65                     4K Video - Flying in Conguillío   Travel & Events
# 66   Ocean Sounds for Sleeping, Meditation, Yoga on...             Music
# 67   White Noise : Relaxing Waterfall Sounds - 8 hours             Music
# 68             Relaxing Music with Peaceful Lake Views             Music
# 69   Relaxing Music and Nature Sounds - 4K and HD 1...  Film & Animation
# 70   Sleepy Ocean Waves Sounds for Deep Sleeping, R...             Music
# 71   Flying with Relaxing Music - DJI Phantom 3 Dro...             Music
# 72            Nature Sounds of Patagonia - 2 Hour Film   Travel & Events
# 73   Mountain Sounds -  New Film with Nature Sounds...             Music
# 74                     HD 1080p - Nature Scenery Video             Music
# 75   Full HD 1080p Video : Relaxing Piano Music ♫ P...             Music
# 76   Mountain Sounds - New Film with Nature Sounds,...  Film & Animation
# 77                     Dominican Republic - Time Lapse  Film & Animation
# 78                      Volcán Llaima - Llaima Volcano             Music
# 79      Sierra Nevada, Conguillío National Park, Chile             Music
# 80               Relaxing White Noise - Trancura River             Music
# 81   HD Video (1080p) with Relaxing Music of Native...             Music
# 82   Relaxing Music with Gentle Ocean Sounds, Sooth...             Music
# 83   Relaxing Music with Healing River Sounds - 7 H...             Music
# 84                         4K Video 💚 Beauty of Nature  Film & Animation
# 85   Patagonian Nature Sounds - Relaxing Rivers, La...  Film & Animation
# 86                              Planet Patagonia in 4K  Film & Animation
# 87   Super Relaxing Music with Nature Sounds - 3 Ho...             Music
# 88   Relaxing Patagonia - Real-time Film Trailer wi...             Music
# 89   Petrohué River - Calbuco Volcano, Los Lagos, C...             Music
# 90   New Time Lapse "Planet Patagonia" Film from Ch...             Music
# 91   Dreams Aquamarine - New Relaxing Music Film wi...             Music
# 92   Relaxing Piano Music with Ocean Sounds, HD Vid...             Music
# 93   Infinity Blue film Trailer 1080p - Ocean Sight...  Film & Animation
# 94   4K Video - Dreamlapse UHD Time Lapse Film Trai...  Film & Animation
# 95   Relaxing Meditation Music with Ocean Views, 2 ...             Music
# 96   Japanese Music 💚 Relaxing Instrumental Music w...             Music
# 97                   Sunset Time Lapse - Stock Footage  Film & Animation
# 98   Tropical Ocean Sounds with Amazing Beach Scene...  Film & Animation
# 99   Relaxing Music Film Compilation for Sleeping, ...             Music
# 100  ~ Ocean Sounds, Waves for Yoga, Meditation, Sl...  Film & Animation
# 101  HD Video 1080p - Timelapse with Sunsets, Cloud...             Music
# 102  DreamLapse Film ☯ Relaxing Music with Time Lapses             Music
# 103  Meditation on the beach with ocean waves - rel...     Entertainment
# 104  Window Views with relaxing sounds of waves - H...  Film & Animation
# 105  Relaxing Music + Over 100 Exotic Landscapes Na...  Film & Animation
# 106        Caribbean Lounge Film Trailer - Ocean Waves  Film & Animation
# 107  Nature Sounds: ☯ Relaxing ZEN for Yoga and Med...  Film & Animation
# 108                Soothing Music & White Sand Beaches   Travel & Events
# 109    Zzz Sleep Music - Melodic Surf - Relaxing Video             Music
# 110  Relaxing Music with Ocean Webcam, 1080p Video ...             Music
# 111  Beautiful views, relaxing music and sounds of ...             Music
# 112  Caribbean Lounge Film (trailer) 3½ hours of na...  Film & Animation
# 113                   Most Romantic Music for All Ages             Music
# 114  Those Relaxing Sounds of Waves, Ocean Sounds -...  Film & Animation
# 115                     Tropical beach - Playa Caleton   Travel & Events
# 116     Playa Grande - Dominican Republic - Best beach   Travel & Events
# 117         Holiday lounge with Relaxing Nature sounds   Travel & Events
#
#         Views  Likes  Dislikes                                          URL
# 0       38967    278         8  https://www.youtube.com/watch?v=EstNSjwpqE8
# 1       19875    340         7  https://www.youtube.com/watch?v=eZXFtb35BsQ
# 2      172868   1291        73  https://www.youtube.com/watch?v=IKGPqvZYEDQ
# 3       78902    778        39  https://www.youtube.com/watch?v=NvLEUgbl6Gg
# 4      307245   2589       200  https://www.youtube.com/watch?v=5iLESlcQwpk
# 5       90706    917        45  https://www.youtube.com/watch?v=xaQp-OdQ738
# 6       46865    444        18  https://www.youtube.com/watch?v=kYTSlfpah7A
# 7       14442    197         4  https://www.youtube.com/watch?v=Al5-Dt6Q15o
# 8      107403   1059        63  https://www.youtube.com/watch?v=tKh08LeJ66c
# 9      280267   2329        67  https://www.youtube.com/watch?v=1gwglom4FeA
# 10     199960   1319        78  https://www.youtube.com/watch?v=O7tYVSP3juo
# 11     159145   1135        56  https://www.youtube.com/watch?v=16DOqcbWN_M
# 12     660170   3538       205  https://www.youtube.com/watch?v=dF7O-DqwsJg
# 13     442627   3073       280  https://www.youtube.com/watch?v=nxJgR33CVs4
# 14     377246   2528       224  https://www.youtube.com/watch?v=0XE9DUdvuHQ
# 15      25724    371        11  https://www.youtube.com/watch?v=78WqKpLwLIo
# 16     476823   3367       227  https://www.youtube.com/watch?v=Obtbq5eI4uE
# 17     363419   3172       216  https://www.youtube.com/watch?v=MBdwv4F5C78
# 18     204811   1990       125  https://www.youtube.com/watch?v=EAOR1X5Tn4w
# 19     102594   1041        55  https://www.youtube.com/watch?v=9SSwgi4hkcI
# 20     349979   2885       181  https://www.youtube.com/watch?v=zXlEyH-bRUw
# 21      87927    930        42  https://www.youtube.com/watch?v=CMCYTWRgT4k
# 22     158091   1535        96  https://www.youtube.com/watch?v=MImPWnkdDN8
# 23     124161   1205        67  https://www.youtube.com/watch?v=Qt1qe5rBvO0
# 24      39912    537        26  https://www.youtube.com/watch?v=dgx9LOzNX7M
# 25     153625    827        36  https://www.youtube.com/watch?v=d90JYK916AU
# 26     148047   1403       115  https://www.youtube.com/watch?v=RZB0Y8wutU4
# 27     263732   1681        91  https://www.youtube.com/watch?v=Tc0LU7y3btU
# 28     100582    665        35  https://www.youtube.com/watch?v=6oc2uma60ig
# 29      20821    168        10  https://www.youtube.com/watch?v=z7hUEigz79Y
# 30     428963   2903       298  https://www.youtube.com/watch?v=TYJvjYYwlxE
# 31      30191    337        12  https://www.youtube.com/watch?v=UTh5fS0mW6A
# 32     154620    712        46  https://www.youtube.com/watch?v=ZbofJucjkSU
# 33      15570    195        15  https://www.youtube.com/watch?v=-i6twp7mNc0
# 34      49366    372        23  https://www.youtube.com/watch?v=NZjUv--j5uQ
# 35      25456    309        20  https://www.youtube.com/watch?v=fA5giowTktg
# 36     214620   1056        28  https://www.youtube.com/watch?v=od5nla42Jvc
# 37      12587    147         4  https://www.youtube.com/watch?v=hXsdXvrUhtY
# 38      28969    294        13  https://www.youtube.com/watch?v=C0xH6N-lj2A
# 39    1395585  10345       770  https://www.youtube.com/watch?v=3UUkV6cRe8g
# 40      25889    320        16  https://www.youtube.com/watch?v=2CbkoiPThoo
# 41      65444    361        35  https://www.youtube.com/watch?v=oXO8IhSLf8o
# 42      12258    162         6  https://www.youtube.com/watch?v=zKEMw5SMYU8
# 43      58406    602        25  https://www.youtube.com/watch?v=xqlInvuL0Zo
# 44       8475    100         7  https://www.youtube.com/watch?v=emQi8rgSw1U
# 45      31000    200        15  https://www.youtube.com/watch?v=fQPzSr89D7c
# 46      12478    176         8  https://www.youtube.com/watch?v=rjMQpwXOv5s
# 47      49088    369        21  https://www.youtube.com/watch?v=EyKbwl9p-_Y
# 48      34547    302         9  https://www.youtube.com/watch?v=tm1Ay7dp2Z4
# 49      89820    614        42  https://www.youtube.com/watch?v=6D65z7RlWrQ
# 50       5473    142         2  https://www.youtube.com/watch?v=6cY96hvniXY
# 51      22695    290         5  https://www.youtube.com/watch?v=KqA0RUc1Q1Y
# 52    9188196  11372      1528  https://www.youtube.com/watch?v=pMxgov6_5TA
# 53       6784    173         9  https://www.youtube.com/watch?v=qedu-xdF2eU
# 54      11850    232         5  https://www.youtube.com/watch?v=kvjN-nLdcD0
# 55      11027    202         3  https://www.youtube.com/watch?v=0ZBV0Co6PNc
# 56      13970    153        11  https://www.youtube.com/watch?v=_yUVZUsjv1M
# 57     404192   2824       201  https://www.youtube.com/watch?v=TYY2E9ly_ho
# 58     363980   1715        70  https://www.youtube.com/watch?v=L_KaQfS1hRQ
# 59    6940080  23779      1388  https://www.youtube.com/watch?v=R3AKlscrjmQ
# 60      23873    141         1  https://www.youtube.com/watch?v=KOb_cZ3ME2s
# 61      21322    144         3  https://www.youtube.com/watch?v=0t3r17oTyZk
# 62     684934   3245       139  https://www.youtube.com/watch?v=IBfQXYe0-Lc
# 63     996299   4680       223  https://www.youtube.com/watch?v=TdpBRZ0dZhw
# 64      39140    240        12  https://www.youtube.com/watch?v=q4bSRKGACO4
# 65     130869    653        16  https://www.youtube.com/watch?v=_pESzMsAYQY
# 66     374916   1817       117  https://www.youtube.com/watch?v=NJre-7QI4gc
# 67      88274    590        29  https://www.youtube.com/watch?v=48GEs8Xxyus
# 68     120775    736        32  https://www.youtube.com/watch?v=wtcl5NEN3bI
# 69     357461   1319        76  https://www.youtube.com/watch?v=ZorDZxpPbOI
# 70    2939404  17682      1683  https://www.youtube.com/watch?v=WwzbkaqT8Ow
# 71     206836   1000        55  https://www.youtube.com/watch?v=G1scWilEZMM
# 72     151107   1171        24  https://www.youtube.com/watch?v=74WZqbfz2TI
# 73      42271    326         6  https://www.youtube.com/watch?v=RmCd6kDrbOU
# 74    1177604   3406       247  https://www.youtube.com/watch?v=DQuhA5ZCV9M
# 75    1147585   1763       225  https://www.youtube.com/watch?v=CyOMgwGiYBc
# 76     329296    518        21  https://www.youtube.com/watch?v=UZ1Q3KL65s0
# 77      21048    259         6  https://www.youtube.com/watch?v=JaU3m80UaUA
# 78       9485    120         3  https://www.youtube.com/watch?v=zlMHOzlEbTM
# 79      11783    144         5  https://www.youtube.com/watch?v=DKPaJCKv8K8
# 80      13636    175         4  https://www.youtube.com/watch?v=u-NUMro_Jbk
# 81    4930490   7787       864  https://www.youtube.com/watch?v=HmZKgaHa3Fg
# 82    1204885   6066       481  https://www.youtube.com/watch?v=DXzk5i4Ofe8
# 83     539600   2178       134  https://www.youtube.com/watch?v=mwDwZwLcGl4
# 84   14288105  27476      1915  https://www.youtube.com/watch?v=0wCC3aLXdOw
# 85     233944   1062        29  https://www.youtube.com/watch?v=EOiNe_GpcHE
# 86     251324   1216        39  https://www.youtube.com/watch?v=nt4HfMWaH8g
# 87    5996360  20752      1309  https://www.youtube.com/watch?v=YrddaP6ml1M
# 88     126494    642        10  https://www.youtube.com/watch?v=Mj8Ks9sXeMc
# 89      37207    245         6  https://www.youtube.com/watch?v=RwZ2eWSxVsY
# 90      56998    342        12  https://www.youtube.com/watch?v=U7onxxo5XAE
# 91     250795   1159        29  https://www.youtube.com/watch?v=5Tg7IbsREr4
# 92    1735706   7434       384  https://www.youtube.com/watch?v=PCuzgXdm3R8
# 93     250511    886        60  https://www.youtube.com/watch?v=dcitAZRsVQY
# 94     793402   2015        85  https://www.youtube.com/watch?v=qiBm4AfRcr0
# 95    1936142   5563       359  https://www.youtube.com/watch?v=ln96IDWdrEQ
# 96    3553672  23012       715  https://www.youtube.com/watch?v=DkW1iTyS8dk
# 97     288334   1409        51  https://www.youtube.com/watch?v=OmjnzCYBXJ4
# 98    3674546  13368       798  https://www.youtube.com/watch?v=4mEbABPtTv8
# 99    4404617  15062       868  https://www.youtube.com/watch?v=c2-e7Z1LEL8
# 100    243001   1156        56  https://www.youtube.com/watch?v=1019PSm_YTs
# 101   3280517  12683       468  https://www.youtube.com/watch?v=8gD_9WPPFb4
# 102     45975    340        13  https://www.youtube.com/watch?v=Sobc1ShSw2g
# 103     43058    289        16  https://www.youtube.com/watch?v=jJkEiw6Gh0U
# 104    179333    702        34  https://www.youtube.com/watch?v=PT0xNZ41GGI
# 105   6456035  21178      1474  https://www.youtube.com/watch?v=6zqpDVyCB2Y
# 106     29391    151         7  https://www.youtube.com/watch?v=fURzvoMDrPg
# 107    267146   1170        56  https://www.youtube.com/watch?v=guOH2DrexUQ
# 108    126378    525        22  https://www.youtube.com/watch?v=6fLYYJlc9dk
# 109     67818    298        18  https://www.youtube.com/watch?v=p1HAGLOXAKk
# 110   3178035   8603       598  https://www.youtube.com/watch?v=0DoJ4I0NJR0
# 111     59803    236        13  https://www.youtube.com/watch?v=VLzUgrOiVOQ
# 112    172942    377        16  https://www.youtube.com/watch?v=yrHHjRSsXr4
# 113     44167    241         9  https://www.youtube.com/watch?v=g-37gJ_M9pw
# 114  18439414  50100      3754  https://www.youtube.com/watch?v=OG2eGVt6v2o
# 115     45202    141        15  https://www.youtube.com/watch?v=xqvJuq9uz0I
# 116     40858    202         8  https://www.youtube.com/watch?v=LILM64Dtq3A
# 117     34922    191         6  https://www.youtube.com/watch?v=jRXCJvRrC2E

# %%
# Graph Data
#plt.bar(np.arange(0,len(df),1),df["Views"], tick_label = df["Date"])
plt.bar(np.arange(0,len(df),1),df["Views"])
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"] = [10,4]
