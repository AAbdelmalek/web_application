# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
response = requests.get("https://www.youtube.com/watch?v=M0xRCrqaffA")

# %%
soup = bs(response.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all("span", class_="video-time")
# Out:
# [<span class="video-time">23:35</span>,
#  <span class="video-time">42:29</span>,
#  <span class="video-time">2:03:10</span>,
#  <span class="video-time">12:59</span>,
#  <span class="video-time">14:05</span>,
#  <span class="video-time">15:16</span>,
#  <span class="video-time">35:27</span>,
#  <span class="video-time">19:49</span>,
#  <span class="video-time">12:20</span>,
#  <span class="video-time">21:57</span>,
#  <span class="video-time">31:53</span>,
#  <span class="video-time">43:23</span>,
#  <span class="video-time">24:34</span>,
#  <span class="video-time">21:27</span>,
#  <span class="video-time">13:54</span>,
#  <span class="video-time">24:47</span>,
#  <span class="video-time">25:55</span>,
#  <span class="video-time">24:10</span>,
#  <span class="video-time">32:39</span>,
#  <span class="video-time">23:27</span>]

# %%
scrape_last = requests.get("https://www.youtube.com/watch?v=h40ggDIhgDM")
last_soup = bs(scrape_last.text, "lxml")
last_soup.find_all("span", class_="video-time")
last_soup.find_all("span", class_="accessible-description")


# for tag in last_soup.find_all("h4", class_="title"):
#     print(tag.find_next("a").text)
last_soup.find_all("h4", text="\n      Category\n    ")
# Out:
# [<h4 class="title">
#        Category
#      </h4>]

# %%
last_soup.find_all("span", class_="index")
# Out:
# []

# %%
  
scrape_first = requests.get("https://www.youtube.com/watch?v=M0xRCrqaffA&list=UUE6acMV3m35znLcf0JGNn7Q")
first_soup = bs(scrape_first.text, "lxml")

# %%
playlist_inside_soup.find("span", class_="index")

# %%
streamed = "streamed live on may 1, 2010"
published = "published on may 1, 2010"
premiered = "premiered may 1, 2010"

premiered.split(" ")[len(premiered.split(" "))-3:len(premiered.split(" "))]
# Out:
# ['may', '1,', '2010']
