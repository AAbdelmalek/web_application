# %%
# To do:
# Fix Dates, must be another published on vs premiered on discrepancy -- OK
# Fix Titles -- OK
# Looks like missing one (1) video for Gibi 344/345 -- OK
# DUPLICATES -- OK
# EDGE CASES ▶ -- OK
# User entered date range -- OK
# Limit Date Range to Years and then YTD, e.g. 2016, 2017, YTD, All-Time
# Better commenting -- OK
# Duration -- OK
# Flask -- 
# HTML/CSS/JS -- 
# Dev Database -- OK
# Wrong Date bug -- 
# DB Date Bug - hours path - messed up datetime object -- OK
# Escape SQL -- 
# Cached Scrapes -- OK
# Premium Content Bug -- OK

# Import Dependencies
from bs4 import BeautifulSoup as bs
import requests
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
import time
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
pd.set_option('display.max_rows', 500)

# Get Scrape Date
scrape_date = datetime.now().strftime("%Y-%m-%d")
scrape_datetime = datetime.utcnow()

# Connect to Database Server
connection = create_engine('mysql://root:Mars@127.0.0.1')

# Creating database if not exists
connection.execute("CREATE DATABASE IF NOT EXISTS web_app_dev")
connection.execute("USE web_app_dev")

# Convert Date from Jan 1, 1999 format to datetime object
converted_date = ""
raw_months = {"Jan": 1, "Feb": 2, "Mar" : 3, "Apr" : 4, 
              "May" : 5, "Jun" : 6, "Jul" : 7, "Aug" : 8,
              "Sep" : 9, "Oct" : 10, "Nov" : 11, "Dec" : 12}

def convertDate(raw_date):
    
    try:
        converted_date = ""
        number_month = raw_months.get(raw_date[0])
        date_str = (str(number_month) + "/" + raw_date[1] + "/" + raw_date[2]).replace(",", "")
        converted_date = datetime.strptime(date_str, '%m/%d/%Y')
        return converted_date
        
    except:
        print(f"{raw_date} Convert function date is not valid.")

# Get Youtuber's Name
input_name = input("Enter Youtuber's Name: ")
print(input_name)

input_date_range = input("How far back in time do you want to go? (YYYY-MM-DD) or (all-time): ")
print(input_date_range)

if input_date_range == "all-time":
    converted_input_date = datetime.strptime("1950-01-01", '%Y-%m-%d')
    
else:
    try:
        converted_input_date = datetime.strptime(input_date_range, '%Y-%m-%d')
        
    except:
        print("Input date is not valid.")
        exit()

list_name = input_name.split()
converted_name = input_name

if len(list_name) > 1:    
    converted_name = ""
    
    for i in range(len(list_name)):
        converted_name = converted_name + list_name[i]
        
        if i != len(list_name)-1:
            converted_name = converted_name + "+"

search_name = converted_name
start_url = "https://www.youtube.com/results?search_query=" + search_name

print(start_url)

get_youtube_url_response = requests.get(start_url)
youtube_name_soup = bs(get_youtube_url_response.text, "lxml")
raw_youtube_name_link = youtube_name_soup.find_all("div", class_="yt-lockup-byline")[0].a.get("href")
videos_link = "https://www.youtube.com" + raw_youtube_name_link + "/videos"
about_link = "https://www.youtube.com" + raw_youtube_name_link + "/about"

print(videos_link)
print(about_link)

# Get About Information
about_html = requests.get(about_link)

# Parse HTML
about_soup = bs(about_html.text, "lxml")

# Artist Information
artist_name = about_soup.find("meta", property="og:title").get("content")

subscribers = about_soup.find_all("span", class_="about-stat")[0].text
subscribers_int = int(subscribers.split(" ")[0].replace(",",""))

total_views = about_soup.find_all("span", class_="about-stat")[1].text
total_views_int = int(total_views[3:len(total_views)].split(" ")[0].replace(",",""))

joined = about_soup.find_all("span", class_="about-stat")[2].text
joined_temp = joined.split(" ")[1:4]
joined_convert = convertDate(joined_temp)

print(f"Artist: {artist_name}")
print(f"Subscribers: {subscribers_int}")
print(f"Views: {total_views_int}")
print(f"Joined: {joined_convert}")

# Replacing spaces withunderscores for new table name
artist_db_name = artist_name.replace(" ","_").replace("`","")

# Checking Database to See if Data was Previously Scraped
df_cache = []
try:
    df_cache = pd.read_sql(f"SELECT artists.ARTIST, artists.SCRAPE_DATE, artists.SEARCH_NAME, JOINED, SUBSCRIBERS, TOTAL_VIEWS, \
    {artist_db_name}.PUBLISHED, \
    {artist_db_name}.TITLE, {artist_db_name}.CATEGORY , {artist_db_name}.DURATION, {artist_db_name}.VIEWS, \
    {artist_db_name}.LIKES, {artist_db_name}.DISLIKES, {artist_db_name}.PAID, {artist_db_name}.FAMILY_FRIENDLY, \
    {artist_db_name}.URL FROM artists \
    INNER JOIN {artist_db_name} \
    ON artists.artist = {artist_db_name}.artist",connection)
    
except:
    print("Not found in database")

if len(df_cache) != 0:
    scrape_date = df_cache.loc[0,"SCRAPE_DATE"]
    print(f"A cached scrape ({scrape_date} UTC) has been found...")
    display(df_cache)
    
else:
    # Convert User Name to UU Format
    youtube_code = raw_youtube_name_link.split("/")[2]

    if youtube_code[0:2] == "UC":

        youtube_code = raw_youtube_name_link.split("/")[2]
        playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:] 

    elif youtube_code[0:2] != "UC":

        youtube_code_raw = about_soup.find("link", rel="canonical").get("href")
        youtube_code = youtube_code_raw.split("/")[4]
        playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:]  

    print(playlist_link)

    # Get Playlist Response
    playlist_response = requests.get(playlist_link)

    # Create Playlist Soup Object
    playlist_soup = bs(playlist_response.text, 'lxml')

    # Get First Video URL as Starting Point
    first_video = "https://www.youtube.com" + playlist_soup.find_all("a", class_="pl-video-title-link")[0].get("href").split("&")[0]
    first_video_within_playlist = first_video + "&" + playlist_link.split("?")[1]

    print(first_video_within_playlist)

    # Create Soup Object for First Video Inside Playlist
    playlist_inside_request = requests.get(first_video_within_playlist) 

    playlist_inside_soup = bs(playlist_inside_request.text, "lxml")

    urls_all = []
    total_videos_in_playlist = int(playlist_inside_soup.find("span", id="playlist-length").text.replace(" videos","").replace(",",""))
    print(f"Total videos: {total_videos_in_playlist}")
    number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) 
    last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
    last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
    link_fix = "https://www.youtube.com" + last_shown_link

    # proceed = input("Proceed with scrape? (y/n)")

    # if proceed == "n" or proceed == "N":
    #     exit()

    print("Getting urls...")

    for i in range(total_videos_in_playlist):   

        if i == 0:       
            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
            url = "https://www.youtube.com" + first_link.find_next("a").get("href")
            original_url = url.split("&")[0]
            urls_all.append(original_url)
            next_link = first_link

        elif i == last_video_index:       
            playlist_inside_request = requests.get(link_fix)
            playlist_inside_soup = bs(playlist_inside_request.text, "lxml")
            last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
            link_fix = "https://www.youtube.com" + last_shown_link
            last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i+1}\n    ")

            if first_link is None:           
                next_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")

            else:          
                next_link = first_link

            next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
            original_url = next_url.split("&")[0]
            urls_all.append(original_url)
            number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) - 1

        else:

            if i == 1:
                first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")

            elif playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ") is None:
                first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")

            else:
                first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ")

            next_link = first_link
            next_link = next_link.find_next("span", class_="index")
            next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
            original_url = next_url.split("&")[0]
            urls_all.append(original_url)

    # Going to Each Video and Extracting Data
    published_on = []
    raw_published_on = []
    views = []
    date = []
    duration_videos = []
    likes = []
    dislikes = []
    title_videos = []
    categories = []
    paid_list = []
    family_friendly = []
    bump = 0

    for i in range(len(urls_all)):
        try:
            video_url = urls_all[i]
            video_response = requests.get(video_url)
            video_soup = bs(video_response.text, 'lxml')

            # Publish Date
            raw_publish_date = video_soup.find("div", id="watch-uploader-info").text
            raw_published_on.append(raw_publish_date)

            # Handle All Raw Dates "Premiered", ""Published", "Streamed", "X Hours Ago"
            publish_date_format = raw_publish_date.split(" ")[len(raw_publish_date.split(" "))-3:len(raw_publish_date.split(" "))]

            if publish_date_format[1] == "hours":
                publish_date_convert = datetime.strptime(scrape_date, '%Y-%m-%d')

            else:
                publish_date_convert = convertDate(publish_date_format)

            # Break if Date Less than Input Date Range
            if publish_date_convert < converted_input_date:
                break

            else:
                published_on.append(publish_date_convert)

            # Title
            title = video_soup.find("title").text.replace(" - YouTube", "")
            title_videos.append(title)

            # Views
            string_views = video_soup.find("div", id="watch7-views-info").text.replace(" views", "").replace(",","").replace("\n","")
            int_views = int(string_views)
            views.append(int_views)

            #Duration
            duration = video_soup.find("meta", itemprop="duration").get("content").replace("PT","").split("M")
            duration_mins = int(video_soup.find("meta", itemprop="duration").get("content").replace("PT","").split("M")[0])
            duration_secs = int(duration[1].replace("S",""))
            total_duration = duration_mins + duration_secs/60
            duration_videos.append(total_duration)

            # Likes
            string_likes = video_soup.find("button", title="I like this").text
            if string_likes != "":
                int_likes = int(string_likes.replace(",",""))
                likes.append(int_likes)
            else:
                likes.append(0)

            # Dislikes
            string_dislikes = video_soup.find("button", title="I dislike this").text
            if string_dislikes != "":
                int_dislikes = int(string_dislikes.replace(",",""))
                dislikes.append(int_dislikes)
            else:
                dislikes.append(0)

            # Category
            category = video_soup.find("h4", class_="title", text="\n      Category\n    ").find_next("a").text
            categories.append(category)

            # Paid
            paid = video_soup.find("meta", itemprop="paid").get("content")
            paid_list.append(paid)

            # Family Friendly
            family = video_soup.find("meta", itemprop="isFamilyFriendly").get("content")
            family_friendly.append(family)

            percent_complete = round(((i+1) / (len(urls_all)))*100,2)

            print(f"{percent_complete}% complete...")
        
        # Remove any data apended to lists during an exception, account for smaller list size after removal vs. i
        except:
            print(f"Skipped {video_url}...")
            try:
                published_on.pop(i-bump)
            except:
                pass            
            try:
                raw_published_on.pop(i-bump)
            except:
                pass            
            try:
                views.pop(i-bump)
            except:
                pass            
            try:
                date.pop(i-bump)
            except:
                pass            
            try:
                duration_videos.pop(i-bump)
            except:
                pass            
            try:
                likes.pop(i-bump)
            except:
                pass
            try:
                dislikes.pop(i-bump)
            except:
                pass
            try:
                title_videos.pop(i-bump)
            except:
                pass
            try:
                categories.pop(i-bump)
            except:
                pass
            try:
                paid_list.pop(i-bump)
            except:
                pass
            try:    
                family_friendly.pop(i-bump)
            except:
                pass
            try:
                urls_all.pop(i-bump)
            except:
                pass
            bump = bump + 1
            continue
            
    urls_to_date = urls_all[0:len(published_on)]

    # Create DataFrame
    df = pd.DataFrame({"Artist" : artist_name,
                       "Scrape_Date" : scrape_datetime,
                       "Search_Name" : input_name,
                       "Joined" : joined_convert,
                       "Subscribers" : subscribers_int,
                       "Total_Views" : total_views_int,
                       "Published": published_on,
                       "Title" : title_videos,
                       "Category" : categories,
                       "Duration" : duration_videos,
                       "Views" : views,
                       "Likes" : likes,
                       "Dislikes" : dislikes,
                       "Paid" : paid_list,
                       "Family_Friendly" : family_friendly,
                       "URL" : urls_to_date,
                      })

    df = df.sort_values("Published",ascending=False)
    
    # Saving to CSV
    df.to_csv(f"{artist_name}_scrape.csv")

    # Saving to JSON
    df.to_json(f"../js/{artist_name}_data.js", orient="records")

    # Insert Data into Database
    print("Inserting data into database...")
    # Creating table for videos
    connection.execute(f"\
    CREATE TABLE IF NOT EXISTS {artist_db_name} (\
    ID INT NOT NULL AUTO_INCREMENT PRIMARY KEY,\
    SCRAPE_DATE DATETIME,\
    SEARCH_NAME VARCHAR(355) CHARACTER SET UTF8MB4,\
    ARTIST VARCHAR(255) CHARACTER SET UTF8MB4,\
    PUBLISHED DATE,\
    TITLE VARCHAR(255) CHARACTER SET UTF8MB4,\
    CATEGORY VARCHAR(255) CHARACTER SET UTF8MB4,\
    DURATION FLOAT,\
    VIEWS INT,\
    LIKES INT,\
    DISLIKES INT,\
    COMMENTS INT,\
    PAID VARCHAR(255) CHARACTER SET UTF8MB4,\
    FAMILY_FRIENDLY VARCHAR(255) CHARACTER SET UTF8MB4,\
    URL VARCHAR(255) CHARACTER SET UTF8MB4\
    )")

    # Creating Table for Artist data
    connection.execute("\
    CREATE TABLE IF NOT EXISTS artists(\
    ID INT NOT NULL AUTO_INCREMENT PRIMARY KEY,\
    SCRAPE_DATE DATETIME,\
    TABLE_NAME VARCHAR(255)CHARACTER SET UTF8MB4,\
    SEARCH_NAME VARCHAR(355) CHARACTER SET UTF8MB4,\
    ARTIST VARCHAR(255) CHARACTER SET UTF8MB4,\
    JOINED DATE,\
    SUBSCRIBERS INT,\
    TOTAL_VIEWS BIGINT\
    )")

    # Getting df values and inserting into appropriate tables
    for i in range(len(df)):
        scrape_date = df.loc[i,"Scrape_Date"]
        search_name = df.loc[i,"Search_Name"]
        table_name = artist_db_name
        artist = df.loc[i,"Artist"].replace("`","")
        joined = df.loc[i,"Joined"]
        subscribers = df.loc[i,"Subscribers"]
        total_views = df.loc[i,"Total_Views"]
        published = df.loc[i,"Published"]
        title = df.loc[i,"Title"].replace("'","").replace('"',"").replace(']',"")\
        .replace('[',"").replace('\\',"").replace("%","").replace("`","")
        category = df.loc[i,"Category"]
        duration = df.loc[i,"Duration"]
        views = df.loc[i,"Views"]
        likes = df.loc[i,"Likes"]
        dislikes = df.loc[i,"Dislikes"]
        paid = df.loc[i,"Paid"]
        family_friendly = df.loc[i,"Family_Friendly"]
        url =  df.loc[i,"URL"]

        connection.execute(f"INSERT INTO {artist_db_name}\
        (SCRAPE_DATE, SEARCH_NAME, ARTIST, PUBLISHED, TITLE, CATEGORY , DURATION,\
        VIEWS, LIKES, DISLIKES, PAID, FAMILY_FRIENDLY, URL)\
        VALUES ('{scrape_date}','{search_name}', '{artist}', '{published}', '{title}', '{category}',\
        '{duration}', '{views}', '{likes}', '{dislikes}', '{paid}',\
        '{family_friendly}', '{url}')")

    connection.execute(f"INSERT INTO artists \
    (SCRAPE_DATE, TABLE_NAME, SEARCH_NAME, ARTIST, JOINED, SUBSCRIBERS, TOTAL_VIEWS)\
    VALUES ('{scrape_date}', '{table_name}','{search_name}', '{artist}', '{joined}', '{subscribers}',\
    '{total_views}')")

    print("Inserted data into database successfully...")

    # View Data
    display(df)
# Out:
# C:\Users\587281\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
# Enter Youtuber's Name: ariana grande breathin
# ariana grande breathin
# How far back in time do you want to go? (YYYY-MM-DD) or (all-time): all-time
# all-time
# https://www.youtube.com/results?search_query=ariana+grande+breathin
# https://www.youtube.com/channel/UC9CoOnJkIBMdeijd9qYoT_g/videos
# https://www.youtube.com/channel/UC9CoOnJkIBMdeijd9qYoT_g/about
# Artist: Ariana Grande`
# Subscribers: 29712247
# Views: 10831102420
# Joined: 2007-01-21 00:00:00
# Not found in database
# https://www.youtube.com/playlist?list=UU9CoOnJkIBMdeijd9qYoT_g
# https://www.youtube.com/watch?v=7_rftpd0u0U&list=UU9CoOnJkIBMdeijd9qYoT_g
# Total videos: 122
# Getting urls...
# 0.82% complete...
# 1.64% complete...
# 2.46% complete...
# 3.28% complete...
# 4.1% complete...
# Skipped https://www.youtube.com/watch?v=-qdIaCrCa08...
# Skipped https://www.youtube.com/watch?v=GrQVvyIt9wA...
# 6.67% complete...
# 7.5% complete...
# 8.33% complete...
# 9.17% complete...
# 10.0% complete...
# 10.83% complete...
# 11.67% complete...
# 12.5% complete...
# 13.33% complete...
# 14.17% complete...
# 15.0% complete...
# 15.83% complete...
# 16.67% complete...
# 17.5% complete...
# 18.33% complete...
# 19.17% complete...
# 20.0% complete...
# 20.83% complete...
# 21.67% complete...
# 22.5% complete...
# 23.33% complete...
# 24.17% complete...
# 25.0% complete...
# 25.83% complete...
# 26.67% complete...
# 27.5% complete...
# 28.33% complete...
# 29.17% complete...
# 30.0% complete...
# 30.83% complete...
# 31.67% complete...
# 32.5% complete...
# 33.33% complete...
# 34.17% complete...
# 35.0% complete...
# 35.83% complete...
# 36.67% complete...
# 37.5% complete...
# 38.33% complete...
# 39.17% complete...
# 40.0% complete...
# 40.83% complete...
# 41.67% complete...
# 42.5% complete...
# 43.33% complete...
# 44.17% complete...
# 45.0% complete...
# 45.83% complete...
# 46.67% complete...
# 47.5% complete...
# 48.33% complete...
# 49.17% complete...
# 50.0% complete...
# 50.83% complete...
# 51.67% complete...
# 52.5% complete...
# 53.33% complete...
# 54.17% complete...
# 55.0% complete...
# 55.83% complete...
# 56.67% complete...
# 57.5% complete...
# 58.33% complete...
# 59.17% complete...
# 60.0% complete...
# 60.83% complete...
# 61.67% complete...
# 62.5% complete...
# 63.33% complete...
# 64.17% complete...
# 65.0% complete...
# 65.83% complete...
# 66.67% complete...
# 67.5% complete...
# 68.33% complete...
# 69.17% complete...
# 70.0% complete...
# 70.83% complete...
# 71.67% complete...
# 72.5% complete...
# 73.33% complete...
# 74.17% complete...
# 75.0% complete...
# 75.83% complete...
# 76.67% complete...
# 77.5% complete...
# 78.33% complete...
# 79.17% complete...
# 80.0% complete...
# 80.83% complete...
# 81.67% complete...
# 82.5% complete...
# 83.33% complete...
# 84.17% complete...
# 85.0% complete...
# 85.83% complete...
# 86.67% complete...
# 87.5% complete...
# 88.33% complete...
# 89.17% complete...
# 90.0% complete...
# 90.83% complete...
# 91.67% complete...
# 92.5% complete...
# 93.33% complete...
# 94.17% complete...
# 95.0% complete...
# 95.83% complete...
# 96.67% complete...
# 97.5% complete...
# 98.33% complete...
# 99.17% complete...
# 100.0% complete...
# Skipped https://www.youtube.com/watch?v=o5e-x9Bcsgc...
# Skipped https://www.youtube.com/watch?v=o5e-x9Bcsgc...
# Inserting data into database...
# Inserted data into database successfully...
#              Artist                Scrape_Date             Search_Name  \
# 0    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 1    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 2    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 3    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 4    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 5    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 6    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 7    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 8    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 9    Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 10   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 11   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 12   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 13   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 14   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 15   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 16   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 17   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 18   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 19   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 20   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 21   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 22   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 23   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 24   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 25   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 26   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 27   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 28   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 29   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 30   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 31   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 32   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 33   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 34   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 35   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 36   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 37   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 38   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 39   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 40   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 41   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 42   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 43   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 44   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 45   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 46   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 47   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 48   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 49   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 50   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 51   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 52   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 53   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 54   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 55   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 56   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 57   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 58   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 59   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 60   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 61   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 62   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 63   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 64   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 65   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 66   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 67   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 68   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 69   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 70   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 71   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 72   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 73   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 74   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 75   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 76   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 77   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 78   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 79   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 80   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 81   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 82   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 83   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 84   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 85   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 86   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 87   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 88   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 89   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 90   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 91   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 92   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 93   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 94   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 95   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 96   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 97   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 98   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 99   Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 100  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 101  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 102  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 104  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 103  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 105  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 106  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 107  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 108  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 109  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 110  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 111  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 112  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 113  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 114  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 115  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 116  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
# 117  Ariana Grande` 2018-12-18 16:08:18.026248  ariana grande breathin
#
#         Joined  Subscribers  Total_Views  Published  \
# 0   2007-01-21     29712247  10831102420 2018-12-13
# 1   2007-01-21     29712247  10831102420 2018-12-11
# 2   2007-01-21     29712247  10831102420 2018-12-07
# 3   2007-01-21     29712247  10831102420 2018-12-02
# 4   2007-01-21     29712247  10831102420 2018-11-29
# 5   2007-01-21     29712247  10831102420 2018-11-28
# 6   2007-01-21     29712247  10831102420 2018-11-27
# 7   2007-01-21     29712247  10831102420 2018-11-27
# 8   2007-01-21     29712247  10831102420 2018-11-06
# 9   2007-01-21     29712247  10831102420 2018-11-03
# 10  2007-01-21     29712247  10831102420 2018-10-10
# 11  2007-01-21     29712247  10831102420 2018-08-23
# 12  2007-01-21     29712247  10831102420 2018-07-23
# 13  2007-01-21     29712247  10831102420 2018-07-19
# 14  2007-01-21     29712247  10831102420 2018-07-12
# 15  2007-01-21     29712247  10831102420 2018-05-25
# 16  2007-01-21     29712247  10831102420 2018-04-27
# 17  2007-01-21     29712247  10831102420 2018-04-23
# 18  2007-01-21     29712247  10831102420 2016-11-17
# 19  2007-01-21     29712247  10831102420 2015-11-02
# 20  2007-01-21     29712247  10831102420 2014-09-30
# 21  2007-01-21     29712247  10831102420 2014-07-07
# 22  2007-01-21     29712247  10831102420 2014-07-02
# 23  2007-01-21     29712247  10831102420 2013-12-27
# 24  2007-01-21     29712247  10831102420 2013-12-19
# 25  2007-01-21     29712247  10831102420 2013-11-19
# 26  2007-01-21     29712247  10831102420 2013-11-15
# 27  2007-01-21     29712247  10831102420 2013-11-15
# 28  2007-01-21     29712247  10831102420 2013-11-14
# 29  2007-01-21     29712247  10831102420 2013-11-09
# 30  2007-01-21     29712247  10831102420 2013-10-31
# 31  2007-01-21     29712247  10831102420 2013-10-21
# 32  2007-01-21     29712247  10831102420 2013-10-04
# 33  2007-01-21     29712247  10831102420 2013-10-04
# 34  2007-01-21     29712247  10831102420 2013-10-01
# 35  2007-01-21     29712247  10831102420 2013-09-27
# 36  2007-01-21     29712247  10831102420 2013-09-08
# 37  2007-01-21     29712247  10831102420 2013-09-08
# 38  2007-01-21     29712247  10831102420 2013-09-08
# 39  2007-01-21     29712247  10831102420 2013-09-08
# 40  2007-01-21     29712247  10831102420 2013-09-07
# 41  2007-01-21     29712247  10831102420 2013-09-06
# 42  2007-01-21     29712247  10831102420 2013-09-05
# 43  2007-01-21     29712247  10831102420 2013-09-05
# 44  2007-01-21     29712247  10831102420 2013-08-15
# 45  2007-01-21     29712247  10831102420 2013-08-09
# 46  2007-01-21     29712247  10831102420 2013-08-06
# 47  2007-01-21     29712247  10831102420 2013-07-29
# 48  2007-01-21     29712247  10831102420 2013-07-22
# 49  2007-01-21     29712247  10831102420 2013-06-17
# 50  2007-01-21     29712247  10831102420 2013-05-25
# 51  2007-01-21     29712247  10831102420 2013-05-06
# 52  2007-01-21     29712247  10831102420 2013-04-23
# 53  2007-01-21     29712247  10831102420 2013-03-26
# 54  2007-01-21     29712247  10831102420 2013-03-21
# 55  2007-01-21     29712247  10831102420 2013-03-16
# 56  2007-01-21     29712247  10831102420 2013-01-23
# 57  2007-01-21     29712247  10831102420 2013-01-10
# 58  2007-01-21     29712247  10831102420 2013-01-04
# 59  2007-01-21     29712247  10831102420 2012-12-27
# 60  2007-01-21     29712247  10831102420 2012-12-25
# 61  2007-01-21     29712247  10831102420 2012-11-18
# 62  2007-01-21     29712247  10831102420 2012-10-27
# 63  2007-01-21     29712247  10831102420 2012-10-08
# 64  2007-01-21     29712247  10831102420 2012-09-06
# 65  2007-01-21     29712247  10831102420 2012-08-18
# 66  2007-01-21     29712247  10831102420 2012-07-26
# 67  2007-01-21     29712247  10831102420 2012-07-11
# 68  2007-01-21     29712247  10831102420 2012-07-01
# 69  2007-01-21     29712247  10831102420 2012-05-26
# 70  2007-01-21     29712247  10831102420 2012-04-21
# 71  2007-01-21     29712247  10831102420 2012-03-21
# 72  2007-01-21     29712247  10831102420 2012-03-20
# 73  2007-01-21     29712247  10831102420 2012-03-18
# 74  2007-01-21     29712247  10831102420 2011-12-23
# 75  2007-01-21     29712247  10831102420 2011-08-08
# 76  2007-01-21     29712247  10831102420 2011-06-08
# 77  2007-01-21     29712247  10831102420 2011-02-27
# 78  2007-01-21     29712247  10831102420 2010-08-23
# 79  2007-01-21     29712247  10831102420 2009-10-23
# 80  2007-01-21     29712247  10831102420 2009-08-11
# 81  2007-01-21     29712247  10831102420 2009-08-11
# 82  2007-01-21     29712247  10831102420 2009-07-11
# 83  2007-01-21     29712247  10831102420 2009-06-25
# 84  2007-01-21     29712247  10831102420 2009-03-06
# 85  2007-01-21     29712247  10831102420 2008-12-07
# 86  2007-01-21     29712247  10831102420 2008-10-22
# 87  2007-01-21     29712247  10831102420 2008-02-07
# 88  2007-01-21     29712247  10831102420 2007-12-11
# 89  2007-01-21     29712247  10831102420 2007-06-15
# 90  2007-01-21     29712247  10831102420 2007-06-06
# 91  2007-01-21     29712247  10831102420 2007-05-11
# 92  2007-01-21     29712247  10831102420 2007-05-07
# 93  2007-01-21     29712247  10831102420 2007-05-05
# 94  2007-01-21     29712247  10831102420 2007-04-22
# 95  2007-01-21     29712247  10831102420 2007-04-14
# 96  2007-01-21     29712247  10831102420 2007-04-10
# 97  2007-01-21     29712247  10831102420 2007-04-09
# 98  2007-01-21     29712247  10831102420 2007-04-08
# 99  2007-01-21     29712247  10831102420 2007-04-07
# 100 2007-01-21     29712247  10831102420 2007-04-07
# 101 2007-01-21     29712247  10831102420 2007-04-07
# 102 2007-01-21     29712247  10831102420 2007-04-05
# 104 2007-01-21     29712247  10831102420 2007-04-01
# 103 2007-01-21     29712247  10831102420 2007-04-01
# 105 2007-01-21     29712247  10831102420 2007-03-26
# 106 2007-01-21     29712247  10831102420 2007-03-25
# 107 2007-01-21     29712247  10831102420 2007-03-24
# 108 2007-01-21     29712247  10831102420 2007-03-16
# 109 2007-01-21     29712247  10831102420 2007-03-15
# 110 2007-01-21     29712247  10831102420 2007-03-15
# 111 2007-01-21     29712247  10831102420 2007-03-14
# 112 2007-01-21     29712247  10831102420 2007-03-13
# 113 2007-01-21     29712247  10831102420 2007-03-03
# 114 2007-01-21     29712247  10831102420 2007-02-02
# 115 2007-01-21     29712247  10831102420 2007-01-22
# 116 2007-01-21     29712247  10831102420 2007-01-22
# 117 2007-01-21     29712247  10831102420 2007-01-22
#
#                                                  Title        Category  \
# 0                Ariana Grande - imagine (lyric video)           Music
# 1    Ariana Grande - thank u, next (behind the scen...           Music
# 2    Ariana Grande - thank u, next (behind the scen...           Music
# 3    Ariana Grande - thank u, next (behind the scen...           Music
# 4    thank u, next - video (behind the scenes sneak...           Music
# 5    Ariana Grande: Dangerous Woman Diaries - Offic...           Music
# 6                Ariana Grande - thank u, next (clean)           Music
# 7              Ariana Grande - thank u, next (trailer)           Music
# 8          Ariana Grande - thank u, next (lyric video)           Music
# 9                Ariana Grande - thank u, next (audio)           Music
# 10                            Ariana Grande - breathin           Music
# 11                    Ariana Grande - breathin (audio)           Music
# 12   Ariana Grande - God is a woman (behind the sce...           Music
# 13   Ariana Grande - God is a woman (behind the sce...           Music
# 14        Ariana Grande - God is a woman (Lyric Video)           Music
# 15   Ariana Grande - No Tears Left To Cry (BTS - Pa...           Music
# 16   Ariana Grande - No Tears Left To Cry (BTS - Pa...           Music
# 17   Ariana Grande - No Tears Left To Cry (BTS - Pa...           Music
# 18    Sweet Like Candy (Official Fragrance Commercial)           Music
# 19                 Focus - Ariana Grande (Lyric Video)           Music
# 20            Google: Hangout w/ Ariana Grande 9/30/14           Music
# 21   Ariana Grande - Break Free (Lyric Video) Feat....           Music
# 22       Ariana Grande - Break Free feat. Zedd (Audio)           Music
# 23                     honeymoon ave - lullaby edition           Music
# 24                  November / December month video :)   Entertainment
# 25                      Last Christmas - Ariana Grande           Music
# 26   ariana singing be alright - justin bieber #lul...           Music
# 27   Ariana Grande Gets Flash'd by Todrick Hall   E...           Music
# 28              Ariana Grande Defends Cyrus and Bieber           Music
# 29   Ariana singing Heart of The Matter #LullabyFriday           Music
# 30       MTV EMA Backstage Experience w/ Ariana Grande           Music
# 31               Popular Song - Dancing With The Stars           Music
# 32   Private Party - Ariana Grande (India Arie cove...           Music
# 33                  Right There - Red Bull Sound Space           Music
# 34                      pink champagne - ariana grande           Music
# 35   Where The Boys Are - Ariana Grande (Connie Fra...           Music
# 36                          Tattooed Heart: Today Show           Music
# 37                                 The Way: Today Show           Music
# 38   Singing 'Almost Is Never Enough' On 'Live With...           Music
# 39                Me on Jimmy Fallon singing rap songs           Music
# 40                  Right There (live) - Ariana Grande           Music
# 41                            My interview with Hot 97           Music
# 42       My album is out omsdafgalksjf - Ariana Grande           Music
# 43               Ariana Grande - Baby I (Video Teaser)           Music
# 44               Tattooed Heart (live) - Ariana Grande           Music
# 45   Ariana Grande - The Way & Baby I acoustic with...           Music
# 46        Right There - Ariana Grande (feat. Big Sean)           Music
# 47       Ariana Grande - Baby I (Official Lyric Video)           Music
# 48                              Ariana Grande - Baby I           Music
# 49   Ariana Grande and Mac Miller Perform The Way l...           Music
# 50                           The Way Behind The Scenes           Music
# 51          Ariana Grande singing The Way on Z100 live           Music
# 52               Ariana Grande - I Believe In You & Me           Music
# 53   Ariana Grande ft Mac Miller 'The Way' Official...           Music
# 54   The Way - Ariana Grande feat. Mac Miller 20 se...           Music
# 55   The Way - Ariana Grande feat. Mac Miller (Firs...           Music
# 56   "Just For Now" - Ariana Grande ( Imogen Heap c...   Entertainment
# 57             Ariana singing Sweet Life - Frank Ocean   Entertainment
# 58       Popular Song - Mika (featuring Ariana Grande)   Entertainment
# 59                                             You say   Entertainment
# 60   Larry Lovestein (Mac Miller) and Ariana Grande...   Entertainment
# 61   Me singing I Believe in You and Me by Whitney ...           Music
# 62   Makeup tutorial by Ariana Grande (I don't know...           Music
# 63        Chubby Bunny Challenge - Jennette and Ariana           Music
# 64       Emotions - Ariana Grande (Mariah Carey cover)           Music
# 65   Ariana Grande - Gimme Some Lovin (The Spencer ...           Music
# 66   Ariana Grande - Die In Your Arms cover (Justin...           Music
# 67   Matt and me singing I Think You're Swell at Me...           Music
# 68   Take care preview.. Leon Thomas III feat Arian...           Music
# 69   Reflection - Ariana Grande (Fetus Grande at 11...           Music
# 70             I got a tattooed heart! - Ariana Grande           Music
# 71                   Old School Videos - Ariana Grande           Music
# 72   Frank Meets Babe - How my grandparents fell in...           Music
# 73                        Frankie sings the hits. LOL.           Music
# 74     "Chestnuts"  Merry Christmas! Love, Ari and Liz           Music
# 75   Frankie celebrates 30,000 followers! @frankiej...          Comedy
# 76   Ariana Grande at 8 years old singing National ...           Music
# 77   Born This Way / Express Yourself - Ariana Gran...           Music
# 78   5 minute total body workout. best friends. Ari...           Music
# 79                       A fun little video we made :]   Entertainment
# 80                       Verrry very Next to Normal :]           Music
# 81   Me taking pics of a Lion / Sorry we don't have...   Entertainment
# 82                      ABC - Broadway In South Africa   Entertainment
# 83    ABC - A Michael Jackson tribute by Ariana Grande           Music
# 84    O Holy Night - Graham Phillips and Ariana Grande           Music
# 85                                let it rain!!!!!.m4v           Music
# 86                              Higher - Ariana Grande           Music
# 87    Suddenly Seymour by Ariana (14) and Frankie (25)           Music
# 88                       "There's Hope"- Ariana Grande           Music
# 89                              Uncle Duke and Grandpa  People & Blogs
# 90                                          Mean Girls          Comedy
# 91                                  Freaky Forever 3-5          Comedy
# 92                         and yet..even more bloopers          Comedy
# 93                             yet..even more bloopers          Comedy
# 94                                  Freaky Forever 3-4          Comedy
# 95                            School Project: DOLPHINS          Comedy
# 96                                  Freaky Forever 3-3          Comedy
# 97                                  Freaky Forever 3-2          Comedy
# 98                                  Freaky Forever 3-1          Comedy
# 99                                 Even More Bloopers!          Comedy
# 100                    Freaky Forever Season 3 trailer          Comedy
# 101                                 Freaky Forever 2-5          Comedy
# 102                                 Freaky Forever 2-4          Comedy
# 104                                 Freaky Forever 2-2          Comedy
# 103                                 Freaky Forever 2-3          Comedy
# 105                                      More Bloopers          Comedy
# 106                                 Freaky Forever 2-1          Comedy
# 107                                 Freaky Forever 1-4          Comedy
# 108                         Freaky Forever episode 1-3          Comedy
# 109                            FREAKY FOREVER BLOOPERS          Comedy
# 110                         Freaky Forever episode 1-2          Comedy
# 111                         Freaky Forever episode 1-1          Comedy
# 112                               freaky forever:PILOT          Comedy
# 113                                            wannabe          Comedy
# 114                                    its not unusual          Comedy
# 115                               dancing grandparents          Comedy
# 116                                              Shoes          Comedy
# 117                                 Ain't No Other Man          Comedy
#
#       Duration     Views    Likes  Dislikes   Paid Family_Friendly  \
# 0     3.533333   7887642   572973     13269  False            True
# 1    12.166667   1648666    90135      1101  False            True
# 2    11.500000   1715268   107878       786  False            True
# 3     9.766667   3487661   241565      1855  False            True
# 4     3.450000   6939745   479595      2816  False            True
# 5     1.016667   8974291   143721      3311  False            True
# 6     3.466667   4955691   124918      1268  False            True
# 7     4.100000   3838893   299690      3854  False            True
# 8     3.466667  55354934  1242790     26224  False            True
# 9     3.466667  62154613  1265161     31329  False            True
# 10    3.316667   6296329   417122     15149  False            True
# 11    3.283333  83665098   739120     16158  False            True
# 12    9.366667   3315198   217653      3702  False            True
# 13    0.650000   1424465   118581      2091  False            True
# 14    3.433333  79987407   962169     53939  False            True
# 15   11.333333   1503521    86126       981  False            True
# 16    8.083333   3403765   160453      1769  False            True
# 17    5.433333   6316854   288055      3271  False            True
# 18    0.516667   1705796    64523      1013  False            True
# 19    3.583333   1474183    26909       925  False            True
# 20    1.933333   1164559    23573       769  False            True
# 21    3.766667   4219251    34169      1218  False            True
# 22    3.583333  22776227   122582      3208  False            True
# 23    3.300000   4309410   146354      2190  False            True
# 24    4.683333   1191783    38103       510  False            True
# 25    3.716667   1307780    23358       406  False            True
# 26    3.300000   3114154   100447      2350  False            True
# 27    7.916667  11345297   167287      2862  False            True
# 28    1.700000   1544950    59336      2213  False            True
# 29    3.066667    935751    33334       739  False           False
# 30    0.516667    601357    18403       262  False            True
# 31    2.933333   1770513    38303       469  False            True
# 32    2.616667    741820    25210       445  False            True
# 33    4.166667    455673    22915       162  False            True
# 34    4.883333    864678    38772       368  False            True
# 35    3.533333    659706    29866       428  False            True
# 36    3.450000    957316    25399       287  False            True
# 37    4.233333    316318    13419       153  False            True
# 38    4.550000    207307     7912       101  False            True
# 39    3.150000   6406605    98945      1104  False            True
# 40    4.150000    413105    13411       177  False            True
# 41   20.483333    257308    10419       119  False            True
# 42    1.716667    478110    24109       216  False            True
# 43    0.483333    618184    24736       281  False            True
# 44    3.450000    672012    24009       237  False            True
# 45    6.083333   4324994    86909      1302  False            True
# 46    4.133333   3788032    62766      1151  False            True
# 47    3.433333   1406710    23966       441  False            True
# 48    3.300000   6099887    54475      1305  False            True
# 49    4.266667    908112    20435       313  False            True
# 50    2.716667   1618016    24104       275  False            True
# 51    1.233333    851389    37585       252  False            True
# 52    3.333333   2438228    62851       829  False            True
# 53    3.950000   9436205    67842      1067  False            True
# 54    0.366667   1771157    18386       502  False            True
# 55    0.616667   1262658    18546       295  False            True
# 56    4.483333   2097791    65245       697  False            True
# 57    2.483333    914348    24578       527  False            True
# 58    3.283333   1453062    18236       323  False            True
# 59    4.383333    855439    17326       337  False            True
# 60    3.466667   1115675    44891       330  False            True
# 61    4.216667    846703    21311       357  False            True
# 62    7.950000  21069716   302821     14898  False            True
# 63    1.783333   2522661    44034       789  False            True
# 64    4.583333  28799560   437863      8042  False            True
# 65    2.133333   1603488    37436       564  False            True
# 66    4.233333  12186216   205893      2917  False            True
# 67    4.250000    500018    12103       130  False            True
# 68    1.316667    421696    10842        95  False            True
# 69    1.916667   1376014    37206       304  False            True
# 70    3.883333   1748049    25273       505  False            True
# 71    5.966667   3523599    65431       901  False            True
# 72    3.183333    243793     8167        56  False            True
# 73    2.100000    307658     8540        98  False            True
# 74    3.116667   1846435    36016       278  False            True
# 75    0.916667    320515     3747       119  False            True
# 76    2.133333   4787968    69400      1239  False            True
# 77    3.483333   2237167    30318       633  False            True
# 78    3.500000    854409    13404       176  False            True
# 79    1.916667   2639018    41249       286  False            True
# 80    1.666667   1860081    22011       253  False            True
# 81    0.283333    167220     2686        15  False            True
# 82    1.416667     97758     2611        14  False            True
# 83    1.283333    277332     6414        34  False            True
# 84    3.566667    330559     5229        37  False            True
# 85    1.383333    291013     5226        72  False            True
# 86    2.083333   1496765    18997       176  False            True
# 87    3.450000    435279     8610        51  False            True
# 88    4.050000    868273    21332       143  False            True
# 89    2.300000     74193     2290        13  False            True
# 90    3.583333    997645    45807       304  False            True
# 91    3.266667     76839     1652        19  False            True
# 92    2.433333     91896     2027        15  False            True
# 93    2.600000    197110     3103        24  False            True
# 94    2.933333     53863     1551        13  False            True
# 95    4.616667    425924     6329        66  False            True
# 96    4.016667    121585     1958        30  False            True
# 97    2.683333    129805     2276        26  False            True
# 98    2.383333     73886     1860        18  False            True
# 99    2.733333     79634     1934        22  False            True
# 100   0.866667     73932     1589        22  False            True
# 101   4.383333     53848     1952        16  False            True
# 102   2.350000     86699     2140        27  False            True
# 104   2.366667    127992     2867        50  False            True
# 103   2.416667     77249     1837        11  False            True
# 105   1.450000    165318     2891        23  False            True
# 106   2.616667    106016     2153        15  False            True
# 107   2.666667    143720     2893        28  False            True
# 108   1.600000    177145     3371        30  False            True
# 109   1.050000    149065     3179        20  False            True
# 110   1.983333    279027     5128        39  False            True
# 111   1.950000    388333     6315        60  False            True
# 112   2.150000    260303     6475        49  False            True
# 113   1.283333   1739973   166289      1259  False            True
# 114   2.083333    342387     6412        73  False            True
# 115   2.800000    234112     8286        60  False            True
# 116   2.833333    841385    18291       378  False            True
# 117   3.600000   1010581    26370       310  False            True
#
#                                              URL
# 0    https://www.youtube.com/watch?v=7_rftpd0u0U
# 1    https://www.youtube.com/watch?v=o38V48OpPaU
# 2    https://www.youtube.com/watch?v=YQTATmS3_NQ
# 3    https://www.youtube.com/watch?v=eTqyt2rqNtg
# 4    https://www.youtube.com/watch?v=gLU3Ad2zuSQ
# 5    https://www.youtube.com/watch?v=GrQVvyIt9wA
# 6    https://www.youtube.com/watch?v=ll4PiBEWFvI
# 7    https://www.youtube.com/watch?v=_TAAICRcgac
# 8    https://www.youtube.com/watch?v=LdeIHC2EGCE
# 9    https://www.youtube.com/watch?v=prvDemxqJIY
# 10   https://www.youtube.com/watch?v=EEhZAHZQyf4
# 11   https://www.youtube.com/watch?v=5OeR5XBEahU
# 12   https://www.youtube.com/watch?v=QTPW_cIYp9o
# 13   https://www.youtube.com/watch?v=1BYr1br2Ee4
# 14   https://www.youtube.com/watch?v=R-WlE-DkwbI
# 15   https://www.youtube.com/watch?v=6R30CVohvdY
# 16   https://www.youtube.com/watch?v=RQTgJRwMdKQ
# 17   https://www.youtube.com/watch?v=bYOxsDiof3c
# 18   https://www.youtube.com/watch?v=J1Cazzj9HWE
# 19   https://www.youtube.com/watch?v=T4FAg5A4wQk
# 20   https://www.youtube.com/watch?v=eNSxmqCza6Y
# 21   https://www.youtube.com/watch?v=KdPpZyCJNyg
# 22   https://www.youtube.com/watch?v=cTgxlpS2L-o
# 23   https://www.youtube.com/watch?v=hFchgev8mjc
# 24   https://www.youtube.com/watch?v=2Ek3WMM7I-0
# 25   https://www.youtube.com/watch?v=dxhIERpCWAM
# 26   https://www.youtube.com/watch?v=DzIUXePx9Xc
# 27   https://www.youtube.com/watch?v=CYSWgsUQt1U
# 28   https://www.youtube.com/watch?v=jyQcjGYiiic
# 29   https://www.youtube.com/watch?v=qNM3_q2MN6s
# 30   https://www.youtube.com/watch?v=QMU68w_OjxQ
# 31   https://www.youtube.com/watch?v=mToFFlJO1mc
# 32   https://www.youtube.com/watch?v=DVSdItO8aMw
# 33   https://www.youtube.com/watch?v=9dVJYQbO720
# 34   https://www.youtube.com/watch?v=datIdc79HJM
# 35   https://www.youtube.com/watch?v=n5Q8tHNHFOk
# 36   https://www.youtube.com/watch?v=GOq2RBVKPsU
# 37   https://www.youtube.com/watch?v=nHeUK7smsXU
# 38   https://www.youtube.com/watch?v=y09dhGlWHqw
# 39   https://www.youtube.com/watch?v=-vLwPhceKz0
# 40   https://www.youtube.com/watch?v=TkNSDPdHMto
# 41   https://www.youtube.com/watch?v=BIL1tDvnH4c
# 42   https://www.youtube.com/watch?v=ZAQ-2YM4nM8
# 43   https://www.youtube.com/watch?v=CT0VaEWBmcw
# 44   https://www.youtube.com/watch?v=7AFOl_PXia4
# 45   https://www.youtube.com/watch?v=kdKS4DuNNHU
# 46   https://www.youtube.com/watch?v=Bw5sNleirKM
# 47   https://www.youtube.com/watch?v=zF6__myqK2E
# 48   https://www.youtube.com/watch?v=TiiRTYRg-qU
# 49   https://www.youtube.com/watch?v=jSl4pu_w7SI
# 50   https://www.youtube.com/watch?v=4QkbfSPPUX0
# 51   https://www.youtube.com/watch?v=nBCP89PM97M
# 52   https://www.youtube.com/watch?v=fQZWz90ek9s
# 53   https://www.youtube.com/watch?v=4rs1ZihNoVg
# 54   https://www.youtube.com/watch?v=G-ud5wQeOCk
# 55   https://www.youtube.com/watch?v=2O3AOhEufyo
# 56   https://www.youtube.com/watch?v=JyiCs_45jWo
# 57   https://www.youtube.com/watch?v=3BXyMy2AGdI
# 58   https://www.youtube.com/watch?v=syw1L7_JYf0
# 59   https://www.youtube.com/watch?v=ZGjnklNv5po
# 60   https://www.youtube.com/watch?v=dbSjUAX3jJk
# 61   https://www.youtube.com/watch?v=4VyCoCTQypU
# 62   https://www.youtube.com/watch?v=di8fRzvfM_0
# 63   https://www.youtube.com/watch?v=DftuqJZAoqk
# 64   https://www.youtube.com/watch?v=bCdETAW4-N4
# 65   https://www.youtube.com/watch?v=s0BIYOuY-Mw
# 66   https://www.youtube.com/watch?v=UjzENV7rhhI
# 67   https://www.youtube.com/watch?v=yymDpUH32jM
# 68   https://www.youtube.com/watch?v=ewnhncpo64o
# 69   https://www.youtube.com/watch?v=fBCnrcwKg7Y
# 70   https://www.youtube.com/watch?v=j32fFzEXat8
# 71   https://www.youtube.com/watch?v=XBqV23kifcg
# 72   https://www.youtube.com/watch?v=ZhmHn_ewp94
# 73   https://www.youtube.com/watch?v=hHsavBv3C2c
# 74   https://www.youtube.com/watch?v=mFiLpdAnZZk
# 75   https://www.youtube.com/watch?v=Kg0RWTdePhQ
# 76   https://www.youtube.com/watch?v=OervLMQvGx4
# 77   https://www.youtube.com/watch?v=62bwXrWTMuU
# 78   https://www.youtube.com/watch?v=QEwwhklDbVo
# 79   https://www.youtube.com/watch?v=u8SoTkp52mQ
# 80   https://www.youtube.com/watch?v=Vk_5jXxy-Ac
# 81   https://www.youtube.com/watch?v=wtGM6tMOVBw
# 82   https://www.youtube.com/watch?v=YxqS63HwZak
# 83   https://www.youtube.com/watch?v=xIjMdrNK5VQ
# 84   https://www.youtube.com/watch?v=L7lcCJP_r58
# 85   https://www.youtube.com/watch?v=bQdQy_Bkw3Q
# 86   https://www.youtube.com/watch?v=IPrGgMwamDc
# 87   https://www.youtube.com/watch?v=ge4kSZU-0vw
# 88   https://www.youtube.com/watch?v=E3ZPSNZ8zdc
# 89   https://www.youtube.com/watch?v=sVySRyYWpfM
# 90   https://www.youtube.com/watch?v=_sEjGp2WmDA
# 91   https://www.youtube.com/watch?v=3B5FLAl1rCw
# 92   https://www.youtube.com/watch?v=AofGquXf9Jo
# 93   https://www.youtube.com/watch?v=2jD7qfks2_Q
# 94   https://www.youtube.com/watch?v=_JNvkLxZklA
# 95   https://www.youtube.com/watch?v=YNagJjGRDi0
# 96   https://www.youtube.com/watch?v=4tJw0-FYLkw
# 97   https://www.youtube.com/watch?v=Kr0w6PuIn_k
# 98   https://www.youtube.com/watch?v=4YfYDLjq_8g
# 99   https://www.youtube.com/watch?v=s_EoNtTQeuc
# 100  https://www.youtube.com/watch?v=8tatzR_p7o0
# 101  https://www.youtube.com/watch?v=wJ1CngkRdJI
# 102  https://www.youtube.com/watch?v=73wPIA9DS7U
# 104  https://www.youtube.com/watch?v=HLHegkLuanQ
# 103  https://www.youtube.com/watch?v=KWHmIOy8Nzg
# 105  https://www.youtube.com/watch?v=tMTkKGFP6Lo
# 106  https://www.youtube.com/watch?v=ojn_nFTedvI
# 107  https://www.youtube.com/watch?v=0Jag5EOENq8
# 108  https://www.youtube.com/watch?v=NaaKjAkxI9c
# 109  https://www.youtube.com/watch?v=S9YiD_qzCP8
# 110  https://www.youtube.com/watch?v=JNshDndYB5I
# 111  https://www.youtube.com/watch?v=nWwkJG8dsDE
# 112  https://www.youtube.com/watch?v=ZoiONqHI8fA
# 113  https://www.youtube.com/watch?v=X_KgIsYMKy8
# 114  https://www.youtube.com/watch?v=G2r2YetPO0c
# 115  https://www.youtube.com/watch?v=SaF-hAQA99Y
# 116  https://www.youtube.com/watch?v=LBKoSOPUMFE
# 117  https://www.youtube.com/watch?v=qXj9Lw7Geg8
