# %%
# Import Dependencies
from bs4 import BeautifulSoup as bs
import requests
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
pd.set_option('display.max_rows', 200)

# %%
converted_date = ""
raw_months = {"Jan": 1, "Feb": 2, "Mar" : 3, "Apr" : 4, 
              "May" : 5, "Jun" : 6, "Jul" : 7, "Aug" : 8,
              "Sep" : 9, "Oct" : 10, "Nov" : 11, "Dec" : 12}

# Convert Date from Jan 1, 1999 format to datetime object
def convertDate(raw_date):
    
    converted_date = ""
    
    temp_date = raw_date.split(" ")
    
    number_month = raw_months.get(temp_date[0])
    
    date_str = (str(number_month) + "/" + temp_date[1] + "/" + temp_date[2]).replace(",", "")
    
    converted_date = datetime.strptime(date_str, '%m/%d/%Y')
    
    return converted_date

# %%
input_name = input("Enter Youtuber's Name: ")

list_name = input_name.split()

converted_name = input_name

if len(list_name) > 1:
    
    converted_name = ""
    
    for i in range(len(list_name)):

        converted_name = converted_name + list_name[i]
        
        if i != len(list_name)-1:
            converted_name = converted_name + "+"

search_name = converted_name

start_url = "https://www.youtube.com/results?search_query=" + search_name
# Out:
# Enter Youtuber's Name: gibi asmr

# %%
print(start_url)
get_youtube_url_response = requests.get(start_url)
# Out:
# https://www.youtube.com/results?search_query=gibi+asmr

# %%
youtube_name_soup = bs(get_youtube_url_response.text, "lxml")

# %%
raw_youtube_name_link = youtube_name_soup.find_all("div", class_="yt-lockup-byline")[0].a.get("href")

videos_link = "https://www.youtube.com" + raw_youtube_name_link + "/videos"

about_link = "https://www.youtube.com" + raw_youtube_name_link + "/about"

print(raw_youtube_name_link)
print(videos_link)
print(about_link)
# Out:
# /channel/UCE6acMV3m35znLcf0JGNn7Q
# https://www.youtube.com/channel/UCE6acMV3m35znLcf0JGNn7Q/videos
# https://www.youtube.com/channel/UCE6acMV3m35znLcf0JGNn7Q/about

# %%
# Get About Information
about_html = requests.get(about_link)

# Parse HTML
about_soup = bs(about_html.text, "lxml")

# %%
# Artist Information
artist_name = about_soup.find("meta", property="og:title").get("content")

subscribers = about_soup.find_all("span", class_="about-stat")[0].text
subscribers_int = int(subscribers.split(" ")[0].replace(",",""))

total_views = about_soup.find_all("span", class_="about-stat")[1].text
total_views_int = int(total_views[3:len(total_views)].split(" ")[0].replace(",",""))

joined = about_soup.find_all("span", class_="about-stat")[2].text
joined_temp = " ".join(joined.split(" ")[1:4])
joined_convert = convertDate(joined_temp)

print(f"Artist: {artist_name}")
print(f"Subscribers: {subscribers_int}")
print(f"Views: {total_views_int}")
print(f"Joined: {joined_convert}")
# Out:
# Artist: Gibi ASMR
# Subscribers: 1525883
# Views: 381050771
# Joined: 2016-06-18 00:00:00

# %%
# Convert User Name to UU Format
youtube_code = raw_youtube_name_link.split("/")[2]

if youtube_code[0:2] == "UC":

    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + raw_youtube_name_link.split("/")[2][2:] 

elif youtube_code[0:2] != "UC":
    
    youtube_code_raw = about_soup.find("link", rel="canonical").get("href")
    
    youtube_code = youtube_code_raw.split("/")[4]
    
    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:]  
    
url = videos_link
print(playlist_link)
# Out:
# https://www.youtube.com/playlist?list=UUE6acMV3m35znLcf0JGNn7Q

# %%
# Get Playlist Response
playlist_response = requests.get(playlist_link)

# %%
# Create Soup Object
playlist_soup = bs(playlist_response.text, 'lxml')

# %%
# Get Video Titles and URLs
title_videos = []
urls = []

video_info = playlist_soup.find_all("a", class_="pl-video-title-link")

for title in video_info:
    
    title_videos.append(title.text.replace("\n      ","").replace("\n    ",""))
    
    link = "https://www.youtube.com" + title.get("href").split("&")[0]
    
    urls.append(link)

# %%
# Going to Each Video and Extracting Data
published_on = []
views = []
date = []
duration_videos = []
likes = []
dislikes = []

for i in range(len(urls)):
    
    video_url = urls[i]
    
    video_response = requests.get(video_url)
    
    video_soup = bs(video_response.text, 'lxml')
    
    # Views
    string_views = video_soup.find("div", id="watch7-views-info").text.replace(" views\n\n\n\n\n", "").replace(",","") 
    int_views = int(string_views)
    views.append(int_views)
    
#     # Duration
#     duration = video_soup.find("span", class_="video-time").text
#     duration_videos.append(duration)
    
    # Likes
    string_likes = video_soup.find("button", title="I like this").text
    int_likes = int(string_likes.replace(",",""))
    likes.append(int_likes)
    
    # Dislikes
    string_dislikes = video_soup.find("button", title="I dislike this").text
    int_dislikes = int(string_dislikes.replace(",",""))
    dislikes.append(int_dislikes)
    
    # Publish Date
    raw_publish_date = video_soup.find("div", id="watch-uploader-info").text
    
    if raw_publish_date.split(" ")[0] == "Published":
        
        publish_date = raw_publish_date.split(" ")[2:5]

        publish_date_format = " ".join(publish_date)
        
        publish_date_convert = convertDate(publish_date_format)

        published_on.append(publish_date_convert)
    
    elif raw_publish_date.split(" ")[0] == "Premiered":
        
        publish_date = raw_publish_date.split(" ")[1:4]

        publish_date_format = " ".join(publish_date)
        
        publish_date_convert = convertDate(publish_date_format)

        published_on.append(publish_date_convert)

# %%
# Create DataFrame
df = pd.DataFrame({"Artist" : artist_name,
                   "Joined" : joined_convert,
                   "Subscribers" : subscribers_int,
                   "Total Views" : total_views_int,
                   "Date": published_on,
                   "Title" : title_videos,
                   #"Duration" : duration_videos,
                   "Views" : views,
                   "Likes" : likes,
                   "Dislikes" : dislikes,
                   "URL" : urls,
                  })

df = df.sort_values("Date",ascending=False).reindex()
df
# Out:
#              Artist     Joined  Subscribers  Total Views       Date  \
# 0   Philip DeFranco 2006-09-15      6329224   2519675036 2018-12-07
# 1   Philip DeFranco 2006-09-15      6329224   2519675036 2018-12-06
# 2   Philip DeFranco 2006-09-15      6329224   2519675036 2018-12-06
# 3   Philip DeFranco 2006-09-15      6329224   2519675036 2018-12-05
# 4   Philip DeFranco 2006-09-15      6329224   2519675036 2018-12-04
# 5   Philip DeFranco 2006-09-15      6329224   2519675036 2018-12-04
# 6   Philip DeFranco 2006-09-15      6329224   2519675036 2018-12-03
# 7   Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-30
# 8   Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-29
# 9   Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-28
# 10  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-27
# 11  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-26
# 12  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-20
# 13  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-19
# 14  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-16
# 15  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-15
# 16  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-14
# 17  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-13
# 18  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-12
# 19  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-09
# 20  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-08
# 21  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-07
# 22  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-06
# 23  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-05
# 24  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-04
# 25  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-02
# 26  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-01
# 27  Philip DeFranco 2006-09-15      6329224   2519675036 2018-11-01
# 28  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-31
# 29  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-30
# 30  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-29
# 31  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-26
# 32  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-25
# 33  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-25
# 34  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-24
# 35  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-24
# 36  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-23
# 37  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-23
# 38  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-22
# 39  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-19
# 40  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-18
# 41  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-17
# 42  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-16
# 43  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-15
# 44  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-11
# 45  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-10
# 46  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-09
# 47  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-08
# 48  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-04
# 49  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-03
# 50  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-02
# 51  Philip DeFranco 2006-09-15      6329224   2519675036 2018-10-01
# 52  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-28
# 53  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-27
# 54  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-26
# 55  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-25
# 56  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-24
# 57  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-20
# 58  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-19
# 59  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-18
# 60  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-17
# 61  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-14
# 62  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-13
# 63  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-12
# 64  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-11
# 65  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-10
# 66  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-07
# 67  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-06
# 68  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-06
# 69  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-05
# 70  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-05
# 71  Philip DeFranco 2006-09-15      6329224   2519675036 2018-09-04
# 72  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-31
# 73  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-30
# 75  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-29
# 74  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-29
# 76  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-28
# 77  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-27
# 78  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-24
# 79  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-23
# 80  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-23
# 81  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-22
# 82  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-22
# 83  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-21
# 84  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-21
# 85  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-20
# 86  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-17
# 87  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-16
# 88  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-15
# 89  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-14
# 90  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-13
# 91  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-10
# 92  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-09
# 93  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-08
# 94  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-07
# 95  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-06
# 96  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-03
# 97  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-02
# 98  Philip DeFranco 2006-09-15      6329224   2519675036 2018-08-01
# 99  Philip DeFranco 2006-09-15      6329224   2519675036 2018-07-31
#
#                                                 Title Duration    Views  \
# 0   Ariana Grande Backlash, ‘Blackfishing’ Controv...    13:58   930156
# 1   Ridiculous Cheating Hoax, Kim Kardashian Rewri...    18:12   920337
# 2   What Happens When A Wildfire Destroys Your Hom...    13:00   284775
# 3   Massive Twitter Plot Exposed, Youtube Lawsuits...    15:44  1014325
# 4   Controversial Tumblr Ban Highlights Huge Probl...    15:53  1043627
# 5   What’s Really At Stake With The Iran Sanctions...     8:47   530431
# 6   WOW! PewDiePie's Last Stand Surprise Twist, Eg...    15:53  1224698
# 7   Insane Celeb Burglary Ring, Payless Prank, CM ...    14:02  1004745
# 8   Why That Revolting UK Bullying Video Matters, ...    17:35  1087862
# 9   What Shawn Mendes' Backlash & Controversy Show...    18:12  1053336
# 10  Why People Are Freaking Out On Cardi B, Apple'...    13:58  1051842
# 11  The Ridiculous #ThotAudit Tax Evasion Situatio...    19:16  1227618
# 12  A Short Goodbye, Taylor Swift's Profit Play, T...    18:09  1051797
# 13  Why People Are Freaking Out About Chipotle Fir...    19:16  1297084
# 14  Ridiculous Serena Williams Controversy, JUUL v...    18:29   859192
# 15  DISGUSTING! Homeless GoFundMe Scam Exposed, Bh...    18:20  1171047
# 16  Goodbye Europe, Article 13 Youtube Ban, Serial...    15:44  1386275
# 17  WOW! Liza Koshy Leads The Way, CNN Sues Trump,...  2:03:45   976334
# 18  Jeffree Star, Miley Cyrus, Trump and Everythin...    18:34  1129667
# 19  HUGE Crackdown & Ban Around The Corner As Juul...    45:59  1077008
# 20  Shane Dawson Eyes Defy, Tucker Carlson Harassm...    18:34  1217900
# 21  Smosh & DEFY Media's Controversial Shutdown, W...    45:59  1151774
# 22  Facebook's Disturbing Chaotic Failure, Tearing...    18:09   999519
# 23  WOW! Pete Davidson Mocks Vet, Diablo Immortal ...     9:04  1073440
# 24  We Need To Talk About Jair Bolsonaro and The B...    17:16   680762
# 25  Ok... Last Chance To Talk About This, And It's...    11:57   805318
# 26  Massive Google Walkout Scandal, How Logan Paul...    18:46  1190749
# 27                     We Need To Talk About Yemen...    10:19   566671
# 28  The Ridiculously Strange & Confusing Mueller C...    17:05  1121754
# 29  Digital vs Traditional $$$ Revealed, Trump's B...    18:09   972750
# 30  What The Justin Bieber Fake Prank Exposed, Twi...    14:38  1123346
# 31  Kendall Jenner Afro Outrage Ridiculousness, He...    18:46   959935
# 32  Fake News & False Flag Conspiracy Grows, The B...    15:21   901757
# 33  We Need To Talk About The Response & Backlash ...    14:02   724576
# 34  Megyn Kelly Apology BLASTED By Al Roker, Canad...  2:05:24  1007918
# 35  We Need To Talk About the Disturbing Greg Step...    13:10   847527
# 36  Disgusting RyanAir Controversy, Why Drake's HU...    17:21  1190631
# 37  Why You Should Care About This Massive Change ...    13:10   562808
# 38  Why People Are Freaking Out About Amy Schumer,...    13:10  1161880
# 39  What ACTUALLY Happened To Khashoggi, Why It Ma...    15:40   884218
# 40  Massive Leaker Exposed, Kristen Bell Disney Pr...    11:57  1076389
# 41  Is Youtube Guilty Of Double Standard, Roseanne...    11:57  1167049
# 42  Fake Victim Exposed, Chris Evans Masculinity D...    13:56  1120537
# 43  ‘Cornerstore Caroline’ Viral Video Outrage, Wa...    11:57  1069289
# 44  What The McGregor Khabib Chaos Shows Us, NY Li...     9:06  1142676
# 45  HUGE Accusations Against Saudi Arabia, Hurrica...    14:04   993461
# 46  The Taylor Swift Kanye West Debate & Divide, J...    16:57  1189795
# 47   So Let's Talk About This BetterHelp Situation...    19:12  1309391
# 48  The Concerning Story of Shimaa Qasim, Houston'...    14:02  1104185
# 49  Fan Bingbing's Mysterious Disappearance, Presi...    13:28  1199937
# 50  Why People Are Freaking Out About Ariana Grand...    17:21  1504077
# 51  Shane Dawson Logan Paul Sociopath Backlash, Ne...    13:10  1480474
# 52  Brett Kavanaugh Approved, BUT Last Second Twis...    18:29  1354491
# 53  Wow! SEC Suing Elon Musk For Fraud, Brett Kava...    22:27  1300916
# 54  Shane Dawson's Sociopath Search, Getting Divor...    18:43  1740986
# 55  Disturbing Youtube Controversy Arrest, Lilly S...    11:22  1514484
# 56  Shane Dawson Hidden Camera Concern, Rod Rosens...  2:04:58  1494000
# 57  Why People Are Freaking Out On Kristen Bell, A...    16:29  1421229
# 58  Philip DeFranco Exposed, Sirius Boycott, Kylie...    13:10  1361312
# 59  Updated: Machine Gun Kelly, Ninja Makes Histor...    11:22  1507955
# 60  New Allegations, Leaks, & Hacks, Elijah Daniel...    45:59  1295083
# 61  Dua Lipa Crackdown Controversy, Top 10 Youtube...    18:29  1340215
# 62  Donald Trump's Disgusting Puerto Rico Conspira...    17:49  1324543
# 63  Kendall Jenner Leak Controversy, Article 13 Ap...    18:45  1484136
# 64  Wow! Deadspin Anti-NYPD Spider-Man Laziness, S...    13:10  1398553
# 65  Why People Are Freaking Out About Olivia Munn,...    18:29  1461817
# 66  Homeless "Scam" Update, Alex Jones Twitter Ban...    21:42  1556653
# 67  WOW! Leaks and Lies Exposed, Gwyneth Paltrow's...    14:15  1334767
# 68  How Article 13 Could Ruin The Internet And Why...     5:54   785139
# 69  Well...This Is A Mess. Deleting Facebook, Alex...  2:05:24  1318660
# 70  We Need To Talk About Myanmar & The Reuters Re...    13:10   741767
# 71  Massive Nike Kaepernick Backlash, Shane Dawson...    45:07  1675374
# 72  Eminem Kamikaze Controversy, Homeless "Scam" L...    45:59  1606907
# 73  Jennifer Lawrence "Fappening" Closure, David D...    18:37  1602986
# 75  We Need To Talk About The Heartbreaking Jamel ...     9:14   938921
# 74  Elon Musk Reignites Libel Controversy, Califor...    13:10  1540711
# 76  WOW! Louis CK Controversial Redemption Tour, T...    14:25  1318180
# 77  KSI Logan Paul Rigging Accusations, John McCai...    22:01  1437056
# 78  Youtube Crackdown Confusion Explained, Laura L...    17:32  1477143
# 79  Debby Ryan Insatiable Scandal, South Africa Fa...    19:58  1344409
# 80  We Need To Talk About Mollie Tibbetts And The ...    45:59  1408014
# 81  Jake Paul Attack Caught on Video, Argento Evid...    14:02  1340944
# 82  We Need To Talk About Why Prisoners in the US ...    16:54   841999
# 83  RIDICULOUS Tinder Prank Double Standard, Flint...     3:55  1334596
# 84  We Need To Talk About Kerala's Horrific Floodi...    16:14   880710
# 85  The Jeffree Star Laura Lee Apology Implosion, ...    13:10  1900414
# 86  YouTube Burnout Goes Mainstream, Elle Mills, I...    18:29  1371910
# 87  Giving Up On YouTube, WWE Body Shaming Controv...    13:47  1388142
# 88  DISGUSTING! Video Exposes Police Officer, Cath...    14:38  1094787
# 89  WOW! Secret Recording Exposes Lies, Ridiculous...    16:48  1309606
# 90  Ninja's Female Streamer Controversy, Secret Tr...    13:10  1305180
# 91  Logan Paul's Delusion, Tone Deaf Controversy H...    13:54  1583357
# 92  Brock Turner DENIED, James Charles Money Backl...    17:28  1382802
# 93  DISGUSTING! Ariadna Juarez 13-Year-Old Scandal...    14:02  1467999
# 94  Ridiculous Candace Owens Harassment, IGN Plagi...    13:10  1293086
# 95  Why We Need to Talk About The Alex Jones InfoW...    45:59  1421097
# 96  Responding to NYT Criticism, Fortnite Coaching...    11:22  1257831
# 97  The NYT Sarah Jeong Scandal & Double Standard ...    23:51  1174106
# 98  Why People Are Freaking Out About MrBeast, Tom...    15:23  1379300
# 99  The Lele Pons Kylie Jenner Divide, 3D "Ghost G...    15:23  1326803
#
#     Likes  Dislikes                                          URL
# 0   38548      1146  https://www.youtube.com/watch?v=HR4esZZltlQ
# 1   39225      1239  https://www.youtube.com/watch?v=ZpMhQidq1-4
# 2   22446       726  https://www.youtube.com/watch?v=TcNasgwvghg
# 3   45625      2485  https://www.youtube.com/watch?v=GWa3CPSBWfA
# 4   44259      1244  https://www.youtube.com/watch?v=oqTJzvx1MYw
# 5   32758      2107  https://www.youtube.com/watch?v=5uOTgFahVks
# 6   56976      2181  https://www.youtube.com/watch?v=aSAVPnyQ0bw
# 7   52684      1122  https://www.youtube.com/watch?v=X0GZJsfjhD4
# 8   60707      2145  https://www.youtube.com/watch?v=Jom6uIqaf8k
# 9   55951      1286  https://www.youtube.com/watch?v=jOxcPGWm4f4
# 10  40241      1124  https://www.youtube.com/watch?v=lbrQ9yi5wME
# 11  46406      2661  https://www.youtube.com/watch?v=BqvFcbG20Ag
# 12  53462      2020  https://www.youtube.com/watch?v=g2x-v9RXzfc
# 13  48683      2062  https://www.youtube.com/watch?v=5PQn6srQTdA
# 14  36401      1490  https://www.youtube.com/watch?v=BmoQ6ZBv4tA
# 15  45333      1017  https://www.youtube.com/watch?v=nAB_wHRUoKo
# 16  51844      1423  https://www.youtube.com/watch?v=0VHzmSMl1yc
# 17  39108      1806  https://www.youtube.com/watch?v=81RRhwfwClo
# 18  64234      1510  https://www.youtube.com/watch?v=95XjdB8v8V4
# 19  45272      1522  https://www.youtube.com/watch?v=stPvNDke80I
# 20  70110      3270  https://www.youtube.com/watch?v=EhezZ3uX4W8
# 21  45397      1215  https://www.youtube.com/watch?v=WIPKrDAaPps
# 22  35711      1125  https://www.youtube.com/watch?v=lxzJ4oURmtA
# 23  44639      3042  https://www.youtube.com/watch?v=mqgcjC-FeDM
# 24  43127      2838  https://www.youtube.com/watch?v=v4nvHgBSzL0
# 25  43971      1700  https://www.youtube.com/watch?v=JzkS5MypaSY
# 26  40404      1397  https://www.youtube.com/watch?v=kShS2IcNdhc
# 27  42480      1236  https://www.youtube.com/watch?v=F8avr-RiF8g
# 28  39774      1152  https://www.youtube.com/watch?v=49zUeM8-OMk
# 29  37179      1205  https://www.youtube.com/watch?v=d3AVJvTtUlA
# 30  48118      2239  https://www.youtube.com/watch?v=_7KbvPjgNiE
# 31  39825      1316  https://www.youtube.com/watch?v=dS6I4IVeJL8
# 32  39307      1970  https://www.youtube.com/watch?v=bdW7sXVbAyA
# 33  39745      1376  https://www.youtube.com/watch?v=6HSnV6WRQV0
# 34  37997      1481  https://www.youtube.com/watch?v=vq6M2LVsd8c
# 35  47908       613  https://www.youtube.com/watch?v=sMsgbqo8ri0
# 36  47405      1730  https://www.youtube.com/watch?v=DwfOHNPgjfU
# 37  46990       499  https://www.youtube.com/watch?v=OQHZHkBc1t4
# 38  47113      1762  https://www.youtube.com/watch?v=n_wW1pH3-ZY
# 39  41959      1433  https://www.youtube.com/watch?v=jO3F9kMGVAo
# 40  38049      1672  https://www.youtube.com/watch?v=HlNAFJotFAg
# 41  41462      2153  https://www.youtube.com/watch?v=N9iw97U-DAI
# 42  41545      2122  https://www.youtube.com/watch?v=H_RcZTM1sNg
# 43  38964      2645  https://www.youtube.com/watch?v=8zoTZjZQPm0
# 44  38984      3049  https://www.youtube.com/watch?v=F-A1w_5N8cA
# 45  39379      2949  https://www.youtube.com/watch?v=gOnsH_uhsOY
# 46  43739      4339  https://www.youtube.com/watch?v=eU5oGn2Sx2k
# 47  80343     24199  https://www.youtube.com/watch?v=gzRqPFtKiYU
# 48  50149      3371  https://www.youtube.com/watch?v=c1eVfq1PTn4
# 49  45679      1309  https://www.youtube.com/watch?v=6Mjb6_MT-qc
# 50  56675      1730  https://www.youtube.com/watch?v=M-Tag12tY6g
# 51  52735      1680  https://www.youtube.com/watch?v=_GdhxyeNz7w
# 52  60399      3954  https://www.youtube.com/watch?v=Yu8PBEU8ADo
# 53  47028      1359  https://www.youtube.com/watch?v=Q-q3bQln3vQ
# 54  79351      1897  https://www.youtube.com/watch?v=4rEEBRS3_AA
# 55  62945      1349  https://www.youtube.com/watch?v=NodyOh6fioc
# 56  56851      1175  https://www.youtube.com/watch?v=4e-u3hZz7D4
# 57  52937      2268  https://www.youtube.com/watch?v=37KctuX00Y0
# 58  50596      1194  https://www.youtube.com/watch?v=EM8OsadJxtE
# 59  53755      1595  https://www.youtube.com/watch?v=g_WSevYLQLk
# 60  46028      1142  https://www.youtube.com/watch?v=Y9iCq6bSyZs
# 61  50318      1834  https://www.youtube.com/watch?v=qxkXSbfYElE
# 62  51858      3542  https://www.youtube.com/watch?v=jE9S5Psybyw
# 63  54483      1378  https://www.youtube.com/watch?v=hFROh2RCtog
# 64  60611      3400  https://www.youtube.com/watch?v=NX8AJvTtt-4
# 65  55355      1564  https://www.youtube.com/watch?v=VdwkPhYX_3A
# 66  52105      1921  https://www.youtube.com/watch?v=ZsbcILumvsE
# 67  47990      1336  https://www.youtube.com/watch?v=RZfTw14Akek
# 68  46147       441  https://www.youtube.com/watch?v=gYU77Qqvy-U
# 69  55434      1423  https://www.youtube.com/watch?v=GhKW4WK2fDY
# 70  52245       457  https://www.youtube.com/watch?v=kSb3w3EQGCs
# 71  64035      1956  https://www.youtube.com/watch?v=IUD1qxX7zmU
# 72  59069      1455  https://www.youtube.com/watch?v=vVIxBjh1HZw
# 73  55613      1304  https://www.youtube.com/watch?v=cS9cvY2te7Q
# 75  65184      2544  https://www.youtube.com/watch?v=K3theEblQ5c
# 74  57784      2079  https://www.youtube.com/watch?v=xXtPkL4RGOA
# 76  53907      1505  https://www.youtube.com/watch?v=EQ7foiSciZQ
# 77  65063      1370  https://www.youtube.com/watch?v=W4YcrVmPTcE
# 78  66521      1568  https://www.youtube.com/watch?v=b0v_5QVUJwg
# 79  53992      1246  https://www.youtube.com/watch?v=_1EOGuua9h0
# 80  67402      3144  https://www.youtube.com/watch?v=qBCPqiqUGAc
# 81  56910      1275  https://www.youtube.com/watch?v=pU-schvzAOU
# 82  66750       716  https://www.youtube.com/watch?v=XejfyN6i0lM
# 83  59501       957  https://www.youtube.com/watch?v=Kv_zehx2-JA
# 84  82513       520  https://www.youtube.com/watch?v=hzDDYwwDJ1E
# 85  68374      2763  https://www.youtube.com/watch?v=kqxne6K_1qA
# 86  51471      1682  https://www.youtube.com/watch?v=DTGm9eopC5U
# 87  65070      1367  https://www.youtube.com/watch?v=xXVv20QI7P0
# 88  54544       944  https://www.youtube.com/watch?v=DOgjmkKUIDs
# 89  52204      1631  https://www.youtube.com/watch?v=CahtQ-2593s
# 90  55934      1369  https://www.youtube.com/watch?v=KQhvsvD_NIo
# 91  60628      1633  https://www.youtube.com/watch?v=Rxr3RrLaHn8
# 92  61244      2078  https://www.youtube.com/watch?v=Lkn7vxFMZkc
# 93  58396      2378  https://www.youtube.com/watch?v=Oos0BdVnAR8
# 94  51257      1557  https://www.youtube.com/watch?v=_r8yyTtKK2k
# 95  59432     17819  https://www.youtube.com/watch?v=mpbNbGZriIA
# 96  45955      1229  https://www.youtube.com/watch?v=Vsd3M0NFEIA
# 97  43923      1202  https://www.youtube.com/watch?v=gCIKHq32Gpw
# 98  51829      1473  https://www.youtube.com/watch?v=gWrYkFAgZtY
# 99  52418      1447  https://www.youtube.com/watch?v=Bi7dbTcnd6g

# %%
(df.Views.sum()/1000000)*2000
# Out:
# 237926.35

# %%
# Graph Data
#plt.bar(np.arange(0,len(df),1),df["Views"], tick_label = df["Date"])
plt.bar(np.arange(0,len(df),1),df["Views"])
plt.xticks(rotation=90)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  <a list of 8 Text xticklabel objects>)
