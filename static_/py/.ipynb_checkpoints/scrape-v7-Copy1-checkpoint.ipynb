# %%
# To do:
# Fix Dates, must be another published on vs premiered on discrepancy OK
# Fix Titles OK
# Looks like missing one (1) video for Gibi 344/345 OK
# Better commenting
# Duration

# Import Dependencies
from bs4 import BeautifulSoup as bs
import requests
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
pd.set_option('display.max_rows', 500)

# %%
converted_date = ""
raw_months = {"Jan": 1, "Feb": 2, "Mar" : 3, "Apr" : 4, 
              "May" : 5, "Jun" : 6, "Jul" : 7, "Aug" : 8,
              "Sep" : 9, "Oct" : 10, "Nov" : 11, "Dec" : 12}

# Convert Date from Jan 1, 1999 format to datetime object
def convertDate(raw_date):
    
    converted_date = ""
    
    number_month = raw_months.get(raw_date[0])
    
    date_str = (str(number_month) + "/" + raw_date[1] + "/" + raw_date[2]).replace(",", "")
    
    converted_date = datetime.strptime(date_str, '%m/%d/%Y')
    
    return converted_date

# %%
# Get Youtuber's Name
input_name = input("Enter Youtuber's Name: ")

list_name = input_name.split()

converted_name = input_name

if len(list_name) > 1:
    
    converted_name = ""
    
    for i in range(len(list_name)):

        converted_name = converted_name + list_name[i]
        
        if i != len(list_name)-1:
            converted_name = converted_name + "+"

search_name = converted_name

start_url = "https://www.youtube.com/results?search_query=" + search_name
# Out:
# Enter Youtuber's Name: gibi asmr

# %%
print(start_url)
get_youtube_url_response = requests.get(start_url)
# Out:
# https://www.youtube.com/results?search_query=gibi+asmr

# %%
youtube_name_soup = bs(get_youtube_url_response.text, "lxml")

# %%
raw_youtube_name_link = youtube_name_soup.find_all("div", class_="yt-lockup-byline")[0].a.get("href")

videos_link = "https://www.youtube.com" + raw_youtube_name_link + "/videos"

about_link = "https://www.youtube.com" + raw_youtube_name_link + "/about"

print(videos_link)
print(about_link)
# Out:
# https://www.youtube.com/channel/UCE6acMV3m35znLcf0JGNn7Q/videos
# https://www.youtube.com/channel/UCE6acMV3m35znLcf0JGNn7Q/about

# %%
# Get About Information
about_html = requests.get(about_link)

# Parse HTML
about_soup = bs(about_html.text, "lxml")

# %%
# Artist Information
artist_name = about_soup.find("meta", property="og:title").get("content")

subscribers = about_soup.find_all("span", class_="about-stat")[0].text
subscribers_int = int(subscribers.split(" ")[0].replace(",",""))

total_views = about_soup.find_all("span", class_="about-stat")[1].text
total_views_int = int(total_views[3:len(total_views)].split(" ")[0].replace(",",""))

joined = about_soup.find_all("span", class_="about-stat")[2].text
joined_temp = joined.split(" ")[1:4]
joined_convert = convertDate(joined_temp)

print(f"Artist: {artist_name}")
print(f"Subscribers: {subscribers_int}")
print(f"Views: {total_views_int}")
print(f"Joined: {joined_convert}")
# Out:
# Artist: Gibi ASMR
# Subscribers: 1528291
# Views: 381687831
# Joined: 2016-06-18 00:00:00

# %%
# Convert User Name to UU Format
youtube_code = raw_youtube_name_link.split("/")[2]

if youtube_code[0:2] == "UC":
    
    youtube_code = raw_youtube_name_link.split("/")[2]

    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:] 

elif youtube_code[0:2] != "UC":
    
    youtube_code_raw = about_soup.find("link", rel="canonical").get("href")
    
    youtube_code = youtube_code_raw.split("/")[4]
    
    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:]  
    

print(playlist_link)
# Out:
# https://www.youtube.com/playlist?list=UUE6acMV3m35znLcf0JGNn7Q

# %%
# Get Playlist Response
playlist_response = requests.get(playlist_link)

# %%
# Create Playlist Soup Object
playlist_soup = bs(playlist_response.text, 'lxml')

# %%
# Get First Video URL as Starting Point
first_video = "https://www.youtube.com" + playlist_soup.find_all("a", class_="pl-video-title-link")[0].get("href").split("&")[0]
first_video_within_playlist = first_video + "&" + playlist_link.split("?")[1]

print(first_video_within_playlist)
# Out:
# https://www.youtube.com/watch?v=M0xRCrqaffA&list=UUE6acMV3m35znLcf0JGNn7Q

# %%
# Create Soup Object for First Video Inside Playlist
playlist_inside_request = requests.get(first_video_within_playlist) 

playlist_inside_soup = bs(playlist_inside_request.text, "lxml")

# %%
urls_all = []
# urls_all.append(first_video)
i=0
total_videos_in_playlist = int(playlist_inside_soup.find("span", id="playlist-length").text.replace(" videos",""))
number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) 
last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
link_fix = "https://www.youtube.com" + last_shown_link
    
for i in range(total_videos_in_playlist):   

    if i == 0:
        
        
        print(f"loop1, i={i}")
        
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
        
        url = "https://www.youtube.com" + first_link.find_next("a").get("href")
        
        original_url = url.split("&")[0]

        urls_all.append(original_url)
        
        next_link = first_link
        
    elif i == last_video_index:

        print(f"loop2, i={i}------------------------------------------------")
        
        playlist_inside_request = requests.get(link_fix)
        
        playlist_inside_soup = bs(playlist_inside_request.text, "lxml")
        
        last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
        
        link_fix = "https://www.youtube.com" + last_shown_link
        
        last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
                        
#        start_video_new_page_text = playlist_inside_soup.find("span", class_="index").text.replace("\n        ","").replace("\n    ","")

#        start_video_new_page_html = playlist_inside_soup.find_all("span", class_="index")[0]
        
#         if start_video_new_page_text == "▶":
#             start_video_new_page_html = playlist_inside_soup.find_all("span", class_="index")[1]

#         else:
#             start_video_new_page_html = playlist_inside_soup.find_all("span", class_="index")[0]
        
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i+1}\n    ")
        
        next_link = first_link
        
        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
        
        original_url = next_url.split("&")[0]
        
        urls_all.append(original_url)
        
        number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) - 1
              
    else:
        
        print(f"loop3, i={i}")
 
        if i == 1:
    
            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        ▶\n    ")
        
        else:
        
            first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i}\n    ")

        next_link = first_link

        next_link = next_link.find_next("span", class_="index")

        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")

        original_url = next_url.split("&")[0]

        urls_all.append(original_url)
# Out:
# loop1, i=0
# loop3, i=1
# loop3, i=2
# loop3, i=3
# loop3, i=4
# loop3, i=5
# loop3, i=6
# loop3, i=7
# loop3, i=8
# loop3, i=9
# loop3, i=10
# loop3, i=11
# loop3, i=12
# loop3, i=13
# loop3, i=14
# loop3, i=15
# loop3, i=16
# loop3, i=17
# loop3, i=18
# loop3, i=19
# loop3, i=20
# loop3, i=21
# loop3, i=22
# loop3, i=23
# loop3, i=24
# loop3, i=25
# loop3, i=26
# loop3, i=27
# loop3, i=28
# loop3, i=29
# loop3, i=30
# loop3, i=31
# loop3, i=32
# loop3, i=33
# loop3, i=34
# loop3, i=35
# loop3, i=36
# loop3, i=37
# loop3, i=38
# loop3, i=39
# loop3, i=40
# loop3, i=41
# loop3, i=42
# loop3, i=43
# loop3, i=44
# loop3, i=45
# loop3, i=46
# loop3, i=47
# loop3, i=48
# loop3, i=49
# loop3, i=50
# loop3, i=51
# loop3, i=52
# loop3, i=53
# loop3, i=54
# loop3, i=55
# loop3, i=56
# loop3, i=57
# loop3, i=58
# loop3, i=59
# loop3, i=60
# loop3, i=61
# loop3, i=62
# loop3, i=63
# loop3, i=64
# loop3, i=65
# loop3, i=66
# loop3, i=67
# loop3, i=68
# loop3, i=69
# loop3, i=70
# loop3, i=71
# loop3, i=72
# loop3, i=73
# loop3, i=74
# loop3, i=75
# loop3, i=76
# loop3, i=77
# loop3, i=78
# loop2, i=79------------------------------------------------
# loop3, i=80
# loop3, i=81
# loop3, i=82
# loop3, i=83
# loop3, i=84
# loop3, i=85
# loop3, i=86
# loop3, i=87
# loop3, i=88
# loop3, i=89
# loop3, i=90
# loop3, i=91
# loop3, i=92
# loop3, i=93
# loop3, i=94
# loop3, i=95
# loop3, i=96
# loop3, i=97
# loop3, i=98
# loop3, i=99
# loop3, i=100
# loop3, i=101
# loop3, i=102
# loop3, i=103
# loop3, i=104
# loop3, i=105
# loop3, i=106
# loop3, i=107
# loop3, i=108
# loop3, i=109
# loop3, i=110
# loop3, i=111
# loop3, i=112
# loop3, i=113
# loop3, i=114
# loop3, i=115
# loop3, i=116
# loop3, i=117
# loop3, i=118
# loop3, i=119
# loop3, i=120
# loop3, i=121
# loop3, i=122
# loop3, i=123
# loop3, i=124
# loop3, i=125
# loop3, i=126
# loop3, i=127
# loop3, i=128
# loop3, i=129
# loop3, i=130
# loop3, i=131
# loop3, i=132
# loop3, i=133
# loop3, i=134
# loop3, i=135
# loop3, i=136
# loop3, i=137
# loop3, i=138
# loop3, i=139
# loop3, i=140
# loop3, i=141
# loop3, i=142
# loop3, i=143
# loop3, i=144
# loop3, i=145
# loop3, i=146
# loop3, i=147
# loop3, i=148
# loop3, i=149
# loop3, i=150
# loop3, i=151
# loop3, i=152
# loop3, i=153
# loop3, i=154
# loop3, i=155
# loop3, i=156
# loop2, i=157------------------------------------------------
# loop3, i=158
# loop3, i=159
# loop3, i=160
# loop3, i=161
# loop3, i=162
# loop3, i=163
# loop3, i=164
# loop3, i=165
# loop3, i=166
# loop3, i=167
# loop3, i=168
# loop3, i=169
# loop3, i=170
# loop3, i=171
# loop3, i=172
# loop3, i=173
# loop3, i=174
# loop3, i=175
# loop3, i=176
# loop3, i=177
# loop3, i=178
# loop3, i=179
# loop3, i=180
# loop3, i=181
# loop3, i=182
# loop3, i=183
# loop3, i=184
# loop3, i=185
# loop3, i=186
# loop3, i=187
# loop3, i=188
# loop3, i=189
# loop3, i=190
# loop3, i=191
# loop3, i=192
# loop3, i=193
# loop3, i=194
# loop3, i=195
# loop3, i=196
# loop3, i=197
# loop3, i=198
# loop3, i=199
# loop3, i=200
# loop3, i=201
# loop3, i=202
# loop3, i=203
# loop3, i=204
# loop3, i=205
# loop3, i=206
# loop3, i=207
# loop3, i=208
# loop3, i=209
# loop3, i=210
# loop3, i=211
# loop3, i=212
# loop3, i=213
# loop3, i=214
# loop3, i=215
# loop3, i=216
# loop3, i=217
# loop3, i=218
# loop3, i=219
# loop3, i=220
# loop3, i=221
# loop3, i=222
# loop3, i=223
# loop3, i=224
# loop3, i=225
# loop3, i=226
# loop3, i=227
# loop3, i=228
# loop3, i=229
# loop3, i=230
# loop3, i=231
# loop3, i=232
# loop3, i=233
# loop3, i=234
# loop2, i=235------------------------------------------------
# loop3, i=236
# loop3, i=237
# loop3, i=238
# loop3, i=239
# loop3, i=240
# loop3, i=241
# loop3, i=242
# loop3, i=243
# loop3, i=244
# loop3, i=245
# loop3, i=246
# loop3, i=247
# loop3, i=248
# loop3, i=249
# loop3, i=250
# loop3, i=251
# loop3, i=252
# loop3, i=253
# loop3, i=254
# loop3, i=255
# loop3, i=256
# loop3, i=257
# loop3, i=258
# loop3, i=259
# loop3, i=260
# loop3, i=261
# loop3, i=262
# loop3, i=263
# loop3, i=264
# loop3, i=265
# loop3, i=266
# loop3, i=267
# loop3, i=268
# loop3, i=269
# loop3, i=270
# loop3, i=271
# loop3, i=272
# loop3, i=273
# loop3, i=274
# loop3, i=275
# loop3, i=276
# loop3, i=277
# loop3, i=278
# loop3, i=279
# loop3, i=280
# loop3, i=281
# loop3, i=282
# loop3, i=283
# loop3, i=284
# loop3, i=285
# loop3, i=286
# loop3, i=287
# loop3, i=288
# loop3, i=289
# loop3, i=290
# loop3, i=291
# loop3, i=292
# loop3, i=293
# loop3, i=294
# loop3, i=295
# loop3, i=296
# loop3, i=297
# loop3, i=298
# loop3, i=299
# loop3, i=300
# loop3, i=301
# loop3, i=302
# loop3, i=303
# loop3, i=304
# loop3, i=305
# loop3, i=306
# loop3, i=307
# loop3, i=308
# loop3, i=309
# loop3, i=310
# loop3, i=311
# loop3, i=312
# loop2, i=313------------------------------------------------
# loop3, i=314
# loop3, i=315
# loop3, i=316
# loop3, i=317
# loop3, i=318
# loop3, i=319
# loop3, i=320
# loop3, i=321
# loop3, i=322
# loop3, i=323
# loop3, i=324
# loop3, i=325
# loop3, i=326
# loop3, i=327
# loop3, i=328
# loop3, i=329
# loop3, i=330
# loop3, i=331
# loop3, i=332
# loop3, i=333
# loop3, i=334
# loop3, i=335
# loop3, i=336
# loop3, i=337
# loop3, i=338
# loop3, i=339
# loop3, i=340
# loop3, i=341
# loop3, i=342
# loop3, i=343
# loop3, i=344

# %%
urls_all
# Out:
# ['https://www.youtube.com/watch?v=M0xRCrqaffA',
#  'https://www.youtube.com/watch?v=doS3YF55xX4',
#  'https://www.youtube.com/watch?v=Fg9mdZvT-_U',
#  'https://www.youtube.com/watch?v=U5k9Dff4voY',
#  'https://www.youtube.com/watch?v=cu3sm0rmDQY',
#  'https://www.youtube.com/watch?v=nv7gnnRQvS0',
#  'https://www.youtube.com/watch?v=GYgQrnvzNeo',
#  'https://www.youtube.com/watch?v=NrxIxEzyg90',
#  'https://www.youtube.com/watch?v=jRY4GAYR4rA',
#  'https://www.youtube.com/watch?v=s4rAhZ-o2t8',
#  'https://www.youtube.com/watch?v=s__lrPUJj24',
#  'https://www.youtube.com/watch?v=ySbCtJPeo3Y',
#  'https://www.youtube.com/watch?v=rH8KWADhriA',
#  'https://www.youtube.com/watch?v=i5I1DmsQUtU',
#  'https://www.youtube.com/watch?v=3dRkeLxAlYI',
#  'https://www.youtube.com/watch?v=6e6_ziEVsK4',
#  'https://www.youtube.com/watch?v=1V80GYzngcY',
#  'https://www.youtube.com/watch?v=h40ggDIhgDM']

# %%
# Going to Each Video and Extracting Data
published_on = []
raw_published_on = []
views = []
date = []
duration_videos = []
likes = []
dislikes = []
title_videos = []

for i in range(len(urls_all)):
    
    video_url = urls_all[i]
    video_response = requests.get(video_url)
    video_soup = bs(video_response.text, 'lxml')
    
    # Title
    title = video_soup.find("title").text.replace(" - YouTube", "")
    title_videos.append(title)
    
    # Views
    string_views = video_soup.find("div", id="watch7-views-info").text.replace(" views\n\n\n\n\n", "").replace(",","") 
    int_views = int(string_views)
    views.append(int_views)
    
#     # Duration
#     duration = video_soup.find("span", class_="video-time").text
#     duration_videos.append(duration)
    
    # Likes
    string_likes = video_soup.find("button", title="I like this").text
    int_likes = int(string_likes.replace(",",""))
    likes.append(int_likes)
    
    # Dislikes
    string_dislikes = video_soup.find("button", title="I dislike this").text
    int_dislikes = int(string_dislikes.replace(",",""))
    dislikes.append(int_dislikes)
    
    # Publish Date
    raw_publish_date = video_soup.find("div", id="watch-uploader-info").text
    raw_published_on.append(raw_publish_date)
    
    # Handle All Raw Dates "Premiered", ""Published", "Streamed"
    publish_date_format = raw_publish_date.split(" ")[len(raw_publish_date.split(" "))-3:len(raw_publish_date.split(" "))]
    publish_date_convert = convertDate(publish_date_format)
    published_on.append(publish_date_convert)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-e9eb31c5d1b2> in <module>()
#      12
#      13     video_url = urls_all[i]
# ---> 14     video_response = requests.get(video_url)
#      15     video_soup = bs(video_response.text, 'lxml')
#      16
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     656
#     657         if not stream:
# --> 658             r.content
#     659
#     660         return r
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\models.py in content(self)
#     821                 self._content = None
#     822             else:
# --> 823                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     824
#     825         self._content_consumed = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     599                 if self.chunk_left == 0:
#     600                     break
# --> 601                 chunk = self._handle_chunk(amt)
#     602                 decoded = self._decode(chunk, decode_content=decode_content,
#     603                                        flush_decoder=False)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\response.py in _handle_chunk(self, amt)
#     564             returned_chunk = value
#     565         else:  # amt > self.chunk_left
# --> 566             returned_chunk = self._fp._safe_read(self.chunk_left)
#     567             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     568             self.chunk_left = None
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _safe_read(self, amt)
#     610         s = []
#     611         while amt > 0:
# --> 612             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     613             if not chunk:
#     614                 raise IncompleteRead(b''.join(s), amt)
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
# 311  Gibi ASMR  https://www.youtube.com/watch?v=DGcFqS3lBvk
# 312  Gibi ASMR  https://www.youtube.com/watch?v=1a_TK9RNosE
# 313  Gibi ASMR  https://www.youtube.com/watch?v=phKr4h5ceus
# 314  Gibi ASMR  https://www.youtube.com/watch?v=iM9qKNbNbXI
# 315  Gibi ASMR  https://www.youtube.com/watch?v=ToiOVn_G4A8
# 316  Gibi ASMR  https://www.youtube.com/watch?v=cF8iqG2WRJw
# 317  Gibi ASMR  https://www.youtube.com/watch?v=QTGR9xo_QZ8
# 318  Gibi ASMR  https://www.youtube.com/watch?v=I8ELdJIVPXI
# 319  Gibi ASMR  https://www.youtube.com/watch?v=OrB635D-Zb8
# 320  Gibi ASMR  https://www.youtube.com/watch?v=3mbqNqCxr_Y
# 321  Gibi ASMR  https://www.youtube.com/watch?v=l6QfwQBtjE0
# 322  Gibi ASMR  https://www.youtube.com/watch?v=wn8ujQ_xH2U
# 323  Gibi ASMR  https://www.youtube.com/watch?v=B1NXNlXFViY
# 324  Gibi ASMR  https://www.youtube.com/watch?v=INEpilcuclk
# 325  Gibi ASMR  https://www.youtube.com/watch?v=I-9lMZsq2-M
# 326  Gibi ASMR  https://www.youtube.com/watch?v=jicQpYSHtVo
# 327  Gibi ASMR  https://www.youtube.com/watch?v=wv4wPC7W4Ag
# 328  Gibi ASMR  https://www.youtube.com/watch?v=yYCyrZHYcSs
# 329  Gibi ASMR  https://www.youtube.com/watch?v=kYueR4HLhyk
# 330  Gibi ASMR  https://www.youtube.com/watch?v=WX3o_C-b-y8
# 331  Gibi ASMR  https://www.youtube.com/watch?v=a8-Em8IN-OY
# 332  Gibi ASMR  https://www.youtube.com/watch?v=X1RK2Uqfoew
# 333  Gibi ASMR  https://www.youtube.com/watch?v=gJ7bUjF0gfw
# 334  Gibi ASMR  https://www.youtube.com/watch?v=fDOqYHCJ9A8
# 335  Gibi ASMR  https://www.youtube.com/watch?v=YX0kQA1rIi8
# 336  Gibi ASMR  https://www.youtube.com/watch?v=nLx2DoJIaNs
# 337  Gibi ASMR  https://www.youtube.com/watch?v=WuFQDJefNMg
# 338  Gibi ASMR  https://www.youtube.com/watch?v=pqaf8Ch4LCg
# 339  Gibi ASMR  https://www.youtube.com/watch?v=kDwOYXRzETY
# 340  Gibi ASMR  https://www.youtube.com/watch?v=i5I1DmsQUtU
# 341  Gibi ASMR  https://www.youtube.com/watch?v=3dRkeLxAlYI
# 342  Gibi ASMR  https://www.youtube.com/watch?v=6e6_ziEVsK4
# 343  Gibi ASMR  https://www.youtube.com/watch?v=1V80GYzngcY
# 344  Gibi ASMR  https://www.youtube.com/watch?v=h40ggDIhgDM

# %%
# Graph Data
#plt.bar(np.arange(0,len(df),1),df["Views"], tick_label = df["Date"])
plt.bar(np.arange(0,len(df),1),df["Views"])
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Views'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-f55d8fd35af6> in <module>()
#       1 # Graph Data
#       2 #plt.bar(np.arange(0,len(df),1),df["Views"], tick_label = df["Date"])
# ----> 3 plt.bar(np.arange(0,len(df),1),df["Views"])
#       4 plt.xticks(rotation=90)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Views'
