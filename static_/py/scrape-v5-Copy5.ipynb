# %%
# To do
# Fix Dates, must be another published on vs premiered on discrepancy
# Fix Titles
# Looks like missing one (1) video for Gibi 344/345


# Import Dependencies
from bs4 import BeautifulSoup as bs
import requests
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
pd.set_option('display.max_rows', 500)

# %%
converted_date = ""
raw_months = {"Jan": 1, "Feb": 2, "Mar" : 3, "Apr" : 4, 
              "May" : 5, "Jun" : 6, "Jul" : 7, "Aug" : 8,
              "Sep" : 9, "Oct" : 10, "Nov" : 11, "Dec" : 12}

# Convert Date from Jan 1, 1999 format to datetime object
def convertDate(raw_date):
    
    converted_date = ""
    
    temp_date = raw_date.split(" ")
    
    number_month = raw_months.get(temp_date[0])
    
    date_str = (str(number_month) + "/" + temp_date[1] + "/" + temp_date[2]).replace(",", "")
    
    converted_date = datetime.strptime(date_str, '%m/%d/%Y')
    
    return converted_date

# %%
input_name = input("Enter Youtuber's Name: ")

list_name = input_name.split()

converted_name = input_name

if len(list_name) > 1:
    
    converted_name = ""
    
    for i in range(len(list_name)):

        converted_name = converted_name + list_name[i]
        
        if i != len(list_name)-1:
            converted_name = converted_name + "+"

search_name = converted_name

start_url = "https://www.youtube.com/results?search_query=" + search_name
# Out:
# Enter Youtuber's Name: gibi asmr

# %%
print(start_url)
get_youtube_url_response = requests.get(start_url)
# Out:
# https://www.youtube.com/results?search_query=gibi+asmr

# %%
youtube_name_soup = bs(get_youtube_url_response.text, "lxml")

# %%
raw_youtube_name_link = youtube_name_soup.find_all("div", class_="yt-lockup-byline")[0].a.get("href")

videos_link = "https://www.youtube.com" + raw_youtube_name_link + "/videos"

about_link = "https://www.youtube.com" + raw_youtube_name_link + "/about"

print(raw_youtube_name_link)
print(videos_link)
print(about_link)
# Out:
# /channel/UCE6acMV3m35znLcf0JGNn7Q
# https://www.youtube.com/channel/UCE6acMV3m35znLcf0JGNn7Q/videos
# https://www.youtube.com/channel/UCE6acMV3m35znLcf0JGNn7Q/about

# %%
# Get About Information
about_html = requests.get(about_link)

# Parse HTML
about_soup = bs(about_html.text, "lxml")

# %%
# Artist Information
artist_name = about_soup.find("meta", property="og:title").get("content")

subscribers = about_soup.find_all("span", class_="about-stat")[0].text
subscribers_int = int(subscribers.split(" ")[0].replace(",",""))

total_views = about_soup.find_all("span", class_="about-stat")[1].text
total_views_int = int(total_views[3:len(total_views)].split(" ")[0].replace(",",""))

joined = about_soup.find_all("span", class_="about-stat")[2].text
joined_temp = " ".join(joined.split(" ")[1:4])
joined_convert = convertDate(joined_temp)

print(f"Artist: {artist_name}")
print(f"Subscribers: {subscribers_int}")
print(f"Views: {total_views_int}")
print(f"Joined: {joined_convert}")
# Out:
# Artist: Gibi ASMR
# Subscribers: 1528028
# Views: 381641192
# Joined: 2016-06-18 00:00:00

# %%
# Convert User Name to UU Format
youtube_code = raw_youtube_name_link.split("/")[2]

if youtube_code[0:2] == "UC":
    
    youtube_code = raw_youtube_name_link.split("/")[2]

    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:] 

elif youtube_code[0:2] != "UC":
    
    youtube_code_raw = about_soup.find("link", rel="canonical").get("href")
    
    youtube_code = youtube_code_raw.split("/")[4]
    
    playlist_link = "https://www.youtube.com" + "/playlist?list=UU" + youtube_code[2:]  
    

print(playlist_link)
# Out:
# https://www.youtube.com/playlist?list=UUE6acMV3m35znLcf0JGNn7Q

# %%
# Get Playlist Response
playlist_response = requests.get(playlist_link)

# %%
# Create Soup Object
playlist_soup = bs(playlist_response.text, 'lxml')

# %%
# Second URL Approach
# https://www.youtube.com/watch?v=M0xRCrqaffA&list=UUE6acMV3m35znLcf0JGNn7Q&t=0s&index=2
first_video = "https://www.youtube.com" + playlist_soup.find_all("a", class_="pl-video-title-link")[0].get("href").split("&")[0]
first_video_within_playlist = first_video + "&" + playlist_link.split("?")[1]

print(first_video_within_playlist)
# Out:
# https://www.youtube.com/watch?v=M0xRCrqaffA&list=UUE6acMV3m35znLcf0JGNn7Q

# %%
playlist_inside_request = requests.get(first_video_within_playlist) 

playlist_inside_soup = bs(playlist_inside_request.text, "lxml")

# %%
urls_all = []
i=0
index=2
# number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) - 1
total_videos_in_playlist = int(playlist_inside_soup.find("span", id="playlist-length").text.replace(" videos",""))
number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) 
#start_video_new_page = playlist_inside_soup.find("span", class_="index").text.replace("\n        ","").replace("\n    ","")
#last_video_index = int(last_shown_link[last_shown_link.find("index"):].replace("index=","")[:2])
last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))

bump = 0
#last_shown_link = playlist_inside_soup.find("a", title="Previous video").get("href")
last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")

link_fix = "https://www.youtube.com" + last_shown_link
    
for i in range(total_videos_in_playlist-1):   

    if i == 0:
        #print("loop 1")
        #number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) - 1
        
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {len(urls_all)+2}\n    ")
        
        url = "https://www.youtube.com" + first_link.find_next("a").get("href")
        
        original_url = url.split("&")[0]

        urls_all.append(original_url)
        
        next_link = first_link
        
    elif i == last_video_index - 1:
        
        #print("loop 2!!!----------------------------")

        playlist_inside_request = requests.get(link_fix)
        
        playlist_inside_soup = bs(playlist_inside_request.text, "lxml")
        
        #Wrong
        #last_shown_link = playlist_inside_soup.find("a", title="Previous video").get("href")
        last_shown_link = playlist_inside_soup.find_all("span", class_="index")[-1].find_next("a").get("href")
        
        link_fix = "https://www.youtube.com" + last_shown_link
        
        #last_video_index = int(last_shown_link[last_shown_link.find("index"):].replace("index=","")[:2])+2
        
        last_video_index = int(playlist_inside_soup.find_all("span", class_="index")[-1].text.replace("\n        ","").replace("\n    ",""))
                        
        start_video_new_page_text = playlist_inside_soup.find("span", class_="index").text.replace("\n        ","").replace("\n    ","")

        if start_video_new_page_text == "▶":
            start_video_new_page_html = playlist_inside_soup.find_all("span", class_="index")[1]

        else:
            start_video_new_page_html = playlist_inside_soup.find_all("span", class_="index")[0]
        
        first_link = start_video_new_page_html
        
        next_link = first_link
        
        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
        
        original_url = next_url.split("&")[0]
        
        urls_all.append(original_url)
        
        number_of_videos_in_page = len(playlist_inside_soup.find_all("span", class_="index")) - 1
              
    else:
        #print("loop 3")
        first_link = playlist_inside_soup.find("span", class_="index", text=f"\n        {i+1}\n    ")
        
        next_link = first_link
        
        next_link = next_link.find_next("span", class_="index")
        
        next_url = "https://www.youtube.com" + next_link.find_next("a").get("href")
        
        original_url = next_url.split("&")[0]
        
        urls_all.append(original_url)

# %%
# Get Video Titles and URLs
# title_videos = []
# urls = []

# video_info = playlist_soup.find_all("a", class_="pl-video-title-link")

# for title in video_info:
    
#     title_videos.append(title.text.replace("\n      ","").replace("\n    ",""))
    
#     link = "https://www.youtube.com" + title.get("href").split("&")[0]
    
#     urls.append(link)

# %%
# Going to Each Video and Extracting Data
published_on = []
raw_published_on = []
views = []
date = []
duration_videos = []
likes = []
dislikes = []
title_videos = []

for i in range(len(urls_all)):
    
    video_url = urls_all[i]
    
    video_response = requests.get(video_url)
    
    video_soup = bs(video_response.text, 'lxml')
    
    # Title
    video_soup.find("title").text.replace(" - YouTube", "")
    
    
    # Views
    string_views = video_soup.find("div", id="watch7-views-info").text.replace(" views\n\n\n\n\n", "").replace(",","") 
    int_views = int(string_views)
    views.append(int_views)
    
#     # Duration
#     duration = video_soup.find("span", class_="video-time").text
#     duration_videos.append(duration)
    
    # Likes
    string_likes = video_soup.find("button", title="I like this").text
    int_likes = int(string_likes.replace(",",""))
    likes.append(int_likes)
    
    # Dislikes
    string_dislikes = video_soup.find("button", title="I dislike this").text
    int_dislikes = int(string_dislikes.replace(",",""))
    dislikes.append(int_dislikes)
    
    # Publish Date
    raw_publish_date = video_soup.find("div", id="watch-uploader-info").text
    
    raw_published_on.append(raw_publish_date)
    
    if raw_publish_date.split(" ")[0] == "Published":
        
        publish_date = raw_publish_date.split(" ")[2:5]

        publish_date_format = " ".join(publish_date)
        
        publish_date_convert = convertDate(publish_date_format)

        published_on.append(publish_date_convert)
    
    elif raw_publish_date.split(" ")[0] == "Premiered":
        
        publish_date = raw_publish_date.split(" ")[1:4]

        publish_date_format = " ".join(publish_date)
        
        publish_date_convert = convertDate(publish_date_format)

        published_on.append(publish_date_convert)

# %%
# Create DataFrame
df = pd.DataFrame({"Artist" : artist_name,
                   "Joined" : joined_convert,
                   "Subscribers" : subscribers_int,
                   "Total Views" : total_views_int,
                   #"Date": published_on,
                   #"Title" : title_videos,
                   #"Duration" : duration_videos,
                   "Views" : views,
                   "Likes" : likes,
                   "Dislikes" : dislikes,
                   "URL" : urls_all,
                  })

#df = df.sort_values("Date",ascending=False).reindex()
df
# Out:
#         Artist     Joined  Subscribers  Total Views    Views  Likes  Dislikes  \
# 0    Gibi ASMR 2016-06-18      1527214    381353194   366448  10225       228
# 1    Gibi ASMR 2016-06-18      1527214    381353194   196884   6166       132
# 2    Gibi ASMR 2016-06-18      1527214    381353194   280026   7944       224
# 3    Gibi ASMR 2016-06-18      1527214    381353194   979112  17826       468
# 4    Gibi ASMR 2016-06-18      1527214    381353194   474454  11919       262
# 5    Gibi ASMR 2016-06-18      1527214    381353194   713459  14989       880
# 6    Gibi ASMR 2016-06-18      1527214    381353194   596616  18147       538
# 7    Gibi ASMR 2016-06-18      1527214    381353194   437190  14133       302
# 8    Gibi ASMR 2016-06-18      1527214    381353194   496343  13256       287
# 9    Gibi ASMR 2016-06-18      1527214    381353194   710729  15084       451
# 10   Gibi ASMR 2016-06-18      1527214    381353194   363029   9606       216
# 11   Gibi ASMR 2016-06-18      1527214    381353194   932590  20012       541
# 12   Gibi ASMR 2016-06-18      1527214    381353194   360651  11305       352
# 13   Gibi ASMR 2016-06-18      1527214    381353194   557144  15594       555
# 14   Gibi ASMR 2016-06-18      1527214    381353194   976260  36160       807
# 15   Gibi ASMR 2016-06-18      1527214    381353194  1341789  21698      1094
# 16   Gibi ASMR 2016-06-18      1527214    381353194   299763   7451       151
# 17   Gibi ASMR 2016-06-18      1527214    381353194  1925747  31805      1725
# 323  https://www.youtube.com/watch?v=INEpilcuclk
# 324  https://www.youtube.com/watch?v=I-9lMZsq2-M
# 325  https://www.youtube.com/watch?v=jicQpYSHtVo
# 326  https://www.youtube.com/watch?v=wv4wPC7W4Ag
# 327  https://www.youtube.com/watch?v=yYCyrZHYcSs
# 328  https://www.youtube.com/watch?v=kYueR4HLhyk
# 329  https://www.youtube.com/watch?v=WX3o_C-b-y8
# 330  https://www.youtube.com/watch?v=a8-Em8IN-OY
# 331  https://www.youtube.com/watch?v=X1RK2Uqfoew
# 332  https://www.youtube.com/watch?v=gJ7bUjF0gfw
# 333  https://www.youtube.com/watch?v=fDOqYHCJ9A8
# 334  https://www.youtube.com/watch?v=YX0kQA1rIi8
# 335  https://www.youtube.com/watch?v=nLx2DoJIaNs
# 336  https://www.youtube.com/watch?v=WuFQDJefNMg
# 337  https://www.youtube.com/watch?v=pqaf8Ch4LCg
# 338  https://www.youtube.com/watch?v=kDwOYXRzETY
# 339  https://www.youtube.com/watch?v=i5I1DmsQUtU
# 340  https://www.youtube.com/watch?v=3dRkeLxAlYI
# 341  https://www.youtube.com/watch?v=6e6_ziEVsK4
# 342  https://www.youtube.com/watch?v=1V80GYzngcY
# 343  https://www.youtube.com/watch?v=h40ggDIhgDM

# %%
published_on
# Out:
# [datetime.datetime(2018, 12, 6, 0, 0),
#  datetime.datetime(2018, 12, 4, 0, 0),
#  datetime.datetime(2018, 12, 1, 0, 0),
#  datetime.datetime(2018, 11, 29, 0, 0),
#  datetime.datetime(2018, 11, 27, 0, 0),
#  datetime.datetime(2018, 11, 26, 0, 0),
#  datetime.datetime(2018, 11, 24, 0, 0),
#  datetime.datetime(2018, 11, 22, 0, 0),
#  datetime.datetime(2018, 11, 20, 0, 0),
#  datetime.datetime(2018, 11, 17, 0, 0),
#  datetime.datetime(2018, 11, 15, 0, 0),
#  datetime.datetime(2018, 11, 13, 0, 0),
#  datetime.datetime(2018, 11, 10, 0, 0),
#  datetime.datetime(2018, 11, 8, 0, 0),
#  datetime.datetime(2018, 11, 6, 0, 0),
#  datetime.datetime(2018, 11, 4, 0, 0),
#  datetime.datetime(2018, 11, 1, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2018, 10, 27, 0, 0),
#  datetime.datetime(2018, 10, 25, 0, 0),
#  datetime.datetime(2018, 10, 23, 0, 0),
#  datetime.datetime(2018, 10, 20, 0, 0),
#  datetime.datetime(2018, 10, 18, 0, 0),
#  datetime.datetime(2018, 10, 16, 0, 0),
#  datetime.datetime(2018, 10, 13, 0, 0),
#  datetime.datetime(2018, 10, 11, 0, 0),
#  datetime.datetime(2018, 10, 9, 0, 0),
#  datetime.datetime(2018, 10, 6, 0, 0),
#  datetime.datetime(2018, 10, 4, 0, 0),
#  datetime.datetime(2018, 10, 2, 0, 0),
#  datetime.datetime(2018, 9, 29, 0, 0),
#  datetime.datetime(2018, 9, 27, 0, 0),
#  datetime.datetime(2018, 9, 25, 0, 0),
#  datetime.datetime(2018, 9, 22, 0, 0),
#  datetime.datetime(2018, 9, 20, 0, 0),
#  datetime.datetime(2018, 9, 18, 0, 0),
#  datetime.datetime(2018, 9, 16, 0, 0),
#  datetime.datetime(2018, 9, 15, 0, 0),
#  datetime.datetime(2018, 9, 11, 0, 0),
#  datetime.datetime(2018, 9, 11, 0, 0),
#  datetime.datetime(2018, 9, 6, 0, 0),
#  datetime.datetime(2018, 9, 4, 0, 0),
#  datetime.datetime(2018, 9, 1, 0, 0),
#  datetime.datetime(2018, 8, 30, 0, 0),
#  datetime.datetime(2018, 8, 28, 0, 0),
#  datetime.datetime(2018, 8, 25, 0, 0),
#  datetime.datetime(2018, 8, 23, 0, 0),
#  datetime.datetime(2018, 8, 21, 0, 0),
#  datetime.datetime(2018, 8, 19, 0, 0),
#  datetime.datetime(2018, 8, 16, 0, 0),
#  datetime.datetime(2018, 8, 16, 0, 0),
#  datetime.datetime(2018, 8, 14, 0, 0),
#  datetime.datetime(2018, 8, 11, 0, 0),
#  datetime.datetime(2018, 8, 9, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2018, 8, 4, 0, 0),
#  datetime.datetime(2018, 8, 2, 0, 0),
#  datetime.datetime(2018, 8, 2, 0, 0),
#  datetime.datetime(2018, 8, 2, 0, 0),
#  datetime.datetime(2018, 8, 2, 0, 0),
#  datetime.datetime(2018, 8, 2, 0, 0),
#  datetime.datetime(2018, 7, 31, 0, 0),
#  datetime.datetime(2018, 7, 28, 0, 0),
#  datetime.datetime(2018, 7, 26, 0, 0),
#  datetime.datetime(2018, 7, 24, 0, 0),
#  datetime.datetime(2018, 7, 21, 0, 0),
#  datetime.datetime(2018, 7, 19, 0, 0),
#  datetime.datetime(2018, 7, 18, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 7, 14, 0, 0),
#  datetime.datetime(2018, 7, 12, 0, 0),
#  datetime.datetime(2018, 7, 10, 0, 0),
#  datetime.datetime(2018, 7, 7, 0, 0),
#  datetime.datetime(2018, 7, 5, 0, 0),
#  datetime.datetime(2018, 7, 3, 0, 0),
#  datetime.datetime(2018, 6, 30, 0, 0),
#  datetime.datetime(2018, 6, 28, 0, 0),
#  datetime.datetime(2018, 6, 26, 0, 0),
#  datetime.datetime(2018, 8, 4, 0, 0),
#  datetime.datetime(2018, 6, 19, 0, 0),
#  datetime.datetime(2018, 6, 17, 0, 0),
#  datetime.datetime(2018, 6, 14, 0, 0),
#  datetime.datetime(2018, 6, 12, 0, 0),
#  datetime.datetime(2018, 6, 9, 0, 0),
#  datetime.datetime(2018, 6, 7, 0, 0),
#  datetime.datetime(2018, 6, 5, 0, 0),
#  datetime.datetime(2018, 6, 2, 0, 0),
#  datetime.datetime(2018, 5, 31, 0, 0),
#  datetime.datetime(2018, 5, 26, 0, 0),
#  datetime.datetime(2018, 5, 24, 0, 0),
#  datetime.datetime(2018, 5, 22, 0, 0),
#  datetime.datetime(2018, 5, 19, 0, 0),
#  datetime.datetime(2018, 5, 17, 0, 0),
#  datetime.datetime(2018, 5, 15, 0, 0),
#  datetime.datetime(2018, 5, 12, 0, 0),
#  datetime.datetime(2018, 5, 10, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2018, 5, 5, 0, 0),
#  datetime.datetime(2018, 5, 3, 0, 0),
#  datetime.datetime(2018, 5, 1, 0, 0),
#  datetime.datetime(2018, 4, 28, 0, 0),
#  datetime.datetime(2018, 4, 26, 0, 0),
#  datetime.datetime(2018, 4, 24, 0, 0),
#  datetime.datetime(2018, 4, 21, 0, 0),
#  datetime.datetime(2018, 4, 19, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2018, 4, 14, 0, 0),
#  datetime.datetime(2018, 4, 12, 0, 0),
#  datetime.datetime(2018, 4, 10, 0, 0),
#  datetime.datetime(2018, 4, 7, 0, 0),
#  datetime.datetime(2018, 4, 5, 0, 0),
#  datetime.datetime(2018, 4, 3, 0, 0),
#  datetime.datetime(2018, 4, 1, 0, 0),
#  datetime.datetime(2018, 3, 29, 0, 0),
#  datetime.datetime(2018, 3, 27, 0, 0),
#  datetime.datetime(2018, 3, 24, 0, 0),
#  datetime.datetime(2018, 3, 22, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2018, 3, 17, 0, 0),
#  datetime.datetime(2018, 3, 15, 0, 0),
#  datetime.datetime(2018, 3, 13, 0, 0),
#  datetime.datetime(2018, 3, 10, 0, 0),
#  datetime.datetime(2018, 3, 8, 0, 0),
#  datetime.datetime(2018, 3, 6, 0, 0),
#  datetime.datetime(2018, 3, 3, 0, 0),
#  datetime.datetime(2018, 3, 1, 0, 0),
#  datetime.datetime(2018, 2, 27, 0, 0),
#  datetime.datetime(2018, 2, 24, 0, 0),
#  datetime.datetime(2018, 2, 22, 0, 0),
#  datetime.datetime(2018, 2, 20, 0, 0),
#  datetime.datetime(2018, 2, 17, 0, 0),
#  datetime.datetime(2018, 2, 15, 0, 0),
#  datetime.datetime(2018, 2, 13, 0, 0),
#  datetime.datetime(2018, 2, 10, 0, 0),
#  datetime.datetime(2018, 2, 8, 0, 0),
#  datetime.datetime(2018, 2, 6, 0, 0),
#  datetime.datetime(2018, 2, 3, 0, 0),
#  datetime.datetime(2018, 2, 1, 0, 0),
#  datetime.datetime(2018, 1, 30, 0, 0),
#  datetime.datetime(2018, 1, 27, 0, 0),
#  datetime.datetime(2018, 1, 25, 0, 0),
#  datetime.datetime(2018, 1, 23, 0, 0),
#  datetime.datetime(2018, 1, 20, 0, 0),
#  datetime.datetime(2018, 1, 18, 0, 0),
#  datetime.datetime(2018, 1, 16, 0, 0),
#  datetime.datetime(2018, 1, 13, 0, 0),
#  datetime.datetime(2018, 1, 11, 0, 0),
#  datetime.datetime(2018, 1, 9, 0, 0),
#  datetime.datetime(2018, 1, 6, 0, 0),
#  datetime.datetime(2018, 1, 4, 0, 0),
#  datetime.datetime(2018, 1, 2, 0, 0),
#  datetime.datetime(2017, 12, 30, 0, 0),
#  datetime.datetime(2017, 12, 29, 0, 0),
#  datetime.datetime(2017, 12, 26, 0, 0),
#  datetime.datetime(2017, 12, 23, 0, 0),
#  datetime.datetime(2017, 12, 19, 0, 0),
#  datetime.datetime(2017, 12, 16, 0, 0),
#  datetime.datetime(2017, 12, 14, 0, 0),
#  datetime.datetime(2017, 12, 12, 0, 0),
#  datetime.datetime(2017, 12, 9, 0, 0),
#  datetime.datetime(2017, 12, 7, 0, 0),
#  datetime.datetime(2017, 12, 5, 0, 0),
#  datetime.datetime(2017, 12, 2, 0, 0),
#  datetime.datetime(2017, 11, 30, 0, 0),
#  datetime.datetime(2017, 11, 28, 0, 0),
#  datetime.datetime(2017, 11, 25, 0, 0),
#  datetime.datetime(2017, 11, 23, 0, 0),
#  datetime.datetime(2017, 11, 21, 0, 0),
#  datetime.datetime(2017, 11, 18, 0, 0),
#  datetime.datetime(2017, 11, 16, 0, 0),
#  datetime.datetime(2017, 11, 14, 0, 0),
#  datetime.datetime(2017, 11, 11, 0, 0),
#  datetime.datetime(2017, 11, 9, 0, 0),
#  datetime.datetime(2017, 11, 7, 0, 0),
#  datetime.datetime(2017, 11, 4, 0, 0),
#  datetime.datetime(2017, 11, 2, 0, 0),
#  datetime.datetime(2017, 10, 31, 0, 0),
#  datetime.datetime(2017, 10, 28, 0, 0),
#  datetime.datetime(2017, 10, 26, 0, 0),
#  datetime.datetime(2017, 10, 24, 0, 0),
#  datetime.datetime(2017, 10, 21, 0, 0),
#  datetime.datetime(2017, 10, 20, 0, 0),
#  datetime.datetime(2017, 10, 19, 0, 0),
#  datetime.datetime(2017, 10, 17, 0, 0),
#  datetime.datetime(2017, 10, 14, 0, 0),
#  datetime.datetime(2017, 10, 12, 0, 0),
#  datetime.datetime(2017, 10, 11, 0, 0),
#  datetime.datetime(2017, 10, 10, 0, 0),
#  datetime.datetime(2017, 10, 7, 0, 0),
#  datetime.datetime(2017, 10, 5, 0, 0),
#  datetime.datetime(2017, 10, 3, 0, 0),
#  datetime.datetime(2017, 9, 30, 0, 0),
#  datetime.datetime(2017, 9, 28, 0, 0),
#  datetime.datetime(2017, 9, 26, 0, 0),
#  datetime.datetime(2017, 9, 24, 0, 0),
#  datetime.datetime(2017, 9, 21, 0, 0),
#  datetime.datetime(2017, 9, 19, 0, 0),
#  datetime.datetime(2017, 9, 16, 0, 0),
#  datetime.datetime(2017, 9, 14, 0, 0),
#  datetime.datetime(2017, 9, 12, 0, 0),
#  datetime.datetime(2017, 9, 9, 0, 0),
#  datetime.datetime(2017, 9, 7, 0, 0),
#  datetime.datetime(2017, 9, 5, 0, 0),
#  datetime.datetime(2017, 9, 2, 0, 0),
#  datetime.datetime(2017, 8, 31, 0, 0),
#  datetime.datetime(2017, 8, 30, 0, 0),
#  datetime.datetime(2017, 8, 26, 0, 0),
#  datetime.datetime(2017, 8, 24, 0, 0),
#  datetime.datetime(2017, 8, 22, 0, 0),
#  datetime.datetime(2017, 8, 19, 0, 0),
#  datetime.datetime(2017, 8, 17, 0, 0),
#  datetime.datetime(2017, 8, 15, 0, 0),
#  datetime.datetime(2017, 8, 12, 0, 0),
#  datetime.datetime(2017, 8, 10, 0, 0),
#  datetime.datetime(2017, 8, 8, 0, 0),
#  datetime.datetime(2017, 8, 5, 0, 0),
#  datetime.datetime(2017, 8, 3, 0, 0),
#  datetime.datetime(2017, 8, 1, 0, 0),
#  datetime.datetime(2017, 7, 29, 0, 0),
#  datetime.datetime(2017, 7, 27, 0, 0),
#  datetime.datetime(2017, 7, 25, 0, 0),
#  datetime.datetime(2017, 7, 22, 0, 0),
#  datetime.datetime(2017, 7, 20, 0, 0),
#  datetime.datetime(2017, 7, 18, 0, 0),
#  datetime.datetime(2017, 7, 15, 0, 0),
#  datetime.datetime(2017, 7, 13, 0, 0),
#  datetime.datetime(2017, 7, 11, 0, 0),
#  datetime.datetime(2017, 7, 8, 0, 0),
#  datetime.datetime(2017, 7, 6, 0, 0),
#  datetime.datetime(2017, 7, 4, 0, 0),
#  datetime.datetime(2017, 7, 1, 0, 0),
#  datetime.datetime(2017, 8, 17, 0, 0),
#  datetime.datetime(2017, 6, 27, 0, 0),
#  datetime.datetime(2017, 6, 24, 0, 0),
#  datetime.datetime(2017, 6, 22, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2017, 6, 16, 0, 0),
#  datetime.datetime(2017, 6, 13, 0, 0),
#  datetime.datetime(2017, 6, 10, 0, 0),
#  datetime.datetime(2017, 6, 8, 0, 0),
#  datetime.datetime(2017, 6, 6, 0, 0),
#  datetime.datetime(2017, 6, 3, 0, 0),
#  datetime.datetime(2017, 5, 31, 0, 0),
#  datetime.datetime(2017, 5, 30, 0, 0),
#  datetime.datetime(2017, 5, 27, 0, 0),
#  datetime.datetime(2017, 5, 25, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2017, 5, 18, 0, 0),
#  datetime.datetime(2017, 5, 16, 0, 0),
#  datetime.datetime(2017, 5, 13, 0, 0),
#  datetime.datetime(2017, 5, 11, 0, 0),
#  datetime.datetime(2017, 5, 9, 0, 0),
#  datetime.datetime(2017, 5, 6, 0, 0),
#  datetime.datetime(2017, 5, 4, 0, 0),
#  datetime.datetime(2017, 5, 2, 0, 0),
#  datetime.datetime(2017, 4, 29, 0, 0),
#  datetime.datetime(2017, 4, 27, 0, 0),
#  datetime.datetime(2017, 4, 25, 0, 0),
#  datetime.datetime(2017, 4, 23, 0, 0),
#  datetime.datetime(2017, 4, 22, 0, 0),
#  datetime.datetime(2017, 4, 20, 0, 0),
#  datetime.datetime(2017, 4, 19, 0, 0),
#  datetime.datetime(2017, 4, 15, 0, 0),
#  datetime.datetime(2017, 4, 13, 0, 0),
#  datetime.datetime(2017, 4, 11, 0, 0),
#  datetime.datetime(2017, 4, 8, 0, 0),
#  datetime.datetime(2017, 4, 6, 0, 0),
#  datetime.datetime(2017, 4, 4, 0, 0),
#  datetime.datetime(2017, 4, 2, 0, 0),
#  datetime.datetime(2017, 4, 1, 0, 0),
#  datetime.datetime(2017, 3, 31, 0, 0),
#  datetime.datetime(2017, 3, 28, 0, 0),
#  datetime.datetime(2017, 3, 26, 0, 0),
#  datetime.datetime(2017, 3, 23, 0, 0),
#  datetime.datetime(2017, 3, 21, 0, 0),
#  datetime.datetime(2017, 3, 18, 0, 0),
#  datetime.datetime(2017, 3, 16, 0, 0),
#  datetime.datetime(2017, 3, 14, 0, 0),
#  datetime.datetime(2017, 3, 11, 0, 0),
#  datetime.datetime(2017, 3, 9, 0, 0),
#  datetime.datetime(2017, 3, 7, 0, 0),
#  datetime.datetime(2017, 3, 4, 0, 0),
#  datetime.datetime(2017, 3, 2, 0, 0),
#  datetime.datetime(2017, 2, 28, 0, 0),
#  datetime.datetime(2017, 2, 25, 0, 0),
#  datetime.datetime(2017, 2, 23, 0, 0),
#  datetime.datetime(2017, 2, 21, 0, 0),
#  datetime.datetime(2017, 2, 18, 0, 0),
#  datetime.datetime(2017, 2, 16, 0, 0),
#  datetime.datetime(2017, 2, 14, 0, 0),
#  datetime.datetime(2017, 2, 11, 0, 0),
#  datetime.datetime(2017, 2, 9, 0, 0),
#  datetime.datetime(2017, 2, 7, 0, 0),
#  datetime.datetime(2017, 2, 4, 0, 0),
#  datetime.datetime(2017, 2, 2, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 28, 0, 0),
#  datetime.datetime(2017, 1, 26, 0, 0),
#  datetime.datetime(2017, 1, 24, 0, 0),
#  datetime.datetime(2017, 1, 21, 0, 0),
#  datetime.datetime(2017, 1, 19, 0, 0),
#  datetime.datetime(2017, 1, 18, 0, 0),
#  datetime.datetime(2017, 1, 17, 0, 0),
#  datetime.datetime(2017, 1, 4, 0, 0),
#  datetime.datetime(2017, 1, 1, 0, 0),
#  datetime.datetime(2016, 12, 30, 0, 0),
#  datetime.datetime(2016, 12, 24, 0, 0),
#  datetime.datetime(2016, 12, 14, 0, 0),
#  datetime.datetime(2017, 2, 21, 0, 0),
#  datetime.datetime(2016, 12, 10, 0, 0),
#  datetime.datetime(2016, 12, 8, 0, 0),
#  datetime.datetime(2016, 12, 5, 0, 0),
#  datetime.datetime(2016, 11, 30, 0, 0),
#  datetime.datetime(2016, 11, 29, 0, 0),
#  datetime.datetime(2016, 11, 19, 0, 0),
#  datetime.datetime(2016, 11, 10, 0, 0),
#  datetime.datetime(2016, 11, 8, 0, 0),
#  datetime.datetime(2016, 11, 3, 0, 0),
#  datetime.datetime(2016, 10, 30, 0, 0),
#  datetime.datetime(2016, 10, 28, 0, 0),
#  datetime.datetime(2016, 10, 25, 0, 0),
#  datetime.datetime(2016, 10, 23, 0, 0),
#  datetime.datetime(2016, 10, 19, 0, 0),
#  datetime.datetime(2016, 10, 13, 0, 0),
#  datetime.datetime(2016, 10, 4, 0, 0),
#  datetime.datetime(2016, 9, 24, 0, 0),
#  datetime.datetime(2016, 9, 22, 0, 0),
#  datetime.datetime(2016, 9, 13, 0, 0),
#  datetime.datetime(2016, 9, 7, 0, 0),
#  datetime.datetime(2016, 8, 29, 0, 0),
#  datetime.datetime(2016, 8, 25, 0, 0),
#  datetime.datetime(2016, 8, 20, 0, 0),
#  datetime.datetime(2016, 8, 19, 0, 0),
#  datetime.datetime(2016, 8, 17, 0, 0),
#  datetime.datetime(2016, 8, 15, 0, 0),
#  datetime.datetime(2016, 8, 13, 0, 0),
#  datetime.datetime(2016, 8, 9, 0, 0),
#  datetime.datetime(2016, 7, 27, 0, 0),
#  datetime.datetime(2016, 7, 15, 0, 0),
#  datetime.datetime(2016, 6, 26, 0, 0)]

# %%
(df.Views.sum()/1000000)*2000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-142a324e49bc> in <module>()
# ----> 1 (df.Views.sum()/1000000)*2000
#       2 raw_publish_date
#
# NameError: name 'df' is not defined

# %%
# Graph Data
#plt.bar(np.arange(0,len(df),1),df["Views"], tick_label = df["Date"])
plt.bar(np.arange(0,len(df),1),df["Views"])
plt.xticks(rotation=90)
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300., 350., 400.]),
#  <a list of 10 Text xticklabel objects>)
