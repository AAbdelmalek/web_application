# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
response = requests.get("https://www.youtube.com/channel/UCy2if-N3KVswQF2KjiqWx9Q/")

# %%
soup = bs(response.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
raw_youtube_name_link = soup.find("div", class_="yt-lockup-byline")

# %%
raw_youtube_name_link
# Out:
# <div class="yt-lockup-byline"><a aria-label="Go to the user page for Poki ASMR
# " class="yt-uix-sessionlink yt-user-name spf-link " data-sessionlink="ei=e_0bXNCDH5OBDMnUgrAK&amp;feature=c4-feed-u&amp;ved=CMYBEMEbIhMIkK3XxKGv3wIVkwADCh1JqgCmKJsc" dir="ltr" href="/channel/UCy2if-N3KVswQF2KjiqWx9Q">Poki ASMR</a></div>

# %%
raw_youtube_name_link.find_next("img").get("src")
# Out:
# '/yts/img/pixel-vfl3z5WfW.gif'

# %%
soup.find("img", class_="channel-header-profile-image").get("src")
# Out:
# 'https://yt3.ggpht.com/a-/AAuE7mAKQTEFOwJwSAHDBbZqlqRUihUe0QwGDK-D8A=s100-mo-c-c0xffffffff-rj-k-no'
